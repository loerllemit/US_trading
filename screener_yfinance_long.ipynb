# %%
### Needed for google colab runtime
# import sys
# !{sys.executable} -m pip install pandas_datareader yfinance yahoo_fin pandas numpy openpyxl --upgrade --no-cache-dir

# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os, os.path
import errno
from pandas_datareader import data as pdr
from yahoo_fin import stock_info as si
import asyncio
from pandas import ExcelWriter
import yfinance as yf
import pandas as pd
import numpy as np
import multiprocessing
import datetime
import time
yf.pdr_override()

# %%
#create directory if non-existent
def mkdir_p(path):
    try:
        os.makedirs(path)
    except OSError as exc: # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else: raise
mkdir_p('us_stocks')

# %%
### Variables
tickers = pd.DataFrame()
#stock list downloaded from https://stockmarketmba.com/stocksintherussell1000.php
tickers = pd.read_excel("Russell1000list.xlsx",sheet_name=0,header=None,usecols = "A,E",skiprows = 2,names = ["ticker","sector"])
tickers["ticker"] = [item.replace(".", "-") for item in tickers["ticker"]] # Yahoo Finance uses dashes instead of dots
tickers = tickers.set_index("sector")

#combine into one string needed to download multiple files using yfinance module
tickers_string = ""
for i in tickers["ticker"]:
    tickers_string += i + " "

index_name = '^RUI' # Russell 1000
start_date = datetime.datetime.now() - datetime.timedelta(days=365)
end_date = datetime.date.today()

# %%
###  Download ticker data from yahoo finance simultaneously
results = yf.download(tickers = tickers_string,start = start_date, end = end_date, interval= '1d',threads = True,group_by="ticker")

### write to file
for ticker in tickers["ticker"]:
    df = results[ticker].reset_index()
    df.to_csv( os.path.join(os.getcwd(),'us_stocks',ticker+'.csv'), index = False, header=True )
# Out:
# [*********************100%***********************]  1006 of 1006 completed

# %%
# Index Returns
index_df = pdr.get_data_yahoo(index_name, start_date, end_date)
index_return = index_df['Adj Close'].iloc[-1] / index_df['Adj Close'].iloc[0]       # not efficient: (index_df['Percent Change'] + 1).cumprod()[-1]

# Import historical data as CSV for all stocks (makes the process faster)
df_list = pd.concat(( map(pd.read_csv, [os.path.join(os.getcwd(),'us_stocks',s+'.csv') for s in tickers["ticker"] ])), keys=tickers["ticker"] )

# Find top 30% performing stocks (relative to the index)
returns_multiples = []
for ticker in tickers["ticker"]:
    # Calculating returns relative to the market (returns multiple)
    df = df_list.loc[ticker].copy()
    stock_return = df['Adj Close'].iloc[-1] / df['Adj Close'].iloc[0]   # not efficient: ((df['Percent Change'] + 1).cumprod()).iloc[-1]
    
    returns_multiple = round((stock_return / index_return), 2)
    returns_multiples.extend([returns_multiple])
    
    print (f'Ticker: {ticker}; Returns Multiple against index: {returns_multiple}\n')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker: AAPL; Returns Multiple against index: 0.99
#
# Ticker: MSFT; Returns Multiple against index: 0.89
#
# Ticker: GOOG; Returns Multiple against index: 0.79
#
# Ticker: GOOGL; Returns Multiple against index: 0.79
#
# Ticker: AMZN; Returns Multiple against index: 0.61
#
# Ticker: BRK-B; Returns Multiple against index: 1.31
#
# Ticker: TSLA; Returns Multiple against index: 0.61
#
# Ticker: UNH; Returns Multiple against index: 1.41
#
# Ticker: JNJ; Returns Multiple against index: 1.33
#
# Ticker: XOM; Returns Multiple against index: 2.09
#
# Ticker: NVDA; Returns Multiple against index: 0.61
#
# Ticker: WMT; Returns Multiple against index: 1.35
#
# Ticker: V; Returns Multiple against index: 1.22
#
# Ticker: JPM; Returns Multiple against index: 1.02
#
# Ticker: PG; Returns Multiple against index: 1.22
#
# Ticker: CVX; Returns Multiple against index: 1.82
#
# Ticker: LLY; Returns Multiple against index: 1.85
#
# Ticker: MA; Returns Multiple against index: 1.24
#
# Ticker: HD; Returns Multiple against index: 0.96
#
# Ticker: META; Returns Multiple against index: 0.42
#
# Ticker: BAC; Returns Multiple against index: 0.93
#
# Ticker: PFE; Returns Multiple against index: 1.21
#
# Ticker: ABBV; Returns Multiple against index: 1.69
#
# Ticker: MRK; Returns Multiple against index: 1.87
#
# Ticker: KO; Returns Multiple against index: 1.44
#
# Ticker: PEP; Returns Multiple against index: 1.36
#
# Ticker: ORCL; Returns Multiple against index: 1.09
#
# Ticker: AVGO; Returns Multiple against index: 1.11
#
# Ticker: COST; Returns Multiple against index: 1.11
#
# Ticker: TMO; Returns Multiple against index: 1.05
#
# Ticker: CSCO; Returns Multiple against index: 1.06
#
# Ticker: ACN; Returns Multiple against index: 0.94
#
# Ticker: MCD; Returns Multiple against index: 1.3
#
# Ticker: DHR; Returns Multiple against index: 1.01
#
# Ticker: TMUS; Returns Multiple against index: 1.58
#
# Ticker: ABT; Returns Multiple against index: 0.97
#
# Ticker: DIS; Returns Multiple against index: 0.73
#
# Ticker: WFC; Returns Multiple against index: 1.09
#
# Ticker: NKE; Returns Multiple against index: 0.78
#
# Ticker: BMY; Returns Multiple against index: 1.73
#
# Ticker: NEE; Returns Multiple against index: 1.17
#
# Ticker: LIN; Returns Multiple against index: 1.22
#
# Ticker: UPS; Returns Multiple against index: 1.07
#
# Ticker: TXN; Returns Multiple against index: 1.11
#
# Ticker: VZ; Returns Multiple against index: 0.93
#
# Ticker: ADBE; Returns Multiple against index: 0.61
#
# Ticker: PM; Returns Multiple against index: 1.45
#
# Ticker: MS; Returns Multiple against index: 1.08
#
# Ticker: CMCSA; Returns Multiple against index: 0.88
#
# Ticker: COP; Returns Multiple against index: 1.98
#
# Ticker: AMGN; Returns Multiple against index: 1.66
#
# Ticker: SCHW; Returns Multiple against index: 1.22
#
# Ticker: CRM; Returns Multiple against index: 0.61
#
# Ticker: RTX; Returns Multiple against index: 1.42
#
# Ticker: HON; Returns Multiple against index: 1.29
#
# Ticker: QCOM; Returns Multiple against index: 0.81
#
# Ticker: NFLX; Returns Multiple against index: 0.59
#
# Ticker: T; Returns Multiple against index: 1.43
#
# Ticker: IBM; Returns Multiple against index: 1.52
#
# Ticker: LOW; Returns Multiple against index: 0.97
#
# Ticker: CVS; Returns Multiple against index: 1.35
#
# Ticker: DE; Returns Multiple against index: 1.49
#
# Ticker: UNP; Returns Multiple against index: 1.06
#
# Ticker: GS; Returns Multiple against index: 1.14
#
# Ticker: LMT; Returns Multiple against index: 1.76
#
# Ticker: ELV; Returns Multiple against index: 1.55
#
# Ticker: AMD; Returns Multiple against index: 0.59
#
# Ticker: INTC; Returns Multiple against index: 0.7
#
# Ticker: CAT; Returns Multiple against index: 1.39
#
# Ticker: SPGI; Returns Multiple against index: 0.91
#
# Ticker: SBUX; Returns Multiple against index: 1.09
#
# Ticker: AXP; Returns Multiple against index: 1.12
#
# Ticker: INTU; Returns Multiple against index: 0.71
#
# Ticker: ADP; Returns Multiple against index: 1.36
#
# Ticker: GILD; Returns Multiple against index: 1.6
#
# Ticker: BLK; Returns Multiple against index: 0.96
#
# Ticker: PLD; Returns Multiple against index: 0.89
#
# Ticker: MDT; Returns Multiple against index: 0.85
#
# Ticker: BA; Returns Multiple against index: nan
#
# Ticker: AMT; Returns Multiple against index: 0.96
#
# Ticker: CI; Returns Multiple against index: 1.95
#
# Ticker: ISRG; Returns Multiple against index: 0.95
#
# Ticker: GE; Returns Multiple against index: 1.06
#
# Ticker: MDLZ; Returns Multiple against index: 1.37
#
# Ticker: C; Returns Multiple against index: 0.91
#
# Ticker: TJX; Returns Multiple against index: 1.32
#
# Ticker: AMAT; Returns Multiple against index: 0.81
#
# Ticker: SYK; Returns Multiple against index: 1.11
#
# Ticker: CB; Returns Multiple against index: 1.42
#
# Ticker: PYPL; Returns Multiple against index: 0.44
#
# Ticker: ADI; Returns Multiple against index: 1.1
#
# Ticker: NOW; Returns Multiple against index: 0.71
#
# Ticker: MMC; Returns Multiple against index: 1.22
#
# Ticker: MO; Returns Multiple against index: 1.36
#
# Ticker: EL; Returns Multiple against index: 0.81
#
# Ticker: EOG; Returns Multiple against index: 1.87
#
# Ticker: VRTX; Returns Multiple against index: 1.83
#
# Ticker: NOC; Returns Multiple against index: 1.8
#
# Ticker: REGN; Returns Multiple against index: 1.38
#
# Ticker: BKNG; Returns Multiple against index: 1.07
#
# Ticker: DUK; Returns Multiple against index: 1.25
#
# Ticker: PGR; Returns Multiple against index: 1.7
#
# Ticker: TGT; Returns Multiple against index: 0.8
#
# Ticker: SO; Returns Multiple against index: 1.33
#
# Ticker: SLB; Returns Multiple against index: 2.01
#
# Ticker: ZTS; Returns Multiple against index: 0.81
#
# Ticker: BDX; Returns Multiple against index: 1.25
#
# Ticker: ITW; Returns Multiple against index: 1.14
#
# Ticker: MRNA; Returns Multiple against index: 0.74
#
# Ticker: MMM; Returns Multiple against index: 0.89
#
# Ticker: HUM; Returns Multiple against index: 1.51
#
# Ticker: GD; Returns Multiple against index: 1.53
#
# Ticker: APD; Returns Multiple against index: 1.31
#
# Ticker: WM; Returns Multiple against index: 1.25
#
# Ticker: CSX; Returns Multiple against index: 1.03
#
# Ticker: HCA; Returns Multiple against index: 1.2
#
# Ticker: USB; Returns Multiple against index: 0.95
#
# Ticker: FISV; Returns Multiple against index: 1.17
#
# Ticker: PNC; Returns Multiple against index: 0.94
#
# Ticker: BSX; Returns Multiple against index: 1.31
#
# Ticker: SHW; Returns Multiple against index: 0.91
#
# Ticker: ETN; Returns Multiple against index: 1.15
#
# Ticker: CL; Returns Multiple against index: 1.23
#
# Ticker: EQIX; Returns Multiple against index: 1.04
#
# Ticker: CME; Returns Multiple against index: 0.97
#
# Ticker: LRCX; Returns Multiple against index: 0.76
#
# Ticker: AON; Returns Multiple against index: 1.25
#
# Ticker: OXY; Returns Multiple against index: 2.54
#
# Ticker: CCI; Returns Multiple against index: 0.9
#
# Ticker: TFC; Returns Multiple against index: 0.88
#
# Ticker: ICE; Returns Multiple against index: 0.96
#
# Ticker: CHTR; Returns Multiple against index: 0.7
#
# Ticker: MU; Returns Multiple against index: 0.76
#
# Ticker: MET; Returns Multiple against index: 1.55
#
# Ticker: BX; Returns Multiple against index: 0.74
#
# Ticker: NSC; Returns Multiple against index: 1.05
#
# Ticker: ATVI; Returns Multiple against index: 1.56
#
# Ticker: PXD; Returns Multiple against index: 1.64
#
# Ticker: GM; Returns Multiple against index: 0.76
#
# Ticker: EMR; Returns Multiple against index: 1.26
#
# Ticker: FCX; Returns Multiple against index: 1.22
#
# Ticker: MPC; Returns Multiple against index: 2.12
#
# Ticker: MCO; Returns Multiple against index: 0.9
#
# Ticker: F; Returns Multiple against index: 0.84
#
# Ticker: KLAC; Returns Multiple against index: 1.12
#
# Ticker: KDP; Returns Multiple against index: 1.34
#
# Ticker: SNPS; Returns Multiple against index: 1.09
#
# Ticker: MNST; Returns Multiple against index: 1.38
#
# Ticker: MCK; Returns Multiple against index: 2.03
#
# Ticker: ORLY; Returns Multiple against index: 1.49
#
# Ticker: PANW; Returns Multiple against index: 1.14
#
# Ticker: DG; Returns Multiple against index: 1.35
#
# Ticker: UBER; Returns Multiple against index: 0.84
#
# Ticker: SRE; Returns Multiple against index: 1.64
#
# Ticker: MAR; Returns Multiple against index: 1.24
#
# Ticker: PSA; Returns Multiple against index: 1.09
#
# Ticker: VMW; Returns Multiple against index: 1.25
#
# Ticker: PSX; Returns Multiple against index: 1.81
#
# Ticker: VLO; Returns Multiple against index: 2.11
#
# Ticker: GIS; Returns Multiple against index: 1.66
#
# Ticker: D; Returns Multiple against index: 0.97
#
# Ticker: ADM; Returns Multiple against index: 1.75
#
# Ticker: AEP; Returns Multiple against index: 1.44
#
# Ticker: SNOW; Returns Multiple against index: 0.45
#
# Ticker: CNC; Returns Multiple against index: 1.41
#
# Ticker: CDNS; Returns Multiple against index: 1.08
#
# Ticker: AZO; Returns Multiple against index: 1.5
#
# Ticker: KHC; Returns Multiple against index: 1.5
#
# Ticker: APH; Returns Multiple against index: 1.15
#
# Ticker: EW; Returns Multiple against index: 0.73
#
# Ticker: HSY; Returns Multiple against index: 1.57
#
# Ticker: SCCO; Returns Multiple against index: 1.3
#
# Ticker: CTVA; Returns Multiple against index: 1.62
#
# Ticker: ROP; Returns Multiple against index: 1.12
#
# Ticker: CTAS; Returns Multiple against index: 1.23
#
# Ticker: FDX; Returns Multiple against index: 0.87
#
# Ticker: AIG; Returns Multiple against index: 1.39
#
# Ticker: LULU; Returns Multiple against index: 1.05
#
# Ticker: A; Returns Multiple against index: 1.18
#
# Ticker: KMB; Returns Multiple against index: 1.25
#
# Ticker: JCI; Returns Multiple against index: 1.03
#
# Ticker: DXCM; Returns Multiple against index: 1.0
#
# Ticker: MSI; Returns Multiple against index: 1.29
#
# Ticker: PAYX; Returns Multiple against index: 1.22
#
# Ticker: KKR; Returns Multiple against index: 0.78
#
# Ticker: CMG; Returns Multiple against index: 1.05
#
# Ticker: AFL; Returns Multiple against index: 1.56
#
# Ticker: ADSK; Returns Multiple against index: 0.85
#
# Ticker: DVN; Returns Multiple against index: 1.86
#
# Ticker: TRV; Returns Multiple against index: 1.52
#
# Ticker: HES; Returns Multiple against index: 2.07
#
# Ticker: RSG; Returns Multiple against index: 1.24
#
# Ticker: LNG; Returns Multiple against index: 1.9
#
# Ticker: SYY; Returns Multiple against index: 1.42
#
# Ticker: BIIB; Returns Multiple against index: 1.5
#
# Ticker: FIS; Returns Multiple against index: 0.79
#
# Ticker: ECL; Returns Multiple against index: 0.78
#
# Ticker: FTNT; Returns Multiple against index: 0.96
#
# Ticker: MCHP; Returns Multiple against index: 1.06
#
# Ticker: KMI; Returns Multiple against index: 1.44
#
# Ticker: LHX; Returns Multiple against index: 1.25
#
# Ticker: ANET; Returns Multiple against index: 1.25
#
# Ticker: ENPH; Returns Multiple against index: 1.66
#
# Ticker: WMB; Returns Multiple against index: 1.55
#
# Ticker: AJG; Returns Multiple against index: 1.42
#
# Ticker: STZ; Returns Multiple against index: 1.3
#
# Ticker: MSCI; Returns Multiple against index: 0.95
#
# Ticker: EXC; Returns Multiple against index: 1.41
#
# Ticker: TT; Returns Multiple against index: 1.06
#
# Ticker: IQV; Returns Multiple against index: 0.93
#
# Ticker: ROST; Returns Multiple against index: 1.26
#
# Ticker: ABNB; Returns Multiple against index: 0.6
#
# Ticker: PRU; Returns Multiple against index: 1.24
#
# Ticker: O; Returns Multiple against index: 1.15
#
# Ticker: SPG; Returns Multiple against index: 0.96
#
# Ticker: MRVL; Returns Multiple against index: 0.55
#
# Ticker: NEM; Returns Multiple against index: 1.04
#
# Ticker: HLT; Returns Multiple against index: 1.16
#
# Ticker: XEL; Returns Multiple against index: 1.29
#
# Ticker: NUE; Returns Multiple against index: 1.67
#
# Ticker: PH; Returns Multiple against index: 1.13
#
# Ticker: COF; Returns Multiple against index: 0.78
#
# Ticker: CARR; Returns Multiple against index: 0.94
#
# Ticker: SQ; Returns Multiple against index: 0.38
#
# Ticker: BK; Returns Multiple against index: 0.95
#
# Ticker: PCAR; Returns Multiple against index: 1.46
#
# Ticker: YUM; Returns Multiple against index: 1.22
#
# Ticker: IDXX; Returns Multiple against index: 0.81
#
# Ticker: EA; Returns Multiple against index: 1.23
#
# Ticker: DOW; Returns Multiple against index: 1.18
#
# Ticker: LVS; Returns Multiple against index: 1.46
#
# Ticker: WBA; Returns Multiple against index: 1.06
#
# Ticker: BF-B; Returns Multiple against index: 1.28
#
# Ticker: BF-A; Returns Multiple against index: 1.36
#
# Ticker: ABC; Returns Multiple against index: 1.72
#
# Ticker: AMP; Returns Multiple against index: 1.32
#
# Ticker: CMI; Returns Multiple against index: 1.38
#
# Ticker: ALL; Returns Multiple against index: 1.49
#
# Ticker: DD; Returns Multiple against index: 1.1
#
# Ticker: ILMN; Returns Multiple against index: 0.66
#
# Ticker: ED; Returns Multiple against index: 1.5
#
# Ticker: KR; Returns Multiple against index: 1.34
#
# Ticker: TDG; Returns Multiple against index: 1.24
#
# Ticker: HAL; Returns Multiple against index: 1.86
#
# Ticker: WDAY; Returns Multiple against index: 0.69
#
# Ticker: GFS; Returns Multiple against index: 1.12
#
# Ticker: CSGP; Returns Multiple against index: 1.24
#
# Ticker: NDAQ; Returns Multiple against index: 1.19
#
# Ticker: RMD; Returns Multiple against index: 0.99
#
# Ticker: WELL; Returns Multiple against index: 0.99
#
# Ticker: DLTR; Returns Multiple against index: 1.27
#
# Ticker: ODFL; Returns Multiple against index: 0.98
#
# Ticker: MTD; Returns Multiple against index: 1.11
#
# Ticker: AME; Returns Multiple against index: 1.21
#
# Ticker: OTIS; Returns Multiple against index: 1.13
#
# Ticker: VICI; Returns Multiple against index: 1.48
#
# Ticker: SBAC; Returns Multiple against index: 0.98
#
# Ticker: KEYS; Returns Multiple against index: 1.06
#
# Ticker: ALB; Returns Multiple against index: 1.19
#
# Ticker: CTSH; Returns Multiple against index: 0.9
#
# Ticker: DLR; Returns Multiple against index: 0.81
#
# Ticker: ON; Returns Multiple against index: 1.32
#
# Ticker: PPG; Returns Multiple against index: 0.99
#
# Ticker: PCG; Returns Multiple against index: 1.48
#
# Ticker: CEG; Returns Multiple against index: nan
#
# Ticker: WEC; Returns Multiple against index: 1.29
#
# Ticker: ROK; Returns Multiple against index: 0.91
#
# Ticker: GWW; Returns Multiple against index: 1.41
#
# Ticker: PEG; Returns Multiple against index: 1.18
#
# Ticker: HPQ; Returns Multiple against index: 0.96
#
# Ticker: OKE; Returns Multiple against index: 1.31
#
# Ticker: DHI; Returns Multiple against index: 0.96
#
# Ticker: FAST; Returns Multiple against index: 0.99
#
# Ticker: BKR; Returns Multiple against index: 1.41
#
# Ticker: ES; Returns Multiple against index: 1.2
#
# Ticker: VRSK; Returns Multiple against index: 0.97
#
# Ticker: DFS; Returns Multiple against index: 1.13
#
# Ticker: MTB; Returns Multiple against index: 1.31
#
# Ticker: GLW; Returns Multiple against index: 1.08
#
# Ticker: STT; Returns Multiple against index: 1.0
#
# Ticker: RIVN; Returns Multiple against index: 0.28
#
# Ticker: APTV; Returns Multiple against index: 0.71
#
# Ticker: TROW; Returns Multiple against index: 0.75
#
# Ticker: WBD; Returns Multiple against index: 0.53
#
# Ticker: IT; Returns Multiple against index: 1.32
#
# Ticker: AWK; Returns Multiple against index: 1.08
#
# Ticker: GPN; Returns Multiple against index: 0.92
#
# Ticker: LYB; Returns Multiple against index: 1.21
#
# Ticker: IFF; Returns Multiple against index: 0.88
#
# Ticker: ALNY; Returns Multiple against index: 1.5
#
# Ticker: VEEV; Returns Multiple against index: 0.75
#
# Ticker: WTW; Returns Multiple against index: 1.29
#
# Ticker: CRWD; Returns Multiple against index: 0.66
#
# Ticker: BAX; Returns Multiple against index: 0.79
#
# Ticker: GPC; Returns Multiple against index: 1.69
#
# Ticker: HRL; Returns Multiple against index: 1.35
#
# Ticker: CDW; Returns Multiple against index: 1.14
#
# Ticker: ZBH; Returns Multiple against index: 1.18
#
# Ticker: FANG; Returns Multiple against index: 1.57
#
# Ticker: ARE; Returns Multiple against index: 0.86
#
# Ticker: RJF; Returns Multiple against index: 1.44
#
# Ticker: LEN-B; Returns Multiple against index: 0.93
#
# Ticker: LEN; Returns Multiple against index: 0.92
#
# Ticker: CBRE; Returns Multiple against index: 0.91
#
# Ticker: EIX; Returns Multiple against index: 1.25
#
# Ticker: SIRI; Returns Multiple against index: 1.26
#
# Ticker: K; Returns Multiple against index: 1.48
#
# Ticker: TSCO; Returns Multiple against index: 1.14
#
# Ticker: EFX; Returns Multiple against index: 0.8
#
# Ticker: URI; Returns Multiple against index: 1.18
#
# Ticker: FITB; Returns Multiple against index: 0.92
#
# Ticker: EBAY; Returns Multiple against index: 0.8
#
# Ticker: EQR; Returns Multiple against index: 0.88
#
# Ticker: VMC; Returns Multiple against index: 1.08
#
# Ticker: AVB; Returns Multiple against index: 0.85
#
# Ticker: ULTA; Returns Multiple against index: 1.37
#
# Ticker: HIG; Returns Multiple against index: 1.36
#
# Ticker: FTV; Returns Multiple against index: 1.07
#
# Ticker: LUV; Returns Multiple against index: 1.06
#
# Ticker: WY; Returns Multiple against index: 1.01
#
# Ticker: ETR; Returns Multiple against index: 1.39
#
# Ticker: FE; Returns Multiple against index: 1.33
#
# Ticker: TSN; Returns Multiple against index: 0.95
#
# Ticker: TTD; Returns Multiple against index: 0.59
#
# Ticker: MKC; Returns Multiple against index: 1.17
#
# Ticker: AEE; Returns Multiple against index: 1.25
#
# Ticker: FRC; Returns Multiple against index: 0.68
#
# Ticker: HZNP; Returns Multiple against index: 1.13
#
# Ticker: DDOG; Returns Multiple against index: 0.45
#
# Ticker: MLM; Returns Multiple against index: 0.99
#
# Ticker: DAL; Returns Multiple against index: 1.12
#
# Ticker: LSXMA; Returns Multiple against index: 1.05
#
# Ticker: LSXMK; Returns Multiple against index: 1.04
#
# Ticker: FWONK; Returns Multiple against index: 1.17
#
# Ticker: FWONA; Returns Multiple against index: 1.14
#
# Ticker: ANSS; Returns Multiple against index: 0.73
#
# Ticker: DTE; Returns Multiple against index: 1.26
#
# Ticker: HBAN; Returns Multiple against index: 1.2
#
# Ticker: SGEN; Returns Multiple against index: 0.96
#
# Ticker: PFG; Returns Multiple against index: 1.57
#
# Ticker: ACGL; Returns Multiple against index: 1.69
#
# Ticker: IR; Returns Multiple against index: 1.06
#
# Ticker: VRSN; Returns Multiple against index: 0.98
#
# Ticker: PWR; Returns Multiple against index: 1.56
#
# Ticker: HPE; Returns Multiple against index: 1.31
#
# Ticker: CTRA; Returns Multiple against index: 1.65
#
# Ticker: PPL; Returns Multiple against index: 1.26
#
# Ticker: RF; Returns Multiple against index: 1.18
#
# Ticker: EXR; Returns Multiple against index: 0.93
#
# Ticker: LH; Returns Multiple against index: 0.96
#
# Ticker: PODD; Returns Multiple against index: 1.31
#
# Ticker: EPAM; Returns Multiple against index: 0.59
#
# Ticker: ZS; Returns Multiple against index: 0.45
#
# Ticker: PAYC; Returns Multiple against index: 0.87
#
# Ticker: CAH; Returns Multiple against index: 2.06
#
# Ticker: TEAM; Returns Multiple against index: 0.39
#
# Ticker: CFG; Returns Multiple against index: 1.04
#
# Ticker: WAT; Returns Multiple against index: 1.18
#
# Ticker: XYL; Returns Multiple against index: 1.1
#
# Ticker: CF; Returns Multiple against index: 2.08
#
# Ticker: CHD; Returns Multiple against index: 1.04
#
# Ticker: DOV; Returns Multiple against index: 1.0
#
# Ticker: WRB; Returns Multiple against index: 1.74
#
# Ticker: TDY; Returns Multiple against index: 1.15
#
# Ticker: ROL; Returns Multiple against index: 1.45
#
# Ticker: INVH; Returns Multiple against index: 0.91
#
# Ticker: TPL; Returns Multiple against index: 2.37
#
# Ticker: MOH; Returns Multiple against index: 1.37
#
# Ticker: CNP; Returns Multiple against index: 1.38
#
# Ticker: NTRS; Returns Multiple against index: 0.93
#
# Ticker: BBY; Returns Multiple against index: 0.98
#
# Ticker: ZM; Returns Multiple against index: 0.44
#
# Ticker: RPRX; Returns Multiple against index: 1.32
#
# Ticker: HEI; Returns Multiple against index: 1.33
#
# Ticker: HEI-A; Returns Multiple against index: 1.14
#
# Ticker: STE; Returns Multiple against index: 0.97
#
# Ticker: AES; Returns Multiple against index: 1.41
#
# Ticker: MRO; Returns Multiple against index: 2.08
#
# Ticker: BMRN; Returns Multiple against index: 1.4
#
# Ticker: MAA; Returns Multiple against index: 0.9
#
# Ticker: JBHT; Returns Multiple against index: 1.1
#
# Ticker: HOLX; Returns Multiple against index: 1.18
#
# Ticker: WAB; Returns Multiple against index: 1.34
#
# Ticker: LPLA; Returns Multiple against index: 1.68
#
# Ticker: VTR; Returns Multiple against index: 1.12
#
# Ticker: CLX; Returns Multiple against index: 1.09
#
# Ticker: STLD; Returns Multiple against index: 2.18
#
# Ticker: AMCR; Returns Multiple against index: 1.32
#
# Ticker: RBLX; Returns Multiple against index: 0.3
#
# Ticker: EXPD; Returns Multiple against index: 1.05
#
# Ticker: SUI; Returns Multiple against index: 0.86
#
# Ticker: IEX; Returns Multiple against index: 1.21
#
# Ticker: DASH; Returns Multiple against index: 0.38
#
# Ticker: CAG; Returns Multiple against index: 1.49
#
# Ticker: UI; Returns Multiple against index: 1.23
#
# Ticker: MKL; Returns Multiple against index: 1.28
#
# Ticker: GRMN; Returns Multiple against index: 0.85
#
# Ticker: FDS; Returns Multiple against index: 1.17
#
# Ticker: FSLR; Returns Multiple against index: 1.89
#
# Ticker: INCY; Returns Multiple against index: 1.49
#
# Ticker: MPWR; Returns Multiple against index: 0.82
#
# Ticker: WST; Returns Multiple against index: 0.66
#
# Ticker: PKI; Returns Multiple against index: 0.88
#
# Ticker: TTWO; Returns Multiple against index: 0.72
#
# Ticker: DRI; Returns Multiple against index: 1.19
#
# Ticker: CMS; Returns Multiple against index: 1.23
#
# Ticker: BR; Returns Multiple against index: 1.02
#
# Ticker: BALL; Returns Multiple against index: 0.72
#
# Ticker: ETSY; Returns Multiple against index: 0.66
#
# Ticker: J; Returns Multiple against index: 1.03
#
# Ticker: CINF; Returns Multiple against index: 1.13
#
# Ticker: KEY; Returns Multiple against index: 0.94
#
# Ticker: DGX; Returns Multiple against index: 1.15
#
# Ticker: ABMD; Returns Multiple against index: 1.41
#
# Ticker: FOX; Returns Multiple against index: 1.05
#
# Ticker: FOXA; Returns Multiple against index: 1.04
#
# Ticker: LYV; Returns Multiple against index: 0.78
#
# Ticker: TRGP; Returns Multiple against index: 1.62
#
# Ticker: WPC; Returns Multiple against index: 1.27
#
# Ticker: RKT; Returns Multiple against index: 0.66
#
# Ticker: MOS; Returns Multiple against index: 1.62
#
# Ticker: BRO; Returns Multiple against index: 1.04
#
# Ticker: AGR; Returns Multiple against index: 1.07
#
# Ticker: ATO; Returns Multiple against index: 1.54
#
# Ticker: LCID; Returns Multiple against index: 0.23
#
# Ticker: SJM; Returns Multiple against index: 1.47
#
# Ticker: FMC; Returns Multiple against index: 1.45
#
# Ticker: OMC; Returns Multiple against index: 1.37
#
# Ticker: SYF; Returns Multiple against index: 0.91
#
# Ticker: COO; Returns Multiple against index: 0.91
#
# Ticker: CPRT; Returns Multiple against index: 1.04
#
# Ticker: CPB; Returns Multiple against index: 1.58
#
# Ticker: EXPE; Returns Multiple against index: 0.68
#
# Ticker: IRM; Returns Multiple against index: 1.45
#
# Ticker: HWM; Returns Multiple against index: 1.48
#
# Ticker: ALGN; Returns Multiple against index: 0.33
#
# Ticker: AVY; Returns Multiple against index: 1.09
#
# Ticker: PLTR; Returns Multiple against index: 0.43
#
# Ticker: RCL; Returns Multiple against index: 0.93
#
# Ticker: FICO; Returns Multiple against index: 1.83
#
# Ticker: GEN; Returns Multiple against index: 1.17
#
# Ticker: AZPN; Returns Multiple against index: 1.79
#
# Ticker: AVTR; Returns Multiple against index: 0.66
#
# Ticker: EQT; Returns Multiple against index: 2.17
#
# Ticker: SWKS; Returns Multiple against index: 0.71
#
# Ticker: NVR; Returns Multiple against index: 0.95
#
# Ticker: TRMB; Returns Multiple against index: 0.8
#
# Ticker: PINS; Returns Multiple against index: 0.68
#
# Ticker: APA; Returns Multiple against index: 2.03
#
# Ticker: LDOS; Returns Multiple against index: 1.49
#
# Ticker: PTC; Returns Multiple against index: 1.22
#
# Ticker: AKAM; Returns Multiple against index: 0.97
#
# Ticker: SPLK; Returns Multiple against index: 0.86
#
# Ticker: HUBS; Returns Multiple against index: 0.42
#
# Ticker: BG; Returns Multiple against index: 1.36
#
# Ticker: NTAP; Returns Multiple against index: 0.87
#
# Ticker: TXT; Returns Multiple against index: 1.19
#
# Ticker: LKQ; Returns Multiple against index: 1.15
#
# Ticker: TYL; Returns Multiple against index: 0.72
#
# Ticker: FLT; Returns Multiple against index: 1.01
#
# Ticker: TER; Returns Multiple against index: 0.69
#
# Ticker: UAL; Returns Multiple against index: 1.23
#
# Ticker: MGM; Returns Multiple against index: 1.05
#
# Ticker: SPOT; Returns Multiple against index: 0.37
#
# Ticker: ESS; Returns Multiple against index: 0.76
#
# Ticker: BAH; Returns Multiple against index: 1.55
#
# Ticker: NET; Returns Multiple against index: 0.33
#
# Ticker: PEAK; Returns Multiple against index: 0.94
#
# Ticker: KIM; Returns Multiple against index: 1.16
#
# Ticker: MTCH; Returns Multiple against index: 0.39
#
# Ticker: LNT; Returns Multiple against index: 1.18
#
# Ticker: JKHY; Returns Multiple against index: 1.44
#
# Ticker: ZBRA; Returns Multiple against index: 0.51
#
# Ticker: L; Returns Multiple against index: 1.22
#
# Ticker: WLK; Returns Multiple against index: 1.34
#
# Ticker: NDSN; Returns Multiple against index: 1.07
#
# Ticker: CHK; Returns Multiple against index: 1.95
#
# Ticker: DPZ; Returns Multiple against index: 0.85
#
# Ticker: SSNC; Returns Multiple against index: 0.8
#
# Ticker: VTRS; Returns Multiple against index: 1.11
#
# Ticker: BEN; Returns Multiple against index: 1.01
#
# Ticker: CSL; Returns Multiple against index: 1.27
#
# Ticker: HUBB; Returns Multiple against index: 1.45
#
# Ticker: OVV; Returns Multiple against index: 1.78
#
# Ticker: ARES; Returns Multiple against index: 1.13
#
# Ticker: EVRG; Returns Multiple against index: 1.1
#
# Ticker: RS; Returns Multiple against index: 1.64
#
# Ticker: SIVB; Returns Multiple against index: 0.34
#
# Ticker: GLPI; Returns Multiple against index: 1.43
#
# Ticker: RPM; Returns Multiple against index: 1.3
#
# Ticker: CBOE; Returns Multiple against index: 1.18
#
# Ticker: IPG; Returns Multiple against index: 1.13
#
# Ticker: HST; Returns Multiple against index: 1.26
#
# Ticker: UDR; Returns Multiple against index: 0.84
#
# Ticker: IP; Returns Multiple against index: 0.99
#
# Ticker: FHN; Returns Multiple against index: 1.82
#
# Ticker: AXON; Returns Multiple against index: 1.36
#
# Ticker: POOL; Returns Multiple against index: 0.69
#
# Ticker: PARAA; Returns Multiple against index: 0.72
#
# Ticker: PARA; Returns Multiple against index: 0.72
#
# Ticker: LBRDA; Returns Multiple against index: 0.67
#
# Ticker: LBRDK; Returns Multiple against index: 0.66
#
# Ticker: BILL; Returns Multiple against index: 0.49
#
# Ticker: VFC; Returns Multiple against index: 0.48
#
# Ticker: ERIE; Returns Multiple against index: 1.77
#
# Ticker: RE; Returns Multiple against index: 1.52
#
# Ticker: SNA; Returns Multiple against index: 1.37
#
# Ticker: BURL; Returns Multiple against index: 0.83
#
# Ticker: CPT; Returns Multiple against index: 0.82
#
# Ticker: WTRG; Returns Multiple against index: 1.18
#
# Ticker: PKG; Returns Multiple against index: 1.28
#
# Ticker: UTHR; Returns Multiple against index: 1.73
#
# Ticker: LW; Returns Multiple against index: 1.86
#
# Ticker: PCTY; Returns Multiple against index: 0.97
#
# Ticker: BIO; Returns Multiple against index: 0.63
#
# Ticker: GDDY; Returns Multiple against index: 1.23
#
# Ticker: ELS; Returns Multiple against index: 0.92
#
# Ticker: U; Returns Multiple against index: 0.27
#
# Ticker: DINO; Returns Multiple against index: 1.93
#
# Ticker: SWK; Returns Multiple against index: 0.51
#
# Ticker: NBIX; Returns Multiple against index: 1.73
#
# Ticker: AFG; Returns Multiple against index: 1.37
#
# Ticker: TRU; Returns Multiple against index: 0.61
#
# Ticker: EQH; Returns Multiple against index: 1.16
#
# Ticker: DOX; Returns Multiple against index: 1.54
#
# Ticker: ACM; Returns Multiple against index: 1.4
#
# Ticker: GGG; Returns Multiple against index: 1.05
#
# Ticker: GL; Returns Multiple against index: 1.58
#
# Ticker: MAS; Returns Multiple against index: 0.87
#
# Ticker: ZI; Returns Multiple against index: 0.51
#
# Ticker: CE; Returns Multiple against index: 0.81
#
# Ticker: DELL; Returns Multiple against index: 0.9
#
# Ticker: CHRW; Returns Multiple against index: 1.2
#
# Ticker: AMH; Returns Multiple against index: 0.94
#
# Ticker: TTC; Returns Multiple against index: 1.32
#
# Ticker: CG; Returns Multiple against index: 0.69
#
# Ticker: CRL; Returns Multiple against index: 0.7
#
# Ticker: TFX; Returns Multiple against index: 0.89
#
# Ticker: QGEN; Returns Multiple against index: 1.08
#
# Ticker: CNA; Returns Multiple against index: 1.25
#
# Ticker: ENTG; Returns Multiple against index: 0.55
#
# Ticker: WDC; Returns Multiple against index: 0.7
#
# Ticker: DT; Returns Multiple against index: 0.67
#
# Ticker: NI; Returns Multiple against index: 1.35
#
# Ticker: HSIC; Returns Multiple against index: 1.3
#
# Ticker: REG; Returns Multiple against index: 1.11
#
# Ticker: BXP; Returns Multiple against index: 0.7
#
# Ticker: MDB; Returns Multiple against index: 0.33
#
# Ticker: CZR; Returns Multiple against index: 0.63
#
# Ticker: ACI; Returns Multiple against index: 1.09
#
# Ticker: CCL; Returns Multiple against index: 0.58
#
# Ticker: BSY; Returns Multiple against index: 0.94
#
# Ticker: NWS; Returns Multiple against index: 1.02
#
# Ticker: NWSA; Returns Multiple against index: 1.02
#
# Ticker: FNF; Returns Multiple against index: 0.91
#
# Ticker: FCNCA; Returns Multiple against index: 1.16
#
# Ticker: SCI; Returns Multiple against index: 1.25
#
# Ticker: KMX; Returns Multiple against index: 0.53
#
# Ticker: ARMK; Returns Multiple against index: 1.4
#
# Ticker: CDAY; Returns Multiple against index: 0.7
#
# Ticker: SRPT; Returns Multiple against index: 1.69
#
# Ticker: WOLF; Returns Multiple against index: 0.79
#
# Ticker: JNPR; Returns Multiple against index: 1.23
#
# Ticker: MORN; Returns Multiple against index: 0.88
#
# Ticker: AR; Returns Multiple against index: 2.18
#
# Ticker: NFE; Returns Multiple against index: 2.15
#
# Ticker: WSO; Returns Multiple against index: 1.01
#
# Ticker: RGEN; Returns Multiple against index: 0.77
#
# Ticker: MTN; Returns Multiple against index: 0.89
#
# Ticker: FIVE; Returns Multiple against index: 1.07
#
# Ticker: EMN; Returns Multiple against index: 0.91
#
# Ticker: DAR; Returns Multiple against index: 1.12
#
# Ticker: DECK; Returns Multiple against index: 1.12
#
# Ticker: PHM; Returns Multiple against index: 0.96
#
# Ticker: MKTX; Returns Multiple against index: 0.91
#
# Ticker: OKTA; Returns Multiple against index: 0.31
#
# Ticker: NLY; Returns Multiple against index: 0.86
#
# Ticker: WSC; Returns Multiple against index: 1.4
#
# Ticker: REXR; Returns Multiple against index: 0.87
#
# Ticker: ALLE; Returns Multiple against index: 1.01
#
# Ticker: BWA; Returns Multiple against index: 1.09
#
# Ticker: BRKR; Returns Multiple against index: 0.98
#
# Ticker: CCK; Returns Multiple against index: 0.95
#
# Ticker: BBWI; Returns Multiple against index: 0.69
#
# Ticker: QRVO; Returns Multiple against index: 0.72
#
# Ticker: JAZZ; Returns Multiple against index: 1.44
#
# Ticker: SNX; Returns Multiple against index: 1.08
#
# Ticker: AGCO; Returns Multiple against index: 1.41
#
# Ticker: JBL; Returns Multiple against index: 1.38
#
# Ticker: VST; Returns Multiple against index: 1.4
#
# Ticker: EWBC; Returns Multiple against index: 1.02
#
# Ticker: LSCC; Returns Multiple against index: 1.05
#
# Ticker: RGA; Returns Multiple against index: 1.75
#
# Ticker: NRG; Returns Multiple against index: 1.12
#
# Ticker: DOCU; Returns Multiple against index: 0.33
#
# Ticker: WRK; Returns Multiple against index: 1.01
#
# Ticker: BKI; Returns Multiple against index: 0.95
#
# Ticker: BJ; Returns Multiple against index: 1.28
#
# Ticker: WYNN; Returns Multiple against index: 1.17
#
# Ticker: LII; Returns Multiple against index: 0.95
#
# Ticker: UHS; Returns Multiple against index: 1.2
#
# Ticker: PFGC; Returns Multiple against index: 1.57
#
# Ticker: CTLT; Returns Multiple against index: 0.46
#
# Ticker: BLDR; Returns Multiple against index: 0.98
#
# Ticker: CMA; Returns Multiple against index: 0.97
#
# Ticker: FFIV; Returns Multiple against index: 0.79
#
# Ticker: WBS; Returns Multiple against index: 1.11
#
# Ticker: CUBE; Returns Multiple against index: 0.95
#
# Ticker: TPR; Returns Multiple against index: 1.06
#
# Ticker: AOS; Returns Multiple against index: 0.88
#
# Ticker: HII; Returns Multiple against index: 1.57
#
# Ticker: PLUG; Returns Multiple against index: 0.46
#
# Ticker: AAP; Returns Multiple against index: 0.78
#
# Ticker: AAL; Returns Multiple against index: 0.95
#
# Ticker: CFR; Returns Multiple against index: 1.33
#
# Ticker: CAR; Returns Multiple against index: 0.95
#
# Ticker: KNX; Returns Multiple against index: 1.13
#
# Ticker: PSTG; Returns Multiple against index: 1.06
#
# Ticker: LSI; Returns Multiple against index: 0.93
#
# Ticker: STOR; Returns Multiple against index: 1.17
#
# Ticker: PAG; Returns Multiple against index: 1.51
#
# Ticker: FRT; Returns Multiple against index: 1.02
#
# Ticker: Z; Returns Multiple against index: 0.69
#
# Ticker: ZG; Returns Multiple against index: 0.68
#
# Ticker: IVZ; Returns Multiple against index: 0.99
#
# Ticker: PNW; Returns Multiple against index: 1.49
#
# Ticker: CGNX; Returns Multiple against index: 0.76
#
# Ticker: CASY; Returns Multiple against index: 1.5
#
# Ticker: NOV; Returns Multiple against index: 1.92
#
# Ticker: HAS; Returns Multiple against index: 0.75
#
# Ticker: LAMR; Returns Multiple against index: 1.02
#
# Ticker: JEF; Returns Multiple against index: 1.17
#
# Ticker: AA; Returns Multiple against index: 1.21
#
# Ticker: TWLO; Returns Multiple against index: 0.2
#
# Ticker: NVCR; Returns Multiple against index: 0.96
#
# Ticker: LECO; Returns Multiple against index: 1.3
#
# Ticker: RHI; Returns Multiple against index: 0.83
#
# Ticker: SEIC; Returns Multiple against index: 1.23
#
# Ticker: RRX; Returns Multiple against index: 0.9
#
# Ticker: G; Returns Multiple against index: 1.08
#
# Ticker: CBSH; Returns Multiple against index: 1.22
#
# Ticker: OC; Returns Multiple against index: 1.15
#
# Ticker: FBHS; Returns Multiple against index: 0.7
#
# Ticker: SBNY; Returns Multiple against index: 0.45
#
# Ticker: UNM; Returns Multiple against index: 2.2
#
# Ticker: LEA; Returns Multiple against index: 0.89
#
# Ticker: ADT; Returns Multiple against index: 1.37
#
# Ticker: CHDN; Returns Multiple against index: 1.13
#
# Ticker: DISH; Returns Multiple against index: 0.54
#
# Ticker: FND; Returns Multiple against index: 0.66
#
# Ticker: TTEK; Returns Multiple against index: 0.99
#
# Ticker: NNN; Returns Multiple against index: 1.25
#
# Ticker: EXAS; Returns Multiple against index: 0.65
#
# Ticker: CLF; Returns Multiple against index: 0.91
#
# Ticker: USFD; Returns Multiple against index: 1.26
#
# Ticker: WHR; Returns Multiple against index: 0.79
#
# Ticker: GME; Returns Multiple against index: 0.65
#
# Ticker: COIN; Returns Multiple against index: 0.18
#
# Ticker: UGI; Returns Multiple against index: 1.08
#
# Ticker: IBKR; Returns Multiple against index: 1.24
#
# Ticker: GLOB; Returns Multiple against index: 0.73
#
# Ticker: COLD; Returns Multiple against index: 1.09
#
# Ticker: WMS; Returns Multiple against index: 0.8
#
# Ticker: RNR; Returns Multiple against index: 1.4
#
# Ticker: OGE; Returns Multiple against index: 1.4
#
# Ticker: PEN; Returns Multiple against index: 1.0
#
# Ticker: ACHC; Returns Multiple against index: 1.73
#
# Ticker: JLL; Returns Multiple against index: 0.75
#
# Ticker: MANH; Returns Multiple against index: 0.92
#
# Ticker: MIDD; Returns Multiple against index: 0.91
#
# Ticker: WSM; Returns Multiple against index: 0.76
#
# Ticker: ZION; Returns Multiple against index: 0.93
#
# Ticker: MPW; Returns Multiple against index: 0.72
#
# Ticker: OLN; Returns Multiple against index: 1.16
#
# Ticker: ALLY; Returns Multiple against index: 0.66
#
# Ticker: HR; Returns Multiple against index: 0.87
#
# Ticker: RL; Returns Multiple against index: 1.11
#
# Ticker: CHE; Returns Multiple against index: 1.26
#
# Ticker: PNR; Returns Multiple against index: 0.74
#
# Ticker: MASI; Returns Multiple against index: 0.59
#
# Ticker: SEE; Returns Multiple against index: 1.0
#
# Ticker: CPRI; Returns Multiple against index: 1.06
#
# Ticker: GMED; Returns Multiple against index: 1.2
#
# Ticker: SWN; Returns Multiple against index: 1.37
#
# Ticker: BERY; Returns Multiple against index: 1.04
#
# Ticker: HOOD; Returns Multiple against index: 0.48
#
# Ticker: RGLD; Returns Multiple against index: 1.34
#
# Ticker: WEX; Returns Multiple against index: 1.45
#
# Ticker: DCI; Returns Multiple against index: 1.24
#
# Ticker: AGL; Returns Multiple against index: 0.91
#
# Ticker: ORI; Returns Multiple against index: 1.28
#
# Ticker: CACI; Returns Multiple against index: 1.39
#
# Ticker: VMI; Returns Multiple against index: 1.55
#
# Ticker: WAL; Returns Multiple against index: 0.69
#
# Ticker: ROKU; Returns Multiple against index: 0.24
#
# Ticker: KBR; Returns Multiple against index: 1.4
#
# Ticker: PCOR; Returns Multiple against index: 0.64
#
# Ticker: GPK; Returns Multiple against index: 1.37
#
# Ticker: PATH; Returns Multiple against index: 0.32
#
# Ticker: NTNX; Returns Multiple against index: 1.08
#
# Ticker: OHI; Returns Multiple against index: 1.38
#
# Ticker: NCLH; Returns Multiple against index: 0.88
#
# Ticker: ITT; Returns Multiple against index: 0.96
#
# Ticker: ATR; Returns Multiple against index: 1.09
#
# Ticker: BOKF; Returns Multiple against index: 1.21
#
# Ticker: TW; Returns Multiple against index: 0.81
#
# Ticker: ST; Returns Multiple against index: 0.89
#
# Ticker: MTZ; Returns Multiple against index: 1.1
#
# Ticker: DKNG; Returns Multiple against index: 0.52
#
# Ticker: NXST; Returns Multiple against index: 1.43
#
# Ticker: HOG; Returns Multiple against index: 1.5
#
# Ticker: BRX; Returns Multiple against index: 1.16
#
# Ticker: PB; Returns Multiple against index: 1.22
#
# Ticker: SF; Returns Multiple against index: 1.05
#
# Ticker: CW; Returns Multiple against index: 1.6
#
# Ticker: GNTX; Returns Multiple against index: 0.96
#
# Ticker: CLVT; Returns Multiple against index: 0.44
#
# Ticker: DXC; Returns Multiple against index: 1.08
#
# Ticker: RRC; Returns Multiple against index: 1.64
#
# Ticker: AIZ; Returns Multiple against index: 1.02
#
# Ticker: XRAY; Returns Multiple against index: 0.69
#
# Ticker: HRB; Returns Multiple against index: 2.14
#
# Ticker: EGP; Returns Multiple against index: 0.89
#
# Ticker: COTY; Returns Multiple against index: 0.94
#
# Ticker: REYN; Returns Multiple against index: 1.32
#
# Ticker: OGN; Returns Multiple against index: 1.12
#
# Ticker: NVT; Returns Multiple against index: 1.3
#
# Ticker: FR; Returns Multiple against index: 0.96
#
# Ticker: ARW; Returns Multiple against index: 1.02
#
# Ticker: RH; Returns Multiple against index: 0.54
#
# Ticker: DBX; Returns Multiple against index: 1.1
#
# Ticker: RUN; Returns Multiple against index: 0.8
#
# Ticker: PLNT; Returns Multiple against index: 1.03
#
# Ticker: CIEN; Returns Multiple against index: 0.86
#
# Ticker: PII; Returns Multiple against index: 1.23
#
# Ticker: STWD; Returns Multiple against index: 1.06
#
# Ticker: DVA; Returns Multiple against index: 0.85
#
# Ticker: PDCE; Returns Multiple against index: 1.57
#
# Ticker: CHH; Returns Multiple against index: 0.97
#
# Ticker: LNC; Returns Multiple against index: 0.69
#
# Ticker: MAT; Returns Multiple against index: 0.98
#
# Ticker: MHK; Returns Multiple against index: 0.65
#
# Ticker: DKS; Returns Multiple against index: 1.3
#
# Ticker: GNRC; Returns Multiple against index: 0.31
#
# Ticker: CLH; Returns Multiple against index: 1.38
#
# Ticker: WCC; Returns Multiple against index: 1.13
#
# Ticker: WH; Returns Multiple against index: 1.06
#
# Ticker: LAD; Returns Multiple against index: 0.96
#
# Ticker: INGR; Returns Multiple against index: 1.26
#
# Ticker: PNFP; Returns Multiple against index: 0.94
#
# Ticker: MDU; Returns Multiple against index: 1.33
#
# Ticker: FYBR; Returns Multiple against index: 0.93
#
# Ticker: VOYA; Returns Multiple against index: 1.23
#
# Ticker: BYD; Returns Multiple against index: 1.11
#
# Ticker: FLO; Returns Multiple against index: 1.39
#
# Ticker: CNXC; Returns Multiple against index: 0.81
#
# Ticker: M; Returns Multiple against index: 1.03
#
# Ticker: ELAN; Returns Multiple against index: 0.52
#
# Ticker: X; Returns Multiple against index: 1.41
#
# Ticker: QDEL; Returns Multiple against index: 0.78
#
# Ticker: LSTR; Returns Multiple against index: 1.22
#
# Ticker: LFUS; Returns Multiple against index: 0.93
#
# Ticker: ASH; Returns Multiple against index: 1.3
#
# Ticker: CACC; Returns Multiple against index: 0.85
#
# Ticker: AMG; Returns Multiple against index: 1.12
#
# Ticker: SNV; Returns Multiple against index: 1.01
#
# Ticker: CR; Returns Multiple against index: 1.21
#
# Ticker: AYI; Returns Multiple against index: 1.08
#
# Ticker: SAIC; Returns Multiple against index: 1.67
#
# Ticker: SON; Returns Multiple against index: 1.26
#
# Ticker: PPC; Returns Multiple against index: 1.08
#
# Ticker: ALK; Returns Multiple against index: 1.09
#
# Ticker: AN; Returns Multiple against index: 1.21
#
# Ticker: DNB; Returns Multiple against index: 0.87
#
# Ticker: OSK; Returns Multiple against index: 0.96
#
# Ticker: NFG; Returns Multiple against index: 1.24
#
# Ticker: ALGM; Returns Multiple against index: 1.11
#
# Ticker: NYT; Returns Multiple against index: 0.9
#
# Ticker: AXTA; Returns Multiple against index: 0.99
#
# Ticker: SLGN; Returns Multiple against index: 1.58
#
# Ticker: MP; Returns Multiple against index: 0.83
#
# Ticker: DTM; Returns Multiple against index: 1.53
#
# Ticker: FCN; Returns Multiple against index: 1.36
#
# Ticker: LUMN; Returns Multiple against index: 0.58
#
# Ticker: SKX; Returns Multiple against index: 1.12
#
# Ticker: SITE; Returns Multiple against index: 0.6
#
# Ticker: EHC; Returns Multiple against index: 1.42
#
# Ticker: AGNC; Returns Multiple against index: 0.84
#
# Ticker: WWD; Returns Multiple against index: 1.05
#
# Ticker: NVST; Returns Multiple against index: 0.95
#
# Ticker: CCCS; Returns Multiple against index: 0.85
#
# Ticker: VVV; Returns Multiple against index: 1.14
#
# Ticker: SRC; Returns Multiple against index: 1.11
#
# Ticker: VAC; Returns Multiple against index: 1.05
#
# Ticker: IONS; Returns Multiple against index: 1.43
#
# Ticker: HTZ; Returns Multiple against index: 0.74
#
# Ticker: AIRC; Returns Multiple against index: 0.86
#
# Ticker: COLM; Returns Multiple against index: 1.05
#
# Ticker: FAF; Returns Multiple against index: 0.84
#
# Ticker: WU; Returns Multiple against index: 1.0
#
# Ticker: BWXT; Returns Multiple against index: 1.55
#
# Ticker: BEPC; Returns Multiple against index: 1.11
#
# Ticker: OZK; Returns Multiple against index: 1.15
#
# Ticker: MSA; Returns Multiple against index: 1.13
#
# Ticker: MKSI; Returns Multiple against index: 0.6
#
# Ticker: PENN; Returns Multiple against index: 0.78
#
# Ticker: WTFC; Returns Multiple against index: 1.19
#
# Ticker: IDA; Returns Multiple against index: 1.23
#
# Ticker: POST; Returns Multiple against index: 1.69
#
# Ticker: GXO; Returns Multiple against index: 0.58
#
# Ticker: EXEL; Returns Multiple against index: 1.2
#
# Ticker: TPX; Returns Multiple against index: 0.85
#
# Ticker: TOL; Returns Multiple against index: 0.78
#
# Ticker: UNVR; Returns Multiple against index: 1.42
#
# Ticker: PRI; Returns Multiple against index: 1.16
#
# Ticker: NATI; Returns Multiple against index: 1.12
#
# Ticker: ESTC; Returns Multiple against index: 0.49
#
# Ticker: TKR; Returns Multiple against index: 1.25
#
# Ticker: SWCH; Returns Multiple against index: 1.58
#
# Ticker: BC; Returns Multiple against index: 0.9
#
# Ticker: GH; Returns Multiple against index: 0.62
#
# Ticker: VRT; Returns Multiple against index: 0.63
#
# Ticker: OLED; Returns Multiple against index: 0.87
#
# Ticker: NWL; Returns Multiple against index: 0.71
#
# Ticker: HUN; Returns Multiple against index: 1.07
#
# Ticker: OSH; Returns Multiple against index: 0.78
#
# Ticker: MRTX; Returns Multiple against index: 0.61
#
# Ticker: RYN; Returns Multiple against index: 1.09
#
# Ticker: GPS; Returns Multiple against index: 1.07
#
# Ticker: PYCR; Returns Multiple against index: 0.97
#
# Ticker: WIX; Returns Multiple against index: 0.62
#
# Ticker: TOST; Returns Multiple against index: 0.5
#
# Ticker: BPOP; Returns Multiple against index: 1.04
#
# Ticker: THG; Returns Multiple against index: 1.35
#
# Ticker: COHR; Returns Multiple against index: 0.63
#
# Ticker: HXL; Returns Multiple against index: 1.34
#
# Ticker: DRVN; Returns Multiple against index: 1.1
#
# Ticker: SGFY; Returns Multiple against index: 2.35
#
# Ticker: TREX; Returns Multiple against index: 0.38
#
# Ticker: BLD; Returns Multiple against index: 0.66
#
# Ticker: EXP; Returns Multiple against index: 0.99
#
# Ticker: IAA; Returns Multiple against index: 0.91
#
# Ticker: KRC; Returns Multiple against index: 0.71
#
# Ticker: GWRE; Returns Multiple against index: 0.58
#
# Ticker: FNB; Returns Multiple against index: 1.34
#
# Ticker: THC; Returns Multiple against index: 0.7
#
# Ticker: COUP; Returns Multiple against index: 0.43
#
# Ticker: SRCL; Returns Multiple against index: 1.06
#
# Ticker: OWL; Returns Multiple against index: 0.86
#
# Ticker: H; Returns Multiple against index: 1.37
#
# Ticker: WEN; Returns Multiple against index: 1.29
#
# Ticker: AXS; Returns Multiple against index: 1.37
#
# Ticker: OMF; Returns Multiple against index: 0.97
#
# Ticker: PVH; Returns Multiple against index: 0.83
#
# Ticker: ESI; Returns Multiple against index: 1.01
#
# Ticker: FIVN; Returns Multiple against index: 0.55
#
# Ticker: VNO; Returns Multiple against index: 0.66
#
# Ticker: LEG; Returns Multiple against index: 1.04
#
# Ticker: CC; Returns Multiple against index: 1.2
#
# Ticker: IART; Returns Multiple against index: 1.01
#
# Ticker: SEB; Returns Multiple against index: 1.27
#
# Ticker: TDOC; Returns Multiple against index: 0.31
#
# Ticker: EEFT; Returns Multiple against index: 0.92
#
# Ticker: THO; Returns Multiple against index: 1.0
#
# Ticker: AZTA; Returns Multiple against index: 0.65
#
# Ticker: LPX; Returns Multiple against index: 1.04
#
# Ticker: RYAN; Returns Multiple against index: 1.26
#
# Ticker: R; Returns Multiple against index: 1.31
#
# Ticker: DLB; Returns Multiple against index: 1.02
#
# Ticker: IPGP; Returns Multiple against index: 0.63
#
# Ticker: DV; Returns Multiple against index: 0.94
#
# Ticker: EVR; Returns Multiple against index: 0.98
#
# Ticker: HE; Returns Multiple against index: 1.26
#
# Ticker: MAN; Returns Multiple against index: 1.15
#
# Ticker: SOFI; Returns Multiple against index: 0.31
#
# Ticker: IAC; Returns Multiple against index: 0.44
#
# Ticker: UMPQ; Returns Multiple against index: 1.2
#
# Ticker: AMC; Returns Multiple against index: 0.25
#
# Ticker: SLM; Returns Multiple against index: 1.11
#
# Ticker: PRGO; Returns Multiple against index: 1.05
#
# Ticker: BFAM; Returns Multiple against index: 0.65
#
# Ticker: XPO; Returns Multiple against index: 0.93
#
# Ticker: AL; Returns Multiple against index: 1.06
#
# Ticker: RITM; Returns Multiple against index: 1.05
#
# Ticker: NYCB; Returns Multiple against index: 0.91
#
# Ticker: JHG; Returns Multiple against index: 0.78
#
# Ticker: SMAR; Returns Multiple against index: 0.57
#
# Ticker: CABO; Returns Multiple against index: 0.48
#
# Ticker: APP; Returns Multiple against index: 0.14
#
# Ticker: AVT; Returns Multiple against index: 1.38
#
# Ticker: LAZ; Returns Multiple against index: 0.99
#
# Ticker: ALSN; Returns Multiple against index: 1.5
#
# Ticker: CHPT; Returns Multiple against index: 0.63
#
# Ticker: CRUS; Returns Multiple against index: 1.0
#
# Ticker: KEX; Returns Multiple against index: 1.43
#
# Ticker: INFA; Returns Multiple against index: 0.53
#
# Ticker: FLS; Returns Multiple against index: 1.2
#
# Ticker: MSM; Returns Multiple against index: 1.27
#
# Ticker: NTRA; Returns Multiple against index: 0.49
#
# Ticker: MTG; Returns Multiple against index: 1.1
#
# Ticker: YETI; Returns Multiple against index: 0.56
#
# Ticker: NEWR; Returns Multiple against index: 0.62
#
# Ticker: PINC; Returns Multiple against index: 1.08
#
# Ticker: AGO; Returns Multiple against index: 1.64
#
# Ticker: DOCS; Returns Multiple against index: 0.66
#
# Ticker: LYFT; Returns Multiple against index: 0.3
#
# Ticker: TFSL; Returns Multiple against index: 0.99
#
# Ticker: CUZ; Returns Multiple against index: 0.78
#
# Ticker: SAM; Returns Multiple against index: 0.87
#
# Ticker: OLPX; Returns Multiple against index: 0.27
#
# Ticker: ICUI; Returns Multiple against index: 0.81
#
# Ticker: UA; Returns Multiple against index: 0.49
#
# Ticker: UAA; Returns Multiple against index: 0.48
#
# Ticker: BHF; Returns Multiple against index: 1.27
#
# Ticker: OLLI; Returns Multiple against index: 1.37
#
# Ticker: TXG; Returns Multiple against index: 0.28
#
# Ticker: HHC; Returns Multiple against index: 0.94
#
# Ticker: KSS; Returns Multiple against index: 0.71
#
# Ticker: LITE; Returns Multiple against index: 0.68
#
# Ticker: SYNH; Returns Multiple against index: 0.41
#
# Ticker: PTON; Returns Multiple against index: 0.33
#
# Ticker: NSA; Returns Multiple against index: 0.75
#
# Ticker: KMPR; Returns Multiple against index: 1.26
#
# Ticker: LOPE; Returns Multiple against index: 1.7
#
# Ticker: TDC; Returns Multiple against index: 0.93
#
# Ticker: WTM; Returns Multiple against index: 1.57
#
# Ticker: VSCO; Returns Multiple against index: 0.97
#
# Ticker: CFLT; Returns Multiple against index: 0.37
#
# Ticker: AWI; Returns Multiple against index: 0.75
#
# Ticker: CNM; Returns Multiple against index: 0.9
#
# Ticker: PLTK; Returns Multiple against index: 0.54
#
# Ticker: WWE; Returns Multiple against index: 1.91
#
# Ticker: TECH; Returns Multiple against index: 0.82
#
# Ticker: W; Returns Multiple against index: 0.19
#
# Ticker: FHB; Returns Multiple against index: 1.13
#
# Ticker: RNG; Returns Multiple against index: 0.2
#
# Ticker: AFRM; Returns Multiple against index: 0.11
#
# Ticker: GTES; Returns Multiple against index: 0.82
#
# Ticker: SSRM; Returns Multiple against index: 1.06
#
# Ticker: NCR; Returns Multiple against index: 0.63
#
# Ticker: BOH; Returns Multiple against index: 1.18
#
# Ticker: MSGS; Returns Multiple against index: 1.19
#
# Ticker: TNL; Returns Multiple against index: 0.87
#
# Ticker: JWN; Returns Multiple against index: 1.08
#
# Ticker: NEU; Returns Multiple against index: 1.17
#
# Ticker: MCW; Returns Multiple against index: 0.61
#
# Ticker: FRPT; Returns Multiple against index: 0.66
#
# Ticker: EPR; Returns Multiple against index: 1.1
#
# Ticker: S; Returns Multiple against index: 0.35
#
# Ticker: HIW; Returns Multiple against index: 0.8
#
# Ticker: PEGA; Returns Multiple against index: 0.37
#
# Ticker: SMG; Returns Multiple against index: 0.44
#
# Ticker: ENOV; Returns Multiple against index: 0.83
#
# Ticker: VNT; Returns Multiple against index: 0.73
#
# Ticker: NCNO; Returns Multiple against index: 0.52
#
# Ticker: AZEK; Returns Multiple against index: 0.55
#
# Ticker: PACW; Returns Multiple against index: 0.66
#
# Ticker: DEI; Returns Multiple against index: 0.56
#
# Ticker: MRCY; Returns Multiple against index: 1.28
#
# Ticker: GO; Returns Multiple against index: 1.3
#
# Ticker: AMED; Returns Multiple against index: 0.67
#
# Ticker: PK; Returns Multiple against index: 0.77
#
# Ticker: TWKS; Returns Multiple against index: 0.38
#
# Ticker: ESAB; Returns Multiple against index: nan
#
# Ticker: AYX; Returns Multiple against index: 0.73
#
# Ticker: SPR; Returns Multiple against index: 0.78
#
# Ticker: CRI; Returns Multiple against index: 0.84
#
# Ticker: CERT; Returns Multiple against index: 0.74
#
# Ticker: TNDM; Returns Multiple against index: 0.35
#
# Ticker: AMBP; Returns Multiple against index: 0.63
#
# Ticker: CPA; Returns Multiple against index: 1.35
#
# Ticker: SLG; Returns Multiple against index: 0.61
#
# Ticker: KD; Returns Multiple against index: 0.73
#
# Ticker: QS; Returns Multiple against index: 0.32
#
# Ticker: RARE; Returns Multiple against index: 0.59
#
# Ticker: FOUR; Returns Multiple against index: 0.94
#
# Ticker: TRIP; Returns Multiple against index: 0.85
#
# Ticker: JAMF; Returns Multiple against index: 0.8
#
# Ticker: VSAT; Returns Multiple against index: 0.8
#
# Ticker: LESL; Returns Multiple against index: 0.71
#
# Ticker: JBLU; Returns Multiple against index: 0.67
#
# Ticker: WOOF; Returns Multiple against index: 0.59
#
# Ticker: SHC; Returns Multiple against index: 0.45
#
# Ticker: SNDR; Returns Multiple against index: 1.23
#
# Ticker: HBI; Returns Multiple against index: 0.46
#
# Ticker: JBGS; Returns Multiple against index: 0.86
#
# Ticker: VIRT; Returns Multiple against index: 1.0
#
# Ticker: DNA; Returns Multiple against index: 0.2
#
# Ticker: SPB; Returns Multiple against index: 0.76
#
# Ticker: HAYW; Returns Multiple against index: 0.43
#
# Ticker: WE; Returns Multiple against index: 0.33
#
# Ticker: SIX; Returns Multiple against index: 0.68
#
# Ticker: MRVI; Returns Multiple against index: 0.35
#
# Ticker: ATUS; Returns Multiple against index: 0.29
#
# Ticker: COMM; Returns Multiple against index: 0.87
#
# Ticker: HPP; Returns Multiple against index: 0.49
#
# Ticker: UPST; Returns Multiple against index: 0.11
#
# Ticker: NVAX; Returns Multiple against index: 0.11
#
# Ticker: UHALB; Returns Multiple against index: nan
#
# Ticker: UHAL; Returns Multiple against index: 1.08
#
# Ticker: DH; Returns Multiple against index: 0.44
#
# Ticker: OPEN; Returns Multiple against index: 0.11
#
# Ticker: CVNA; Returns Multiple against index: 0.03
#
# Ticker: TAP; Returns Multiple against index: 1.44
#
# Ticker: EHAB; Returns Multiple against index: nan
#
# Ticker: UWMC; Returns Multiple against index: 0.9

# %%
# Creating dataframe of only top 40%
tickers["Returns_multiple"] =  returns_multiples
tickers["RS_Rating"] = tickers.groupby("sector").Returns_multiple.rank(pct=True) * 100
rs_df = tickers[tickers.RS_Rating >= tickers.RS_Rating.quantile(.60)].sort_values('RS_Rating',ascending=False)

# %%
# Checking Minervini conditions of top 40% of stocks in given list
exportList = pd.DataFrame(columns=['Stock', "Sector", "RS_Rating", "returns multiple", "Last Price","%change","50 Day MA", "150 Day Ma", "200 Day MA", "52 Week Low", "52 week High", "% from 52 week high"])

for i in range(len(rs_df)):
    stock = rs_df["ticker"].iloc[i]
    ret_mult = rs_df["Returns_multiple"].iloc[i]
    sector = rs_df.index[i]
    try:
        df = pd.read_csv(os.path.join(os.getcwd(),'us_stocks',f'{stock}.csv'), index_col=0) 
        sma = [50, 150, 200]
        for x in sma:
            df["SMA_"+str(x)] = round(df['Adj Close'].rolling(window=x).mean(), 2)
        
        # Storing required values 
        currentClose = df["Adj Close"][-1]
        prevClose =  df["Adj Close"][-2]
        pct_chg   = (currentClose - prevClose ) * 100/ prevClose
        moving_average_50 = df["SMA_50"][-1]
        moving_average_150 = df["SMA_150"][-1]
        moving_average_200 = df["SMA_200"][-1]
        low_of_52week = round(min(df["Low"]), 2)
        high_of_52week = round(max(df["High"]), 2)
        pct_from_52wkhigh = (high_of_52week - currentClose)/high_of_52week * 100
        RS_Rating = round(rs_df[rs_df['ticker']==stock].RS_Rating.tolist()[0])
        
        try:
            moving_average_200_20 = df["SMA_200"][-20]
        except Exception:
            moving_average_200_20 = 0

        # Condition 1: Current Price > 150 SMA and > 200 SMA
        condition_1 = currentClose > moving_average_150 > moving_average_200
        
        # Condition 2: 150 SMA and > 200 SMA
        condition_2 = moving_average_150 > moving_average_200

        # Condition 3: 200 SMA trending up for at least 1 month
        condition_3 = moving_average_200 > moving_average_200_20
        
        # Condition 4: 50 SMA> 150 SMA and 50 SMA> 200 SMA
        condition_4 = moving_average_50 > moving_average_150 > moving_average_200
           
        # Condition 5: Current Price > 50 SMA
        condition_5 = currentClose > moving_average_50
           
        # Condition 6: Current Price is at least 30% above 52 week low
        condition_6 = currentClose >= (1.3*low_of_52week)
           
        # Condition 7: Current Price is within 30% of 52 week high
        condition_7 = currentClose >= (.7*high_of_52week)

        # Condition 8: Daily change is positive 
        #
        
        # If all conditions above are true, add stock to exportList
        if(condition_1 and condition_2 and condition_3 and condition_4 and condition_5 and condition_6 and condition_7):
            exportEntry = pd.DataFrame({'Stock': stock, "Sector" : sector, "RS_Rating": RS_Rating , "returns multiple" : ret_mult, "Last Price" : round(currentClose,3), "%change" : round(pct_chg,2), "50 Day MA": moving_average_50, "150 Day Ma" : moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week, "% from 52 week high" : round(pct_from_52wkhigh,2)},index=[0])
            exportList = pd.concat([exportList,exportEntry], ignore_index=True)
            print (stock + " made the Minervini requirements")
    except Exception as e:
        print (e)
        print(f"Could not gather data on {stock}")

exportList = exportList.sort_values(by='RS_Rating', ascending=False)
print('\n', exportList)
writer = ExcelWriter(os.path.join(os.getcwd(),"output_screener_us_long_position.xlsx"))
exportList.to_excel(writer, "Sheet1",index=False)
writer.save()
# Out:
# WWE made the Minervini requirements
# NOC made the Minervini requirements
# LW made the Minervini requirements
# FSLR made the Minervini requirements
# STLD made the Minervini requirements
# HRB made the Minervini requirements
# FICO made the Minervini requirements
# FHN made the Minervini requirements
# CAH made the Minervini requirements
# SAIC made the Minervini requirements
# ERIE made the Minervini requirements
# GPC made the Minervini requirements
# MCK made the Minervini requirements
# ENPH made the Minervini requirements
# TMUS made the Minervini requirements
# RGA made the Minervini requirements
# PAG made the Minervini requirements
# SWCH made the Minervini requirements
# CI made the Minervini requirements
# HII made the Minervini requirements
# WRB made the Minervini requirements
# TPL made the Minervini requirements
# PWR made the Minervini requirements
# MRK made the Minervini requirements
# PGR made the Minervini requirements
# AZO made the Minervini requirements
# POST made the Minervini requirements
# LLY made the Minervini requirements
# ACGL made the Minervini requirements
# VMI made the Minervini requirements
# BAH made the Minervini requirements
# BWXT made the Minervini requirements
# ORLY made the Minervini requirements
# VRTX made the Minervini requirements
# RS made the Minervini requirements
# GIS made the Minervini requirements
# JBL made the Minervini requirements
# GL made the Minervini requirements
# ALSN made the Minervini requirements
# ADP made the Minervini requirements
# BMY made the Minervini requirements
# UTHR made the Minervini requirements
# ACHC made the Minervini requirements
# NBIX made the Minervini requirements
# PFG made the Minervini requirements
# ON made the Minervini requirements
# ULTA made the Minervini requirements
# ADT made the Minervini requirements
# MSI made the Minervini requirements
# PCAR made the Minervini requirements
# ROL made the Minervini requirements
# HUBB made the Minervini requirements
# SLGN made the Minervini requirements
# PCG made the Minervini requirements
# SRPT made the Minervini requirements
# TJX made the Minervini requirements
# AMGN made the Minervini requirements
# GILD made the Minervini requirements
# AJG made the Minervini requirements
# GWW made the Minervini requirements
# CASY made the Minervini requirements
# HUM made the Minervini requirements
# WSC made the Minervini requirements
# ALNY made the Minervini requirements
# BIIB made the Minervini requirements
# AES made the Minervini requirements
# CMI made the Minervini requirements
# CLH made the Minervini requirements
# APD made the Minervini requirements
# BMRN made the Minervini requirements
# TTC made the Minervini requirements
# R made the Minervini requirements
# DECK made the Minervini requirements
# HES made the Minervini requirements
# ASH made the Minervini requirements
# RPM made the Minervini requirements
# NVT made the Minervini requirements
# IBKR made the Minervini requirements
# SBUX made the Minervini requirements
# APA made the Minervini requirements
# KEYS made the Minervini requirements
# TKR made the Minervini requirements
# SLB made the Minervini requirements
# MNST made the Minervini requirements
# CSGP made the Minervini requirements
# CTAS made the Minervini requirements
# NDAQ made the Minervini requirements
# IEX made the Minervini requirements
#
#     Stock                  Sector RS_Rating  returns multiple  Last Price  \
# 0    WWE  Communication Services       100              1.91       77.85
# 2     LW        Consumer Staples       100              1.86       86.29
# 3   FSLR  Information Technology       100              1.89      157.47
# 4   STLD               Materials       100              2.18      108.27
# 5    HRB  Consumer Discretionary       100              2.14       41.52
# ..   ...                     ...       ...               ...         ...
# 83  MNST        Consumer Staples        68              1.38      101.44
# 84  CSGP             Industrials        67              1.24       80.96
# 85  CTAS             Industrials        64              1.23      452.62
# 86  NDAQ              Financials        63              1.19       67.01
# 87   IEX             Industrials        62              1.21      233.78
#
#     %change  50 Day MA  150 Day Ma  200 Day MA  52 Week Low  52 week High  \
# 0     -1.21      76.23       69.18       66.79        46.91         81.63
# 2     -1.59      83.49       76.52       72.57        49.71         88.63
# 3     -5.79     144.84      108.62      100.53        59.60        173.68
# 4      1.43      91.49       80.92       80.74        50.54        109.63
# 5     -1.73      40.92       38.99       35.61        21.08         48.76
# ..      ...        ...         ...         ...          ...           ...
# 83    -0.71      94.70       92.17       89.46        71.78        104.65
# 84    -1.00      77.34       69.22       67.51        49.00         85.37
# 85    -1.48     421.31      403.38      401.81       343.86        463.72
# 86    -1.25      61.76       57.31       57.24        46.77         70.55
# 87    -1.30     218.59      202.72      199.78       172.19        243.51
#
#     % from 52 week high
# 0                  4.63
# 2                  2.64
# 3                  9.33
# 4                  1.24
# 5                 14.85
# ..                  ...
# 83                 3.07
# 84                 5.17
# 85                 2.39
# 86                 5.02
# 87                 4.00
#
# [88 rows x 12 columns]
# /tmp/ipykernel_3801/2175041067.py:68: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()

# %%
exportList
# Out:
#    Stock                  Sector RS_Rating  returns multiple  Last Price  \
# 0    WWE  Communication Services       100              1.91       77.85
# 2     LW        Consumer Staples       100              1.86       86.29
# 3   FSLR  Information Technology       100              1.89      157.47
# 4   STLD               Materials       100              2.18      108.27
# 5    HRB  Consumer Discretionary       100              2.14       41.52
# ..   ...                     ...       ...               ...         ...
# 83  MNST        Consumer Staples        68              1.38      101.44
# 84  CSGP             Industrials        67              1.24       80.96
# 85  CTAS             Industrials        64              1.23      452.62
# 86  NDAQ              Financials        63              1.19       67.01
# 87   IEX             Industrials        62              1.21      233.78
#
#     %change  50 Day MA  150 Day Ma  200 Day MA  52 Week Low  52 week High  \
# 0     -1.21      76.23       69.18       66.79        46.91         81.63
# 2     -1.59      83.49       76.52       72.57        49.71         88.63
# 3     -5.79     144.84      108.62      100.53        59.60        173.68
# 4      1.43      91.49       80.92       80.74        50.54        109.63
# 5     -1.73      40.92       38.99       35.61        21.08         48.76
# ..      ...        ...         ...         ...          ...           ...
# 83    -0.71      94.70       92.17       89.46        71.78        104.65
# 84    -1.00      77.34       69.22       67.51        49.00         85.37
# 85    -1.48     421.31      403.38      401.81       343.86        463.72
# 86    -1.25      61.76       57.31       57.24        46.77         70.55
# 87    -1.30     218.59      202.72      199.78       172.19        243.51
#
#     % from 52 week high
# 0                  4.63
# 2                  2.64
# 3                  9.33
# 4                  1.24
# 5                 14.85
# ..                  ...
# 83                 3.07
# 84                 5.17
# 85                 2.39
# 86                 5.02
# 87                 4.00
#
# [88 rows x 12 columns]
