# %%
### Needed for google colab runtime
# import sys
# !{sys.executable} -m pip install pandas_datareader yfinance yahoo_fin pandas numpy openpyxl --upgrade --no-cache-dir

# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os, os.path
import errno
from pandas_datareader import data as pdr
from yahoo_fin import stock_info as si
import asyncio
from pandas import ExcelWriter
import yfinance as yf
import pandas as pd
import numpy as np
import multiprocessing
import datetime
import time
yf.pdr_override()

# %%
#create directory if non-existent
def mkdir_p(path):
    try:
        os.makedirs(path)
    except OSError as exc: # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else: raise
mkdir_p('us_stocks')

# %%
### Variables
tickers = pd.DataFrame()
#stock list downloaded from https://stockmarketmba.com/stocksintherussell1000.php
tickers = pd.read_excel("Russell1000list.xlsx",sheet_name=0,header=None,usecols = "A,E",skiprows = 2,names = ["ticker","sector"])
tickers["ticker"] = [item.replace(".", "-") for item in tickers["ticker"]] # Yahoo Finance uses dashes instead of dots
tickers = tickers.set_index("sector")

#combine into one string needed to download multiple files using yfinance module
tickers_string = ""
for i in tickers["ticker"]:
    tickers_string += i + " "

index_name = '^RUI' # Russell 1000
start_date = datetime.datetime.now() - datetime.timedelta(days=365)
end_date = datetime.date.today()

# %%
###===== OPTIONAL: if the file screener_yyfinance.ipynb has already been run =====###

###  Download ticker data from yahoo finance simultaneously
# results = yf.download(tickers = tickers_string,start = start_date, end = end_date, interval= '1d',threads = True,group_by="ticker")

### write to file
# for ticker in tickers["ticker"]:
    # df = results[ticker].reset_index()
    # df.to_csv( os.path.join(os.getcwd(),'us_stocks',ticker+'.csv'), index = False, header=True )

# %%
# Index Returns
index_df = pdr.get_data_yahoo(index_name, start_date, end_date)
index_return = index_df['Adj Close'].iloc[-1] / index_df['Adj Close'].iloc[0]       # not efficient: (index_df['Percent Change'] + 1).cumprod()[-1]

# Import historical data as CSV for all stocks (makes the process faster)
df_list = pd.concat(( map(pd.read_csv, [os.path.join(os.getcwd(),'us_stocks',s+'.csv') for s in tickers["ticker"] ])), keys=tickers["ticker"] )

# Find top 30% performing stocks (relative to the index)
returns_multiples = []
for ticker in tickers["ticker"]:
    # Calculating returns relative to the market (returns multiple)
    df = df_list.loc[ticker].copy()
    stock_return = df['Adj Close'].iloc[-1] / df['Adj Close'].iloc[0]   # not efficient: ((df['Percent Change'] + 1).cumprod()).iloc[-1]
    
    returns_multiple = round((stock_return / index_return), 2)
    returns_multiples.extend([returns_multiple])
    
    print (f'Ticker: {ticker}; Returns Multiple against index: {returns_multiple}\n')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker: AAPL; Returns Multiple against index: 1.19
#
# Ticker: MSFT; Returns Multiple against index: 1.01
#
# Ticker: AMZN; Returns Multiple against index: 0.86
#
# Ticker: TSLA; Returns Multiple against index: 1.36
#
# Ticker: BRK-B; Returns Multiple against index: 1.15
#
# Ticker: FB; Returns Multiple against index: nan
#
# Ticker: UNH; Returns Multiple against index: 1.47
#
# Ticker: META; Returns Multiple against index: 0.5
#
# Ticker: NVDA; Returns Multiple against index: 0.72
#
# Ticker: V; Returns Multiple against index: 1.03
#
# Ticker: JNJ; Returns Multiple against index: 1.14
#
# Ticker: XOM; Returns Multiple against index: 2.09
#
# Ticker: PG; Returns Multiple against index: 1.11
#
# Ticker: WMT; Returns Multiple against index: 1.06
#
# Ticker: MA; Returns Multiple against index: 1.09
#
# Ticker: JPM; Returns Multiple against index: 0.87
#
# Ticker: HD; Returns Multiple against index: 1.03
#
# Ticker: CVX; Returns Multiple against index: 1.93
#
# Ticker: LLY; Returns Multiple against index: 1.5
#
# Ticker: PFE; Returns Multiple against index: 1.21
#
# Ticker: KO; Returns Multiple against index: 1.29
#
# Ticker: BAC; Returns Multiple against index: 0.99
#
# Ticker: ABBV; Returns Multiple against index: 1.54
#
# Ticker: PEP; Returns Multiple against index: 1.28
#
# Ticker: COST; Returns Multiple against index: 1.3
#
# Ticker: TMO; Returns Multiple against index: 1.11
#
# Ticker: AVGO; Returns Multiple against index: 1.21
#
# Ticker: MRK; Returns Multiple against index: 1.38
#
# Ticker: DHR; Returns Multiple against index: 0.99
#
# Ticker: ACN; Returns Multiple against index: 0.96
#
# Ticker: ORCL; Returns Multiple against index: 0.96
#
# Ticker: ADBE; Returns Multiple against index: 0.67
#
# Ticker: DIS; Returns Multiple against index: 0.7
#
# Ticker: MCD; Returns Multiple against index: 1.24
#
# Ticker: ABT; Returns Multiple against index: 0.96
#
# Ticker: CRM; Returns Multiple against index: 0.71
#
# Ticker: CSCO; Returns Multiple against index: 0.91
#
# Ticker: VZ; Returns Multiple against index: 0.91
#
# Ticker: TMUS; Returns Multiple against index: 1.24
#
# Ticker: NKE; Returns Multiple against index: 0.76
#
# Ticker: NEE; Returns Multiple against index: 1.21
#
# Ticker: CMCSA; Returns Multiple against index: 0.68
#
# Ticker: QCOM; Returns Multiple against index: 1.05
#
# Ticker: TXN; Returns Multiple against index: 1.03
#
# Ticker: UPS; Returns Multiple against index: 1.18
#
# Ticker: AMD; Returns Multiple against index: 0.91
#
# Ticker: WFC; Returns Multiple against index: 1.17
#
# Ticker: BMY; Returns Multiple against index: 1.28
#
# Ticker: PM; Returns Multiple against index: 1.1
#
# Ticker: LIN; Returns Multiple against index: 1.05
#
# Ticker: MS; Returns Multiple against index: 1.0
#
# Ticker: INTC; Returns Multiple against index: 0.67
#
# Ticker: UNP; Returns Multiple against index: 1.27
#
# Ticker: RTX; Returns Multiple against index: 1.21
#
# Ticker: CVS; Returns Multiple against index: 1.39
#
# Ticker: AMGN; Returns Multiple against index: 1.34
#
# Ticker: T; Returns Multiple against index: 1.0
#
# Ticker: SCHW; Returns Multiple against index: 1.18
#
# Ticker: HON; Returns Multiple against index: 0.98
#
# Ticker: INTU; Returns Multiple against index: 0.89
#
# Ticker: AMT; Returns Multiple against index: 1.02
#
# Ticker: SPGI; Returns Multiple against index: 0.92
#
# Ticker: LOW; Returns Multiple against index: 1.14
#
# Ticker: MDT; Returns Multiple against index: 0.78
#
# Ticker: IBM; Returns Multiple against index: 1.16
#
# Ticker: AXP; Returns Multiple against index: 1.13
#
# Ticker: ANTM; Returns Multiple against index: nan
#
# Ticker: COP; Returns Multiple against index: 2.32
#
# Ticker: GS; Returns Multiple against index: 0.97
#
# Ticker: ELV; Returns Multiple against index: 1.56
#
# Ticker: LMT; Returns Multiple against index: 1.4
#
# Ticker: PYPL; Returns Multiple against index: 0.38
#
# Ticker: BLK; Returns Multiple against index: 0.87
#
# Ticker: DE; Returns Multiple against index: 1.16
#
# Ticker: NFLX; Returns Multiple against index: 0.44
#
# Ticker: C; Returns Multiple against index: 0.84
#
# Ticker: ADP; Returns Multiple against index: 1.38
#
# Ticker: SBUX; Returns Multiple against index: 0.85
#
# Ticker: NOW; Returns Multiple against index: 0.81
#
# Ticker: BA; Returns Multiple against index: 0.84
#
# Ticker: EL; Returns Multiple against index: 0.85
#
# Ticker: CAT; Returns Multiple against index: 1.06
#
# Ticker: PLD; Returns Multiple against index: 1.11
#
# Ticker: AMAT; Returns Multiple against index: 0.79
#
# Ticker: ADI; Returns Multiple against index: 1.03
#
# Ticker: CI; Returns Multiple against index: 1.63
#
# Ticker: MDLZ; Returns Multiple against index: 1.16
#
# Ticker: ISRG; Returns Multiple against index: 0.72
#
# Ticker: DUK; Returns Multiple against index: 1.23
#
# Ticker: MMM; Returns Multiple against index: 0.77
#
# Ticker: MMC; Returns Multiple against index: 1.18
#
# Ticker: SO; Returns Multiple against index: 1.39
#
# Ticker: ZTS; Returns Multiple against index: 0.89
#
# Ticker: SYK; Returns Multiple against index: 0.95
#
# Ticker: GE; Returns Multiple against index: 0.81
#
# Ticker: GOOG; Returns Multiple against index: 0.88
#
# Ticker: GOOGL; Returns Multiple against index: 0.88
#
# Ticker: MO; Returns Multiple against index: 1.08
#
# Ticker: GILD; Returns Multiple against index: 1.07
#
# Ticker: BKNG; Returns Multiple against index: 0.96
#
# Ticker: CB; Returns Multiple against index: 1.23
#
# Ticker: MRNA; Returns Multiple against index: 0.35
#
# Ticker: TGT; Returns Multiple against index: 0.81
#
# Ticker: CCI; Returns Multiple against index: 1.07
#
# Ticker: TJX; Returns Multiple against index: 1.1
#
# Ticker: NOC; Returns Multiple against index: 1.57
#
# Ticker: CHTR; Returns Multiple against index: 0.58
#
# Ticker: LRCX; Returns Multiple against index: 0.85
#
# Ticker: BX; Returns Multiple against index: 0.9
#
# Ticker: BDX; Returns Multiple against index: 1.18
#
# Ticker: CME; Returns Multiple against index: 1.23
#
# Ticker: ABNB; Returns Multiple against index: 0.83
#
# Ticker: MU; Returns Multiple against index: 0.88
#
# Ticker: CSX; Returns Multiple against index: 1.19
#
# Ticker: VRTX; Returns Multiple against index: 1.73
#
# Ticker: USB; Returns Multiple against index: 0.99
#
# Ticker: WM; Returns Multiple against index: 1.27
#
# Ticker: PGR; Returns Multiple against index: 1.57
#
# Ticker: FISV; Returns Multiple against index: 1.07
#
# Ticker: CL; Returns Multiple against index: 1.16
#
# Ticker: PNC; Returns Multiple against index: 0.99
#
# Ticker: D; Returns Multiple against index: 1.24
#
# Ticker: REGN; Returns Multiple against index: 1.24
#
# Ticker: TFC; Returns Multiple against index: 1.02
#
# Ticker: ITW; Returns Multiple against index: 1.08
#
# Ticker: EW; Returns Multiple against index: 0.9
#
# Ticker: NSC; Returns Multiple against index: 1.15
#
# Ticker: EQIX; Returns Multiple against index: 0.89
#
# Ticker: ATVI; Returns Multiple against index: 1.11
#
# Ticker: SHW; Returns Multiple against index: 0.9
#
# Ticker: GD; Returns Multiple against index: 1.31
#
# Ticker: FDX; Returns Multiple against index: 0.92
#
# Ticker: HCA; Returns Multiple against index: 0.96
#
# Ticker: HUM; Returns Multiple against index: 1.34
#
# Ticker: F; Returns Multiple against index: 1.39
#
# Ticker: AON; Returns Multiple against index: 1.12
#
# Ticker: ICE; Returns Multiple against index: 0.98
#
# Ticker: KLAC; Returns Multiple against index: 1.16
#
# Ticker: UBER; Returns Multiple against index: 0.89
#
# Ticker: ETN; Returns Multiple against index: 1.04
#
# Ticker: BSX; Returns Multiple against index: 1.08
#
# Ticker: FIS; Returns Multiple against index: 0.84
#
# Ticker: EOG; Returns Multiple against index: 2.2
#
# Ticker: PSA; Returns Multiple against index: 1.25
#
# Ticker: TEAM; Returns Multiple against index: 0.76
#
# Ticker: MCO; Returns Multiple against index: 0.88
#
# Ticker: APD; Returns Multiple against index: 1.1
#
# Ticker: DG; Returns Multiple against index: 1.28
#
# Ticker: SNPS; Returns Multiple against index: 1.14
#
# Ticker: KDP; Returns Multiple against index: 1.27
#
# Ticker: CNC; Returns Multiple against index: 1.72
#
# Ticker: OXY; Returns Multiple against index: 2.95
#
# Ticker: EMR; Returns Multiple against index: 0.97
#
# Ticker: GM; Returns Multiple against index: 0.93
#
# Ticker: MET; Returns Multiple against index: 1.28
#
# Ticker: MAR; Returns Multiple against index: 1.34
#
# Ticker: PXD; Returns Multiple against index: 1.96
#
# Ticker: AEP; Returns Multiple against index: 1.36
#
# Ticker: MNST; Returns Multiple against index: 1.08
#
# Ticker: CDNS; Returns Multiple against index: 1.17
#
# Ticker: SRE; Returns Multiple against index: 1.51
#
# Ticker: PANW; Returns Multiple against index: 1.34
#
# Ticker: VMW; Returns Multiple against index: 1.14
#
# Ticker: MRVL; Returns Multiple against index: 0.91
#
# Ticker: MCK; Returns Multiple against index: 2.03
#
# Ticker: ADSK; Returns Multiple against index: 0.83
#
# Ticker: SLB; Returns Multiple against index: 1.68
#
# Ticker: ECL; Returns Multiple against index: 0.86
#
# Ticker: HSY; Returns Multiple against index: 1.47
#
# Ticker: ORLY; Returns Multiple against index: 1.36
#
# Ticker: PAYX; Returns Multiple against index: 1.32
#
# Ticker: APH; Returns Multiple against index: 1.14
#
# Ticker: ADM; Returns Multiple against index: 1.74
#
# Ticker: STZ; Returns Multiple against index: 1.31
#
# Ticker: SNOW; Returns Multiple against index: 0.66
#
# Ticker: ROP; Returns Multiple against index: 0.97
#
# Ticker: CFLT; Returns Multiple against index: 0.47
#
# Ticker: LHX; Returns Multiple against index: 1.16
#
# Ticker: KHC; Returns Multiple against index: 1.17
#
# Ticker: GIS; Returns Multiple against index: 1.5
#
# Ticker: MPC; Returns Multiple against index: 2.02
#
# Ticker: KMB; Returns Multiple against index: 1.07
#
# Ticker: RSG; Returns Multiple against index: 1.35
#
# Ticker: EXC; Returns Multiple against index: 1.48
#
# Ticker: KKR; Returns Multiple against index: 0.93
#
# Ticker: CMG; Returns Multiple against index: 1.01
#
# Ticker: SYY; Returns Multiple against index: 1.25
#
# Ticker: IQV; Returns Multiple against index: 0.96
#
# Ticker: O; Returns Multiple against index: 1.18
#
# Ticker: CTAS; Returns Multiple against index: 1.21
#
# Ticker: WBD; Returns Multiple against index: 0.56
#
# Ticker: AZO; Returns Multiple against index: 1.58
#
# Ticker: FCX; Returns Multiple against index: 1.03
#
# Ticker: VLO; Returns Multiple against index: 2.08
#
# Ticker: COF; Returns Multiple against index: 0.79
#
# Ticker: XEL; Returns Multiple against index: 1.3
#
# Ticker: AIG; Returns Multiple against index: 1.16
#
# Ticker: CRWD; Returns Multiple against index: 0.81
#
# Ticker: MCHP; Returns Multiple against index: 0.96
#
# Ticker: MSI; Returns Multiple against index: 1.17
#
# Ticker: ENPH; Returns Multiple against index: 2.16
#
# Ticker: MSCI; Returns Multiple against index: 0.85
#
# Ticker: CTVA; Returns Multiple against index: 1.63
#
# Ticker: A; Returns Multiple against index: 0.87
#
# Ticker: PSX; Returns Multiple against index: 1.55
#
# Ticker: KMI; Returns Multiple against index: 1.36
#
# Ticker: WMB; Returns Multiple against index: 1.59
#
# Ticker: LULU; Returns Multiple against index: 0.91
#
# Ticker: SQ; Returns Multiple against index: 0.33
#
# Ticker: JCI; Returns Multiple against index: 0.88
#
# Ticker: PH; Returns Multiple against index: 1.11
#
# Ticker: ANET; Returns Multiple against index: 1.58
#
# Ticker: TRV; Returns Multiple against index: 1.2
#
# Ticker: AFL; Returns Multiple against index: 1.3
#
# Ticker: SBAC; Returns Multiple against index: 1.06
#
# Ticker: EA; Returns Multiple against index: 1.0
#
# Ticker: AJG; Returns Multiple against index: 1.48
#
# Ticker: DLR; Returns Multiple against index: 0.92
#
# Ticker: WELL; Returns Multiple against index: 1.03
#
# Ticker: LNG; Returns Multiple against index: 2.07
#
# Ticker: DOW; Returns Multiple against index: 0.98
#
# Ticker: DLTR; Returns Multiple against index: 1.79
#
# Ticker: BF-B; Returns Multiple against index: 1.18
#
# Ticker: BF-A; Returns Multiple against index: 1.26
#
# Ticker: PRU; Returns Multiple against index: 1.11
#
# Ticker: HLT; Returns Multiple against index: 1.19
#
# Ticker: NEM; Returns Multiple against index: 0.88
#
# Ticker: TT; Returns Multiple against index: 0.98
#
# Ticker: SCCO; Returns Multiple against index: 0.95
#
# Ticker: NUE; Returns Multiple against index: 1.45
#
# Ticker: DVN; Returns Multiple against index: 2.94
#
# Ticker: GPN; Returns Multiple against index: 0.9
#
# Ticker: CTSH; Returns Multiple against index: 0.97
#
# Ticker: ILMN; Returns Multiple against index: 0.51
#
# Ticker: CARR; Returns Multiple against index: 0.85
#
# Ticker: DXCM; Returns Multiple against index: 0.76
#
# Ticker: RMD; Returns Multiple against index: 0.9
#
# Ticker: BK; Returns Multiple against index: 0.98
#
# Ticker: SPG; Returns Multiple against index: 0.96
#
# Ticker: TDG; Returns Multiple against index: 1.19
#
# Ticker: ED; Returns Multiple against index: 1.56
#
# Ticker: HPQ; Returns Multiple against index: 1.15
#
# Ticker: YUM; Returns Multiple against index: 1.02
#
# Ticker: IDXX; Returns Multiple against index: 0.61
#
# Ticker: WBA; Returns Multiple against index: 0.85
#
# Ticker: ODFL; Returns Multiple against index: 1.03
#
# Ticker: KR; Returns Multiple against index: 1.39
#
# Ticker: OTIS; Returns Multiple against index: 0.92
#
# Ticker: VICI; Returns Multiple against index: 1.33
#
# Ticker: WEC; Returns Multiple against index: 1.29
#
# Ticker: SGEN; Returns Multiple against index: 1.15
#
# Ticker: IFF; Returns Multiple against index: 0.89
#
# Ticker: RIVN; Returns Multiple against index: nan
#
# Ticker: PEG; Returns Multiple against index: 1.26
#
# Ticker: ZM; Returns Multiple against index: 0.31
#
# Ticker: DELL; Returns Multiple against index: 0.93
#
# Ticker: PCAR; Returns Multiple against index: 1.22
#
# Ticker: BIIB; Returns Multiple against index: 0.79
#
# Ticker: TSN; Returns Multiple against index: 1.15
#
# Ticker: MTB; Returns Multiple against index: 1.59
#
# Ticker: TWTR; Returns Multiple against index: 0.77
#
# Ticker: ES; Returns Multiple against index: 1.19
#
# Ticker: DDOG; Returns Multiple against index: 0.82
#
# Ticker: VRSK; Returns Multiple against index: 1.05
#
# Ticker: HES; Returns Multiple against index: 2.05
#
# Ticker: LCID; Returns Multiple against index: 0.85
#
# Ticker: CPRT; Returns Multiple against index: 0.91
#
# Ticker: CMI; Returns Multiple against index: 1.07
#
# Ticker: GLW; Returns Multiple against index: 1.0
#
# Ticker: ALL; Returns Multiple against index: 1.1
#
# Ticker: LSXMA; Returns Multiple against index: 1.0
#
# Ticker: LSXMK; Returns Multiple against index: 1.0
#
# Ticker: FWONK; Returns Multiple against index: 1.47
#
# Ticker: FWONA; Returns Multiple against index: 1.46
#
# Ticker: MTD; Returns Multiple against index: 0.91
#
# Ticker: KEYS; Returns Multiple against index: 1.07
#
# Ticker: PPG; Returns Multiple against index: 0.95
#
# Ticker: FAST; Returns Multiple against index: 1.09
#
# Ticker: LVS; Returns Multiple against index: 1.02
#
# Ticker: DD; Returns Multiple against index: 0.94
#
# Ticker: ON; Returns Multiple against index: 1.71
#
# Ticker: ROK; Returns Multiple against index: 0.92
#
# Ticker: ROST; Returns Multiple against index: 0.94
#
# Ticker: AMP; Returns Multiple against index: 1.22
#
# Ticker: ABC; Returns Multiple against index: 1.36
#
# Ticker: BAX; Returns Multiple against index: 0.83
#
# Ticker: CSGP; Returns Multiple against index: 0.97
#
# Ticker: AWK; Returns Multiple against index: 0.95
#
# Ticker: AME; Returns Multiple against index: 1.08
#
# Ticker: GFS; Returns Multiple against index: nan
#
# Ticker: AVB; Returns Multiple against index: 1.1
#
# Ticker: TROW; Returns Multiple against index: 0.66
#
# Ticker: EQR; Returns Multiple against index: 1.09
#
# Ticker: FRC; Returns Multiple against index: 0.89
#
# Ticker: DFS; Returns Multiple against index: 0.97
#
# Ticker: LYB; Returns Multiple against index: 1.11
#
# Ticker: GWW; Returns Multiple against index: 1.56
#
# Ticker: ALB; Returns Multiple against index: 1.4
#
# Ticker: PCG; Returns Multiple against index: 1.55
#
# Ticker: CBRE; Returns Multiple against index: 0.94
#
# Ticker: ALNY; Returns Multiple against index: 1.32
#
# Ticker: APTV; Returns Multiple against index: 0.74
#
# Ticker: EBAY; Returns Multiple against index: 0.71
#
# Ticker: HRL; Returns Multiple against index: 1.26
#
# Ticker: DHI; Returns Multiple against index: 0.92
#
# Ticker: RBLX; Returns Multiple against index: 0.58
#
# Ticker: EIX; Returns Multiple against index: 1.39
#
# Ticker: EXR; Returns Multiple against index: 1.24
#
# Ticker: EFX; Returns Multiple against index: 0.81
#
# Ticker: SIRI; Returns Multiple against index: 1.23
#
# Ticker: ARE; Returns Multiple against index: 0.91
#
# Ticker: WY; Returns Multiple against index: 1.19
#
# Ticker: STT; Returns Multiple against index: 0.96
#
# Ticker: DASH; Returns Multiple against index: 0.34
#
# Ticker: OKE; Returns Multiple against index: 1.41
#
# Ticker: ANSS; Returns Multiple against index: 0.77
#
# Ticker: WST; Returns Multiple against index: 0.76
#
# Ticker: DTE; Returns Multiple against index: 1.31
#
# Ticker: K; Returns Multiple against index: 1.33
#
# Ticker: MPWR; Returns Multiple against index: 1.02
#
# Ticker: HAL; Returns Multiple against index: 1.72
#
# Ticker: BKR; Returns Multiple against index: 1.21
#
# Ticker: SIVB; Returns Multiple against index: 0.8
#
# Ticker: CDW; Returns Multiple against index: 1.0
#
# Ticker: LEN-B; Returns Multiple against index: 0.87
#
# Ticker: LEN; Returns Multiple against index: 0.91
#
# Ticker: ETR; Returns Multiple against index: 1.24
#
# Ticker: ZBH; Returns Multiple against index: 0.95
#
# Ticker: DRE; Returns Multiple against index: 1.37
#
# Ticker: EPAM; Returns Multiple against index: 0.77
#
# Ticker: AEE; Returns Multiple against index: 1.26
#
# Ticker: CLR; Returns Multiple against index: 2.07
#
# Ticker: MKC; Returns Multiple against index: 1.06
#
# Ticker: LH; Returns Multiple against index: 0.89
#
# Ticker: FTV; Returns Multiple against index: 0.98
#
# Ticker: COIN; Returns Multiple against index: 0.36
#
# Ticker: MDB; Returns Multiple against index: 0.61
#
# Ticker: IT; Returns Multiple against index: 1.09
#
# Ticker: ALGN; Returns Multiple against index: 0.41
#
# Ticker: INVH; Returns Multiple against index: 1.12
#
# Ticker: FITB; Returns Multiple against index: 1.06
#
# Ticker: WTW; Returns Multiple against index: 1.02
#
# Ticker: LUV; Returns Multiple against index: 0.89
#
# Ticker: ZS; Returns Multiple against index: 0.78
#
# Ticker: VMC; Returns Multiple against index: 1.09
#
# Ticker: MLM; Returns Multiple against index: 1.08
#
# Ticker: URI; Returns Multiple against index: 1.02
#
# Ticker: TTD; Returns Multiple against index: 1.03
#
# Ticker: LYV; Returns Multiple against index: 1.21
#
# Ticker: SPOT; Returns Multiple against index: 0.5
#
# Ticker: FE; Returns Multiple against index: 1.28
#
# Ticker: CEG; Returns Multiple against index: nan
#
# Ticker: PLTR; Returns Multiple against index: 0.33
#
# Ticker: CTRA; Returns Multiple against index: 2.01
#
# Ticker: PAYC; Returns Multiple against index: 0.87
#
# Ticker: DAL; Returns Multiple against index: 0.93
#
# Ticker: TTWO; Returns Multiple against index: 0.93
#
# Ticker: GPC; Returns Multiple against index: 1.58
#
# Ticker: VRSN; Returns Multiple against index: 0.96
#
# Ticker: CHD; Returns Multiple against index: 1.11
#
# Ticker: PPL; Returns Multiple against index: 1.17
#
# Ticker: TSCO; Returns Multiple against index: 1.11
#
# Ticker: RJF; Returns Multiple against index: 1.36
#
# Ticker: STE; Returns Multiple against index: 1.13
#
# Ticker: NTRS; Returns Multiple against index: 1.01
#
# Ticker: MAA; Returns Multiple against index: 1.04
#
# Ticker: HIG; Returns Multiple against index: 1.11
#
# Ticker: VTR; Returns Multiple against index: 1.02
#
# Ticker: IR; Returns Multiple against index: 1.03
#
# Ticker: FANG; Returns Multiple against index: 2.12
#
# Ticker: WAT; Returns Multiple against index: 0.83
#
# Ticker: SUI; Returns Multiple against index: 0.9
#
# Ticker: CMS; Returns Multiple against index: 1.26
#
# Ticker: CNP; Returns Multiple against index: 1.43
#
# Ticker: CF; Returns Multiple against index: 2.58
#
# Ticker: RF; Returns Multiple against index: 1.31
#
# Ticker: CTLT; Returns Multiple against index: 0.78
#
# Ticker: BR; Returns Multiple against index: 1.15
#
# Ticker: ULTA; Returns Multiple against index: 1.32
#
# Ticker: PKI; Returns Multiple against index: 0.85
#
# Ticker: AVTR; Returns Multiple against index: 0.68
#
# Ticker: AGR; Returns Multiple against index: 1.1
#
# Ticker: HBAN; Returns Multiple against index: 1.07
#
# Ticker: PWR; Returns Multiple against index: 1.42
#
# Ticker: DOV; Returns Multiple against index: 0.84
#
# Ticker: MTCH; Returns Multiple against index: 0.42
#
# Ticker: BALL; Returns Multiple against index: 0.71
#
# Ticker: AMCR; Returns Multiple against index: 1.16
#
# Ticker: GRMN; Returns Multiple against index: 0.6
#
# Ticker: ZI; Returns Multiple against index: 0.8
#
# Ticker: JBHT; Returns Multiple against index: 1.13
#
# Ticker: HEI; Returns Multiple against index: 1.41
#
# Ticker: HEI-A; Returns Multiple against index: 1.28
#
# Ticker: UI; Returns Multiple against index: 1.12
#
# Ticker: MOH; Returns Multiple against index: 1.54
#
# Ticker: MOS; Returns Multiple against index: 2.0
#
# Ticker: TDY; Returns Multiple against index: 1.0
#
# Ticker: HPE; Returns Multiple against index: 1.08
#
# Ticker: ROL; Returns Multiple against index: 1.05
#
# Ticker: RPRX; Returns Multiple against index: 1.29
#
# Ticker: SWKS; Returns Multiple against index: 0.66
#
# Ticker: LBRDA; Returns Multiple against index: 0.61
#
# Ticker: LBRDK; Returns Multiple against index: 0.6
#
# Ticker: BRO; Returns Multiple against index: 1.27
#
# Ticker: CFG; Returns Multiple against index: 1.04
#
# Ticker: ESS; Returns Multiple against index: 0.99
#
# Ticker: FOX; Returns Multiple against index: 1.09
#
# Ticker: FOXA; Returns Multiple against index: 1.09
#
# Ticker: NET; Returns Multiple against index: 0.58
#
# Ticker: HOLX; Returns Multiple against index: 0.97
#
# Ticker: PODD; Returns Multiple against index: 1.01
#
# Ticker: XYL; Returns Multiple against index: 0.82
#
# Ticker: TRMB; Returns Multiple against index: 0.75
#
# Ticker: VFC; Returns Multiple against index: 0.71
#
# Ticker: LPLA; Returns Multiple against index: 1.8
#
# Ticker: NDAQ; Returns Multiple against index: 1.09
#
# Ticker: COO; Returns Multiple against index: 0.78
#
# Ticker: EXPD; Returns Multiple against index: 0.93
#
# Ticker: TYL; Returns Multiple against index: 0.91
#
# Ticker: FLT; Returns Multiple against index: 0.94
#
# Ticker: BMRN; Returns Multiple against index: 1.33
#
# Ticker: BBY; Returns Multiple against index: 0.79
#
# Ticker: PFG; Returns Multiple against index: 1.4
#
# Ticker: ZBRA; Returns Multiple against index: 0.59
#
# Ticker: HUBS; Returns Multiple against index: 0.55
#
# Ticker: CLX; Returns Multiple against index: 1.0
#
# Ticker: TWLO; Returns Multiple against index: 0.24
#
# Ticker: WAB; Returns Multiple against index: 1.15
#
# Ticker: PARAA; Returns Multiple against index: 0.7
#
# Ticker: PARA; Returns Multiple against index: 0.69
#
# Ticker: KEY; Returns Multiple against index: 1.09
#
# Ticker: J; Returns Multiple against index: 1.05
#
# Ticker: CAH; Returns Multiple against index: 1.53
#
# Ticker: CAG; Returns Multiple against index: 1.2
#
# Ticker: TER; Returns Multiple against index: 0.82
#
# Ticker: SYF; Returns Multiple against index: 0.81
#
# Ticker: WPC; Returns Multiple against index: 1.35
#
# Ticker: WRB; Returns Multiple against index: 1.62
#
# Ticker: ATO; Returns Multiple against index: 1.45
#
# Ticker: FDS; Returns Multiple against index: 1.33
#
# Ticker: DGX; Returns Multiple against index: 0.95
#
# Ticker: ACGL; Returns Multiple against index: 1.33
#
# Ticker: BIO; Returns Multiple against index: 0.69
#
# Ticker: INCY; Returns Multiple against index: 1.13
#
# Ticker: MKL; Returns Multiple against index: 1.09
#
# Ticker: IEX; Returns Multiple against index: 1.09
#
# Ticker: NTAP; Returns Multiple against index: 0.9
#
# Ticker: KMX; Returns Multiple against index: 0.76
#
# Ticker: ENTG; Returns Multiple against index: 0.96
#
# Ticker: AVY; Returns Multiple against index: 0.97
#
# Ticker: OKTA; Returns Multiple against index: 0.28
#
# Ticker: EVRG; Returns Multiple against index: 1.22
#
# Ticker: WDC; Returns Multiple against index: 0.84
#
# Ticker: DRI; Returns Multiple against index: 1.02
#
# Ticker: GNRC; Returns Multiple against index: 0.59
#
# Ticker: HWM; Returns Multiple against index: 1.31
#
# Ticker: SSNC; Returns Multiple against index: 0.9
#
# Ticker: EXPE; Returns Multiple against index: 0.84
#
# Ticker: HZNP; Returns Multiple against index: 0.69
#
# Ticker: AKAM; Returns Multiple against index: 0.91
#
# Ticker: AES; Returns Multiple against index: 1.33
#
# Ticker: LNT; Returns Multiple against index: 1.21
#
# Ticker: TECH; Returns Multiple against index: 0.75
#
# Ticker: TRU; Returns Multiple against index: 0.7
#
# Ticker: EQT; Returns Multiple against index: 2.82
#
# Ticker: CINF; Returns Multiple against index: 0.98
#
# Ticker: NLOK; Returns Multiple against index: 0.95
#
# Ticker: MRO; Returns Multiple against index: 2.65
#
# Ticker: JKHY; Returns Multiple against index: 1.34
#
# Ticker: UDR; Returns Multiple against index: 1.04
#
# Ticker: IP; Returns Multiple against index: 0.88
#
# Ticker: CSL; Returns Multiple against index: 1.75
#
# Ticker: LKQ; Returns Multiple against index: 1.2
#
# Ticker: BILL; Returns Multiple against index: 0.67
#
# Ticker: CPB; Returns Multiple against index: 1.28
#
# Ticker: POOL; Returns Multiple against index: 0.81
#
# Ticker: CPT; Returns Multiple against index: 1.03
#
# Ticker: TRGP; Returns Multiple against index: 1.88
#
# Ticker: PEAK; Returns Multiple against index: 0.9
#
# Ticker: BG; Returns Multiple against index: 1.45
#
# Ticker: SJM; Returns Multiple against index: 1.32
#
# Ticker: OMC; Returns Multiple against index: 1.14
#
# Ticker: NVR; Returns Multiple against index: 0.93
#
# Ticker: ACI; Returns Multiple against index: 1.12
#
# Ticker: DOCU; Returns Multiple against index: 0.26
#
# Ticker: IRM; Returns Multiple against index: 1.38
#
# Ticker: STLD; Returns Multiple against index: 1.49
#
# Ticker: PTC; Returns Multiple against index: 1.07
#
# Ticker: DPZ; Returns Multiple against index: 0.81
#
# Ticker: PLUG; Returns Multiple against index: 1.38
#
# Ticker: MGM; Returns Multiple against index: 0.93
#
# Ticker: PINS; Returns Multiple against index: 0.53
#
# Ticker: CG; Returns Multiple against index: 0.78
#
# Ticker: SWK; Returns Multiple against index: 0.55
#
# Ticker: ETSY; Returns Multiple against index: 0.57
#
# Ticker: AZPN; Returns Multiple against index: 1.95
#
# Ticker: BEN; Returns Multiple against index: 0.98
#
# Ticker: ELS; Returns Multiple against index: 0.99
#
# Ticker: TXT; Returns Multiple against index: 1.04
#
# Ticker: BXP; Returns Multiple against index: 0.92
#
# Ticker: LDOS; Returns Multiple against index: 1.12
#
# Ticker: RGEN; Returns Multiple against index: 0.88
#
# Ticker: U; Returns Multiple against index: 0.34
#
# Ticker: FMC; Returns Multiple against index: 1.31
#
# Ticker: ABMD; Returns Multiple against index: 0.87
#
# Ticker: CHRW; Returns Multiple against index: 1.48
#
# Ticker: NDSN; Returns Multiple against index: 1.1
#
# Ticker: KIM; Returns Multiple against index: 1.2
#
# Ticker: L; Returns Multiple against index: 1.19
#
# Ticker: WTRG; Returns Multiple against index: 1.13
#
# Ticker: AMH; Returns Multiple against index: 1.03
#
# Ticker: CTXS; Returns Multiple against index: 1.08
#
# Ticker: PKG; Returns Multiple against index: 1.06
#
# Ticker: GLPI; Returns Multiple against index: 1.22
#
# Ticker: ARES; Returns Multiple against index: 1.15
#
# Ticker: TPL; Returns Multiple against index: 1.7
#
# Ticker: HST; Returns Multiple against index: 1.28
#
# Ticker: CBOE; Returns Multiple against index: 1.1
#
# Ticker: UAL; Returns Multiple against index: 0.99
#
# Ticker: BAH; Returns Multiple against index: 1.36
#
# Ticker: GDDY; Returns Multiple against index: 1.16
#
# Ticker: PCTY; Returns Multiple against index: 1.09
#
# Ticker: FHN; Returns Multiple against index: 1.75
#
# Ticker: NI; Returns Multiple against index: 1.43
#
# Ticker: CE; Returns Multiple against index: 0.86
#
# Ticker: FICO; Returns Multiple against index: 1.12
#
# Ticker: WLK; Returns Multiple against index: 1.31
#
# Ticker: MAS; Returns Multiple against index: 1.0
#
# Ticker: SNA; Returns Multiple against index: 1.17
#
# Ticker: FCNCA; Returns Multiple against index: 1.1
#
# Ticker: RS; Returns Multiple against index: 1.51
#
# Ticker: TFX; Returns Multiple against index: 0.73
#
# Ticker: DT; Returns Multiple against index: 0.65
#
# Ticker: OVV; Returns Multiple against index: 2.1
#
# Ticker: VTRS; Returns Multiple against index: 0.83
#
# Ticker: RPM; Returns Multiple against index: 1.37
#
# Ticker: AAP; Returns Multiple against index: 1.03
#
# Ticker: WMS; Returns Multiple against index: 1.34
#
# Ticker: LW; Returns Multiple against index: 1.49
#
# Ticker: CRL; Returns Multiple against index: 0.55
#
# Ticker: DAR; Returns Multiple against index: 1.23
#
# Ticker: IPG; Returns Multiple against index: 0.91
#
# Ticker: EMN; Returns Multiple against index: 0.98
#
# Ticker: HUBB; Returns Multiple against index: 1.33
#
# Ticker: RYAN; Returns Multiple against index: 1.44
#
# Ticker: TAP; Returns Multiple against index: 1.32
#
# Ticker: DOX; Returns Multiple against index: 1.25
#
# Ticker: QGEN; Returns Multiple against index: 0.93
#
# Ticker: GGG; Returns Multiple against index: 0.97
#
# Ticker: BSY; Returns Multiple against index: 0.62
#
# Ticker: SBNY; Returns Multiple against index: 0.79
#
# Ticker: Y; Returns Multiple against index: 1.48
#
# Ticker: QRVO; Returns Multiple against index: 0.58
#
# Ticker: LUMN; Returns Multiple against index: 1.01
#
# Ticker: CCK; Returns Multiple against index: 1.05
#
# Ticker: REXR; Returns Multiple against index: 1.22
#
# Ticker: VST; Returns Multiple against index: 1.58
#
# Ticker: BLDR; Returns Multiple against index: 1.28
#
# Ticker: AR; Returns Multiple against index: 2.81
#
# Ticker: WOLF; Returns Multiple against index: 1.47
#
# Ticker: HAS; Returns Multiple against index: 0.96
#
# Ticker: EQH; Returns Multiple against index: 1.18
#
# Ticker: FNF; Returns Multiple against index: 1.04
#
# Ticker: REG; Returns Multiple against index: 1.09
#
# Ticker: APP; Returns Multiple against index: 0.4
#
# Ticker: CCL; Returns Multiple against index: 0.51
#
# Ticker: NLY; Returns Multiple against index: 0.98
#
# Ticker: CNA; Returns Multiple against index: 1.14
#
# Ticker: LSI; Returns Multiple against index: 1.18
#
# Ticker: AFG; Returns Multiple against index: 1.32
#
# Ticker: WSO; Returns Multiple against index: 1.17
#
# Ticker: CHK; Returns Multiple against index: 2.09
#
# Ticker: MORN; Returns Multiple against index: 0.99
#
# Ticker: FSLR; Returns Multiple against index: 1.53
#
# Ticker: UHAL; Returns Multiple against index: 0.93
#
# Ticker: BURL; Returns Multiple against index: 0.58
#
# Ticker: FFIV; Returns Multiple against index: 0.88
#
# Ticker: AGL; Returns Multiple against index: 0.83
#
# Ticker: APA; Returns Multiple against index: 2.3
#
# Ticker: CZR; Returns Multiple against index: 0.52
#
# Ticker: ROKU; Returns Multiple against index: 0.24
#
# Ticker: CUBE; Returns Multiple against index: 1.02
#
# Ticker: WRK; Returns Multiple against index: 0.9
#
# Ticker: BKI; Returns Multiple against index: 1.02
#
# Ticker: NFE; Returns Multiple against index: 2.34
#
# Ticker: SCI; Returns Multiple against index: 1.15
#
# Ticker: NWS; Returns Multiple against index: 0.93
#
# Ticker: NWSA; Returns Multiple against index: 0.9
#
# Ticker: OLPX; Returns Multiple against index: nan
#
# Ticker: MKTX; Returns Multiple against index: 0.68
#
# Ticker: DINO; Returns Multiple against index: 2.04
#
# Ticker: ALLY; Returns Multiple against index: 0.76
#
# Ticker: ACM; Returns Multiple against index: 1.29
#
# Ticker: HSIC; Returns Multiple against index: 1.08
#
# Ticker: DISH; Returns Multiple against index: 0.5
#
# Ticker: UTHR; Returns Multiple against index: 1.19
#
# Ticker: RCL; Returns Multiple against index: 0.65
#
# Ticker: CMA; Returns Multiple against index: 1.34
#
# Ticker: WSM; Returns Multiple against index: 0.95
#
# Ticker: CLVT; Returns Multiple against index: 0.58
#
# Ticker: RE; Returns Multiple against index: 1.27
#
# Ticker: CDAY; Returns Multiple against index: 0.65
#
# Ticker: AOS; Returns Multiple against index: 0.91
#
# Ticker: PHM; Returns Multiple against index: 0.99
#
# Ticker: PATH; Returns Multiple against index: 0.3
#
# Ticker: EWBC; Returns Multiple against index: 1.19
#
# Ticker: SNX; Returns Multiple against index: 0.92
#
# Ticker: ERIE; Returns Multiple against index: 1.44
#
# Ticker: AAL; Returns Multiple against index: 0.84
#
# Ticker: AMC; Returns Multiple against index: 0.22
#
# Ticker: GLOB; Returns Multiple against index: 0.79
#
# Ticker: GL; Returns Multiple against index: 1.26
#
# Ticker: MPW; Returns Multiple against index: 0.84
#
# Ticker: MTN; Returns Multiple against index: 0.89
#
# Ticker: BRKR; Returns Multiple against index: 0.73
#
# Ticker: JAZZ; Returns Multiple against index: 1.27
#
# Ticker: ZEN; Returns Multiple against index: 0.73
#
# Ticker: BJ; Returns Multiple against index: 1.51
#
# Ticker: UHS; Returns Multiple against index: 0.79
#
# Ticker: NRG; Returns Multiple against index: 1.15
#
# Ticker: CLF; Returns Multiple against index: 0.9
#
# Ticker: NBIX; Returns Multiple against index: 1.23
#
# Ticker: RRX; Returns Multiple against index: 1.16
#
# Ticker: HII; Returns Multiple against index: 1.36
#
# Ticker: WHR; Returns Multiple against index: 0.86
#
# Ticker: ACC; Returns Multiple against index: nan
#
# Ticker: BWA; Returns Multiple against index: 1.02
#
# Ticker: WSC; Returns Multiple against index: 1.67
#
# Ticker: TTC; Returns Multiple against index: 0.95
#
# Ticker: Z; Returns Multiple against index: 0.46
#
# Ticker: ZG; Returns Multiple against index: 0.46
#
# Ticker: ALLE; Returns Multiple against index: 0.78
#
# Ticker: ELAN; Returns Multiple against index: 0.5
#
# Ticker: MANH; Returns Multiple against index: 1.0
#
# Ticker: ARMK; Returns Multiple against index: 1.31
#
# Ticker: JNPR; Returns Multiple against index: 1.2
#
# Ticker: G; Returns Multiple against index: 1.05
#
# Ticker: SRPT; Returns Multiple against index: 1.64
#
# Ticker: LSCC; Returns Multiple against index: 0.98
#
# Ticker: BBWI; Returns Multiple against index: 0.71
#
# Ticker: LEA; Returns Multiple against index: 1.04
#
# Ticker: FBHS; Returns Multiple against index: 0.77
#
# Ticker: COLD; Returns Multiple against index: 0.98
#
# Ticker: PSTG; Returns Multiple against index: 1.28
#
# Ticker: EXAS; Returns Multiple against index: 0.44
#
# Ticker: LAMR; Returns Multiple against index: 1.05
#
# Ticker: FND; Returns Multiple against index: 0.74
#
# Ticker: LII; Returns Multiple against index: 0.91
#
# Ticker: RHI; Returns Multiple against index: 0.89
#
# Ticker: PNW; Returns Multiple against index: 1.21
#
# Ticker: CABO; Returns Multiple against index: 0.62
#
# Ticker: PAG; Returns Multiple against index: 1.41
#
# Ticker: KNX; Returns Multiple against index: 1.11
#
# Ticker: AA; Returns Multiple against index: 1.2
#
# Ticker: UGI; Returns Multiple against index: 1.02
#
# Ticker: OC; Returns Multiple against index: 1.06
#
# Ticker: CAR; Returns Multiple against index: 2.17
#
# Ticker: TPR; Returns Multiple against index: 1.01
#
# Ticker: CBSH; Returns Multiple against index: 1.24
#
# Ticker: AIZ; Returns Multiple against index: 1.11
#
# Ticker: FTNT; Returns Multiple against index: 0.96
#
# Ticker: PCOR; Returns Multiple against index: 0.69
#
# Ticker: JBL; Returns Multiple against index: 1.08
#
# Ticker: JLL; Returns Multiple against index: 0.83
#
# Ticker: MASI; Returns Multiple against index: 0.64
#
# Ticker: FRT; Returns Multiple against index: 1.02
#
# Ticker: CGNX; Returns Multiple against index: 0.58
#
# Ticker: DECK; Returns Multiple against index: 0.94
#
# Ticker: AXON; Returns Multiple against index: 0.77
#
# Ticker: AVLR; Returns Multiple against index: 0.56
#
# Ticker: NLSN; Returns Multiple against index: 1.58
#
# Ticker: ESTC; Returns Multiple against index: 0.63
#
# Ticker: NNN; Returns Multiple against index: 1.17
#
# Ticker: WAL; Returns Multiple against index: 0.92
#
# Ticker: OGN; Returns Multiple against index: 1.02
#
# Ticker: SEE; Returns Multiple against index: 1.08
#
# Ticker: CFR; Returns Multiple against index: 1.46
#
# Ticker: WBS; Returns Multiple against index: 1.15
#
# Ticker: LECO; Returns Multiple against index: 1.19
#
# Ticker: HOOD; Returns Multiple against index: 0.29
#
# Ticker: FIVN; Returns Multiple against index: 0.59
#
# Ticker: PNR; Returns Multiple against index: 0.7
#
# Ticker: IVZ; Returns Multiple against index: 0.83
#
# Ticker: NWL; Returns Multiple against index: 0.85
#
# Ticker: LNC; Returns Multiple against index: 0.89
#
# Ticker: ZION; Returns Multiple against index: 1.17
#
# Ticker: TTEK; Returns Multiple against index: 1.06
#
# Ticker: MAT; Returns Multiple against index: 1.31
#
# Ticker: OGE; Returns Multiple against index: 1.39
#
# Ticker: CHDN; Returns Multiple against index: 1.07
#
# Ticker: MIDD; Returns Multiple against index: 0.97
#
# Ticker: PFGC; Returns Multiple against index: 1.31
#
# Ticker: AGCO; Returns Multiple against index: 1.03
#
# Ticker: RRC; Returns Multiple against index: 2.01
#
# Ticker: ARW; Returns Multiple against index: 1.02
#
# Ticker: CIEN; Returns Multiple against index: 0.92
#
# Ticker: NVCR; Returns Multiple against index: 0.75
#
# Ticker: STOR; Returns Multiple against index: 0.96
#
# Ticker: DVA; Returns Multiple against index: nan
#
# Ticker: WYNN; Returns Multiple against index: 0.69
#
# Ticker: XRAY; Returns Multiple against index: 0.63
#
# Ticker: CASY; Returns Multiple against index: 1.31
#
# Ticker: HTZ; Returns Multiple against index: 1.34
#
# Ticker: JEF; Returns Multiple against index: 1.07
#
# Ticker: FIVE; Returns Multiple against index: 0.86
#
# Ticker: RGA; Returns Multiple against index: 1.28
#
# Ticker: CHNG; Returns Multiple against index: 1.31
#
# Ticker: SOFI; Returns Multiple against index: 0.46
#
# Ticker: OLN; Returns Multiple against index: 1.3
#
# Ticker: MHK; Returns Multiple against index: 0.68
#
# Ticker: SEIC; Returns Multiple against index: 1.08
#
# Ticker: BERY; Returns Multiple against index: 1.01
#
# Ticker: LAD; Returns Multiple against index: 0.87
#
# Ticker: WEX; Returns Multiple against index: 1.04
#
# Ticker: EGP; Returns Multiple against index: 1.12
#
# Ticker: AFRM; Returns Multiple against index: 0.24
#
# Ticker: OHI; Returns Multiple against index: 1.21
#
# Ticker: ACHC; Returns Multiple against index: 1.44
#
# Ticker: SWN; Returns Multiple against index: 1.7
#
# Ticker: STWD; Returns Multiple against index: 1.16
#
# Ticker: RL; Returns Multiple against index: 0.98
#
# Ticker: USFD; Returns Multiple against index: 1.08
#
# Ticker: PPC; Returns Multiple against index: 1.1
#
# Ticker: OSH; Returns Multiple against index: 0.6
#
# Ticker: TREX; Returns Multiple against index: 0.5
#
# Ticker: ST; Returns Multiple against index: 0.83
#
# Ticker: CNXC; Returns Multiple against index: 0.84
#
# Ticker: DNB; Returns Multiple against index: 0.94
#
# Ticker: KBR; Returns Multiple against index: 1.4
#
# Ticker: XPO; Returns Multiple against index: 0.71
#
# Ticker: CPRI; Returns Multiple against index: 1.03
#
# Ticker: CHE; Returns Multiple against index: 1.12
#
# Ticker: UNM; Returns Multiple against index: 1.77
#
# Ticker: CACC; Returns Multiple against index: 0.96
#
# Ticker: NXST; Returns Multiple against index: 1.57
#
# Ticker: DBX; Returns Multiple against index: 0.81
#
# Ticker: SYNH; Returns Multiple against index: 0.73
#
# Ticker: RH; Returns Multiple against index: 0.44
#
# Ticker: ATR; Returns Multiple against index: 0.96
#
# Ticker: FR; Returns Multiple against index: 1.13
#
# Ticker: PII; Returns Multiple against index: 1.07
#
# Ticker: BEPC; Returns Multiple against index: 1.07
#
# Ticker: THC; Returns Multiple against index: 0.95
#
# Ticker: ORI; Returns Multiple against index: 1.16
#
# Ticker: MKSI; Returns Multiple against index: 0.76
#
# Ticker: EXEL; Returns Multiple against index: 1.0
#
# Ticker: PLNT; Returns Multiple against index: 1.03
#
# Ticker: NOV; Returns Multiple against index: 1.51
#
# Ticker: CACI; Returns Multiple against index: 1.22
#
# Ticker: RUN; Returns Multiple against index: 0.96
#
# Ticker: RGLD; Returns Multiple against index: 1.0
#
# Ticker: AIRC; Returns Multiple against index: 0.99
#
# Ticker: DCI; Returns Multiple against index: 1.0
#
# Ticker: BLD; Returns Multiple against index: 0.92
#
# Ticker: AN; Returns Multiple against index: 1.26
#
# Ticker: PB; Returns Multiple against index: 1.22
#
# Ticker: GWRE; Returns Multiple against index: 0.64
#
# Ticker: NVST; Returns Multiple against index: 0.98
#
# Ticker: BRX; Returns Multiple against index: 1.17
#
# Ticker: GPK; Returns Multiple against index: 1.32
#
# Ticker: WCC; Returns Multiple against index: 1.43
#
# Ticker: ADT; Returns Multiple against index: 1.18
#
# Ticker: GNTX; Returns Multiple against index: 0.99
#
# Ticker: AGNC; Returns Multiple against index: 0.93
#
# Ticker: SF; Returns Multiple against index: 1.05
#
# Ticker: ITT; Returns Multiple against index: 0.96
#
# Ticker: IAC; Returns Multiple against index: 0.59
#
# Ticker: CHH; Returns Multiple against index: 1.09
#
# Ticker: NFG; Returns Multiple against index: 1.58
#
# Ticker: FYBR; Returns Multiple against index: 0.91
#
# Ticker: LFUS; Returns Multiple against index: 0.96
#
# Ticker: HRB; Returns Multiple against index: 2.1
#
# Ticker: COTY; Returns Multiple against index: 1.07
#
# Ticker: LITE; Returns Multiple against index: 1.06
#
# Ticker: WU; Returns Multiple against index: 0.83
#
# Ticker: MP; Returns Multiple against index: 1.11
#
# Ticker: WH; Returns Multiple against index: 1.09
#
# Ticker: VOYA; Returns Multiple against index: 1.13
#
# Ticker: IONS; Returns Multiple against index: 1.45
#
# Ticker: DKNG; Returns Multiple against index: 0.32
#
# Ticker: GXO; Returns Multiple against index: 0.63
#
# Ticker: REYN; Returns Multiple against index: 1.17
#
# Ticker: MTZ; Returns Multiple against index: 1.04
#
# Ticker: CCCS; Returns Multiple against index: 0.91
#
# Ticker: BYD; Returns Multiple against index: 1.08
#
# Ticker: SITE; Returns Multiple against index: 0.69
#
# Ticker: MDU; Returns Multiple against index: 1.14
#
# Ticker: PNFP; Returns Multiple against index: 0.98
#
# Ticker: TDOC; Returns Multiple against index: 0.26
#
# Ticker: INGR; Returns Multiple against index: 1.14
#
# Ticker: DXC; Returns Multiple against index: 0.87
#
# Ticker: IBKR; Returns Multiple against index: 1.24
#
# Ticker: GMED; Returns Multiple against index: 0.86
#
# Ticker: KRC; Returns Multiple against index: 0.92
#
# Ticker: SON; Returns Multiple against index: 1.19
#
# Ticker: BOKF; Returns Multiple against index: 1.27
#
# Ticker: ALK; Returns Multiple against index: 0.93
#
# Ticker: WWD; Returns Multiple against index: 0.9
#
# Ticker: LYFT; Returns Multiple against index: 0.4
#
# Ticker: PENN; Returns Multiple against index: 0.45
#
# Ticker: FLO; Returns Multiple against index: 1.31
#
# Ticker: VAC; Returns Multiple against index: 1.11
#
# Ticker: BPOP; Returns Multiple against index: 1.25
#
# Ticker: BC; Returns Multiple against index: 0.87
#
# Ticker: CLH; Returns Multiple against index: 1.36
#
# Ticker: VMI; Returns Multiple against index: 1.32
#
# Ticker: HR; Returns Multiple against index: 1.15
#
# Ticker: NVT; Returns Multiple against index: 1.22
#
# Ticker: HUN; Returns Multiple against index: 1.15
#
# Ticker: SRC; Returns Multiple against index: 0.99
#
# Ticker: FAF; Returns Multiple against index: 0.92
#
# Ticker: AYI; Returns Multiple against index: 1.11
#
# Ticker: SNV; Returns Multiple against index: 1.19
#
# Ticker: COUP; Returns Multiple against index: 0.32
#
# Ticker: PRGO; Returns Multiple against index: 1.03
#
# Ticker: IIVI; Returns Multiple against index: 0.8
#
# Ticker: CR; Returns Multiple against index: 1.16
#
# Ticker: OLED; Returns Multiple against index: 0.61
#
# Ticker: CW; Returns Multiple against index: 1.5
#
# Ticker: TOL; Returns Multiple against index: 0.84
#
# Ticker: IDA; Returns Multiple against index: 1.21
#
# Ticker: AXTA; Returns Multiple against index: 1.0
#
# Ticker: LSTR; Returns Multiple against index: 1.03
#
# Ticker: ASH; Returns Multiple against index: 1.25
#
# Ticker: TMX; Returns Multiple against index: 1.1
#
# Ticker: FCN; Returns Multiple against index: 1.32
#
# Ticker: DKS; Returns Multiple against index: 1.0
#
# Ticker: INFA; Returns Multiple against index: nan
#
# Ticker: RNR; Returns Multiple against index: 1.09
#
# Ticker: HOG; Returns Multiple against index: 1.26
#
# Ticker: SKX; Returns Multiple against index: 0.91
#
# Ticker: X; Returns Multiple against index: 1.1
#
# Ticker: VNO; Returns Multiple against index: 0.81
#
# Ticker: OSK; Returns Multiple against index: 0.86
#
# Ticker: CC; Returns Multiple against index: 1.32
#
# Ticker: LEG; Returns Multiple against index: 0.97
#
# Ticker: PEN; Returns Multiple against index: 0.81
#
# Ticker: PYCR; Returns Multiple against index: 1.1
#
# Ticker: MNDT; Returns Multiple against index: 1.41
#
# Ticker: CHPT; Returns Multiple against index: 0.95
#
# Ticker: POST; Returns Multiple against index: 1.42
#
# Ticker: DRVN; Returns Multiple against index: 1.24
#
# Ticker: RYN; Returns Multiple against index: 1.13
#
# Ticker: EHC; Returns Multiple against index: 0.94
#
# Ticker: TWKS; Returns Multiple against index: nan
#
# Ticker: PDCE; Returns Multiple against index: 1.81
#
# Ticker: AZTA; Returns Multiple against index: 0.65
#
# Ticker: S; Returns Multiple against index: 0.49
#
# Ticker: SAIC; Returns Multiple against index: 1.28
#
# Ticker: GH; Returns Multiple against index: 0.51
#
# Ticker: IPGP; Returns Multiple against index: 0.6
#
# Ticker: SHC; Returns Multiple against index: 0.7
#
# Ticker: HXL; Returns Multiple against index: 1.23
#
# Ticker: NATI; Returns Multiple against index: 1.1
#
# Ticker: WTFC; Returns Multiple against index: 1.35
#
# Ticker: BWXT; Returns Multiple against index: 1.09
#
# Ticker: DTM; Returns Multiple against index: 1.44
#
# Ticker: ALGM; Returns Multiple against index: 0.86
#
# Ticker: NYT; Returns Multiple against index: 0.71
#
# Ticker: AMG; Returns Multiple against index: 0.92
#
# Ticker: SWCH; Returns Multiple against index: 1.47
#
# Ticker: NRZ; Returns Multiple against index: 1.06
#
# Ticker: DLB; Returns Multiple against index: 0.9
#
# Ticker: LPX; Returns Multiple against index: 1.0
#
# Ticker: IAA; Returns Multiple against index: 0.76
#
# Ticker: VVV; Returns Multiple against index: 1.05
#
# Ticker: OWL; Returns Multiple against index: 0.85
#
# Ticker: W; Returns Multiple against index: 0.22
#
# Ticker: PLTK; Returns Multiple against index: 0.45
#
# Ticker: VRT; Returns Multiple against index: 0.61
#
# Ticker: PRI; Returns Multiple against index: 0.99
#
# Ticker: MSA; Returns Multiple against index: 0.89
#
# Ticker: NTRA; Returns Multiple against index: 0.49
#
# Ticker: CRUS; Returns Multiple against index: 0.97
#
# Ticker: NSA; Returns Multiple against index: 1.03
#
# Ticker: OZK; Returns Multiple against index: 1.18
#
# Ticker: NVAX; Returns Multiple against index: 0.15
#
# Ticker: EEFT; Returns Multiple against index: 0.8
#
# Ticker: NYCB; Returns Multiple against index: 0.96
#
# Ticker: ESI; Returns Multiple against index: 1.01
#
# Ticker: EXP; Returns Multiple against index: 0.94
#
# Ticker: TOST; Returns Multiple against index: nan
#
# Ticker: M; Returns Multiple against index: 1.01
#
# Ticker: TPX; Returns Multiple against index: 0.67
#
# Ticker: BFAM; Returns Multiple against index: 0.56
#
# Ticker: SLGN; Returns Multiple against index: 1.31
#
# Ticker: SEB; Returns Multiple against index: 1.06
#
# Ticker: TKR; Returns Multiple against index: 1.09
#
# Ticker: OMF; Returns Multiple against index: 0.81
#
# Ticker: NCR; Returns Multiple against index: 0.91
#
# Ticker: HE; Returns Multiple against index: 1.11
#
# Ticker: COLM; Returns Multiple against index: 0.82
#
# Ticker: AVT; Returns Multiple against index: 1.25
#
# Ticker: IART; Returns Multiple against index: 0.79
#
# Ticker: THO; Returns Multiple against index: 0.82
#
# Ticker: WEN; Returns Multiple against index: 1.05
#
# Ticker: DOCS; Returns Multiple against index: 0.37
#
# Ticker: THG; Returns Multiple against index: 1.11
#
# Ticker: SMG; Returns Multiple against index: 0.44
#
# Ticker: FLS; Returns Multiple against index: 1.0
#
# Ticker: PINC; Returns Multiple against index: 1.05
#
# Ticker: SMAR; Returns Multiple against index: 0.58
#
# Ticker: CUZ; Returns Multiple against index: 0.89
#
# Ticker: MTG; Returns Multiple against index: 1.1
#
# Ticker: H; Returns Multiple against index: 1.44
#
# Ticker: SRCL; Returns Multiple against index: 0.81
#
# Ticker: MRTX; Returns Multiple against index: 0.57
#
# Ticker: LAZ; Returns Multiple against index: 0.93
#
# Ticker: QS; Returns Multiple against index: 0.58
#
# Ticker: PVH; Returns Multiple against index: 0.62
#
# Ticker: GO; Returns Multiple against index: 1.71
#
# Ticker: UNVR; Returns Multiple against index: 1.31
#
# Ticker: AL; Returns Multiple against index: 1.12
#
# Ticker: ICUI; Returns Multiple against index: 0.79
#
# Ticker: TFSL; Returns Multiple against index: 0.92
#
# Ticker: AXS; Returns Multiple against index: 1.33
#
# Ticker: RNG; Returns Multiple against index: 0.23
#
# Ticker: FNB; Returns Multiple against index: 1.28
#
# Ticker: DV; Returns Multiple against index: 0.91
#
# Ticker: JHG; Returns Multiple against index: 0.7
#
# Ticker: NEWR; Returns Multiple against index: 0.93
#
# Ticker: AWI; Returns Multiple against index: 1.0
#
# Ticker: MAN; Returns Multiple against index: 0.72
#
# Ticker: TDC; Returns Multiple against index: 0.71
#
# Ticker: QDEL; Returns Multiple against index: 0.64
#
# Ticker: UA; Returns Multiple against index: 0.45
#
# Ticker: UAA; Returns Multiple against index: 0.44
#
# Ticker: CNM; Returns Multiple against index: 0.99
#
# Ticker: TXG; Returns Multiple against index: 0.22
#
# Ticker: R; Returns Multiple against index: 1.15
#
# Ticker: VNT; Returns Multiple against index: 0.67
#
# Ticker: AMED; Returns Multiple against index: 0.76
#
# Ticker: EVR; Returns Multiple against index: 0.81
#
# Ticker: NCNO; Returns Multiple against index: 0.54
#
# Ticker: WIX; Returns Multiple against index: 0.37
#
# Ticker: RARE; Returns Multiple against index: 0.54
#
# Ticker: OLLI; Returns Multiple against index: 0.92
#
# Ticker: EPR; Returns Multiple against index: 1.09
#
# Ticker: HBI; Returns Multiple against index: 0.57
#
# Ticker: MSM; Returns Multiple against index: 1.16
#
# Ticker: DEI; Returns Multiple against index: 0.76
#
# Ticker: SAM; Returns Multiple against index: 0.7
#
# Ticker: SLM; Returns Multiple against index: 1.01
#
# Ticker: KSS; Returns Multiple against index: 0.69
#
# Ticker: AMBP; Returns Multiple against index: 0.72
#
# Ticker: CERT; Returns Multiple against index: 0.52
#
# Ticker: YETI; Returns Multiple against index: 0.43
#
# Ticker: JWN; Returns Multiple against index: 0.84
#
# Ticker: KEX; Returns Multiple against index: 1.5
#
# Ticker: NTNX; Returns Multiple against index: 0.6
#
# Ticker: UMPQ; Returns Multiple against index: 1.11
#
# Ticker: TNDM; Returns Multiple against index: 0.51
#
# Ticker: AYX; Returns Multiple against index: 1.06
#
# Ticker: TNL; Returns Multiple against index: 0.91
#
# Ticker: WTM; Returns Multiple against index: 1.4
#
# Ticker: ALSN; Returns Multiple against index: 1.17
#
# Ticker: GTES; Returns Multiple against index: 0.76
#
# Ticker: GPS; Returns Multiple against index: 0.48
#
# Ticker: HHC; Returns Multiple against index: 0.87
#
# Ticker: MCW; Returns Multiple against index: 0.65
#
# Ticker: PK; Returns Multiple against index: 0.89
#
# Ticker: HIW; Returns Multiple against index: 0.85
#
# Ticker: MRVI; Returns Multiple against index: 0.54
#
# Ticker: SGFY; Returns Multiple against index: 1.37
#
# Ticker: VEEV; Returns Multiple against index: 0.66
#
# Ticker: WE; Returns Multiple against index: nan
#
# Ticker: SSRM; Returns Multiple against index: 1.05
#
# Ticker: DNA; Returns Multiple against index: 0.33
#
# Ticker: FHB; Returns Multiple against index: 1.15
#
# Ticker: JAMF; Returns Multiple against index: 0.68
#
# Ticker: PACW; Returns Multiple against index: 0.74
#
# Ticker: WOOF; Returns Multiple against index: 0.8
#
# Ticker: AGO; Returns Multiple against index: 1.32
#
# Ticker: SPR; Returns Multiple against index: 0.87
#
# Ticker: CRI; Returns Multiple against index: 0.87
#
# Ticker: BHF; Returns Multiple against index: 1.24
#
# Ticker: BOH; Returns Multiple against index: 1.17
#
# Ticker: PEGA; Returns Multiple against index: 0.34
#
# Ticker: AZEK; Returns Multiple against index: 0.55
#
# Ticker: VSCO; Returns Multiple against index: 0.62
#
# Ticker: ENOV; Returns Multiple against index: 0.72
#
# Ticker: WDAY; Returns Multiple against index: 0.71
#
# Ticker: MSGS; Returns Multiple against index: 1.02
#
# Ticker: WWE; Returns Multiple against index: 1.5
#
# Ticker: LOPE; Returns Multiple against index: 1.06
#
# Ticker: SLG; Returns Multiple against index: 0.85
#
# Ticker: NEU; Returns Multiple against index: 1.04
#
# Ticker: OPEN; Returns Multiple against index: 0.29
#
# Ticker: GME; Returns Multiple against index: 0.68
#
# Ticker: MRCY; Returns Multiple against index: 1.13
#
# Ticker: DH; Returns Multiple against index: nan
#
# Ticker: LESL; Returns Multiple against index: 0.67
#
# Ticker: NCLH; Returns Multiple against index: 0.66
#
# Ticker: JBLU; Returns Multiple against index: 0.63
#
# Ticker: JBGS; Returns Multiple against index: 0.88
#
# Ticker: SPB; Returns Multiple against index: 0.76
#
# Ticker: KMPR; Returns Multiple against index: 0.86
#
# Ticker: ESAB; Returns Multiple against index: nan
#
# Ticker: VSAT; Returns Multiple against index: 0.86
#
# Ticker: TRIP; Returns Multiple against index: 0.82
#
# Ticker: VIRT; Returns Multiple against index: 1.11
#
# Ticker: HAYW; Returns Multiple against index: 0.61
#
# Ticker: UPST; Returns Multiple against index: 0.11
#
# Ticker: KD; Returns Multiple against index: nan
#
# Ticker: FRPT; Returns Multiple against index: 0.33
#
# Ticker: FOUR; Returns Multiple against index: 0.67
#
# Ticker: SNDR; Returns Multiple against index: 1.14
#
# Ticker: CPA; Returns Multiple against index: 1.09
#
# Ticker: ATUS; Returns Multiple against index: 0.44
#
# Ticker: SIX; Returns Multiple against index: 0.67
#
# Ticker: HPP; Returns Multiple against index: 0.62
#
# Ticker: TW; Returns Multiple against index: 0.89
#
# Ticker: SPLK; Returns Multiple against index: 0.69
#
# Ticker: CVNA; Returns Multiple against index: 0.12
#
# Ticker: RKT; Returns Multiple against index: 0.58
#
# Ticker: UWMC; Returns Multiple against index: 0.64
#
# Ticker: PTON; Returns Multiple against index: 0.1
#
# Ticker: EHAB; Returns Multiple against index: nan

# %%
# Creating dataframe of only bottom 40%
tickers["Returns_multiple"] =  returns_multiples
tickers["RS_Rating"] = tickers.groupby("sector").Returns_multiple.rank(pct=True) * 100
rs_df = tickers[tickers.RS_Rating <= tickers.RS_Rating.quantile(.40)].sort_values('RS_Rating',ascending=True)

# %%
# Checking Minervini conditions of bottom 40% of stocks in given list
exportList = pd.DataFrame(columns=['Stock', "Sector", "RS_Rating", "returns multiple", "Last Price","%change","50 Day MA", "150 Day Ma", "200 Day MA", "52 Week Low", "52 week High", "% from 52 week low"])

for i in range(len(rs_df)):
    stock = rs_df["ticker"].iloc[i]
    ret_mult = rs_df["Returns_multiple"].iloc[i]
    sector = rs_df.index[i]
    try:
        df = pd.read_csv(os.path.join(os.getcwd(),'us_stocks',f'{stock}.csv'), index_col=0) 
        sma = [50, 150, 200]
        for x in sma:
            df["SMA_"+str(x)] = round(df['Adj Close'].rolling(window=x).mean(), 2)
        
        # Storing required values 
        currentClose = df["Adj Close"][-1]
        prevClose =  df["Adj Close"][-2]
        pct_chg   = (currentClose - prevClose ) * 100/ prevClose
        moving_average_50 = df["SMA_50"][-1]
        moving_average_150 = df["SMA_150"][-1]
        moving_average_200 = df["SMA_200"][-1]
        low_of_52week = round(min(df["Low"]), 2)
        high_of_52week = round(max(df["High"]), 2)
        pct_from_52wkhigh = (high_of_52week - currentClose)/high_of_52week * 100
        pct_from_52wklow = (currentClose - low_of_52week)/low_of_52week * 100
        RS_Rating = round(rs_df[rs_df['ticker']==stock].RS_Rating.tolist()[0])
        
        try:
            moving_average_200_20 = df["SMA_200"][-20]
        except Exception:
            moving_average_200_20 = 0

        # Condition 1: Current Price < 150 SMA and < 200 SMA
        condition_1 = currentClose < moving_average_150 < moving_average_200
        
        # Condition 2: 150 SMA and < 200 SMA
        condition_2 = moving_average_150 < moving_average_200

        # Condition 3: 200 SMA trending down for at least 1 month
        condition_3 = moving_average_200 < moving_average_200_20
        
        # Condition 4: 50 SMA< 150 SMA and 50 SMA< 200 SMA
        condition_4 = moving_average_50 < moving_average_150 < moving_average_200
           
        # Condition 5: Current Price < 50 SMA
        condition_5 = currentClose < moving_average_50
           
        # Condition 6: Current Price is at least 30% below 52 week high
        condition_6 = currentClose <= (0.7*high_of_52week)
           
        # Condition 7: Current Price is within 30% of 52 week low
        condition_7 = currentClose <= (1.4*low_of_52week)

        # Condition 8: Price greater than 15
        condition_8 = currentClose  > 15
        
        # If all conditions above are true, add stock to exportList
        if(condition_1 and condition_2 and condition_3 and condition_4 and condition_5 and condition_6 and condition_7 and condition_8):
            exportEntry = pd.DataFrame({'Stock': stock, "Sector" : sector, "RS_Rating": RS_Rating , "returns multiple" : ret_mult, "Last Price" : round(currentClose,3), "%change" : round(pct_chg,2), "50 Day MA": moving_average_50, "150 Day Ma" : moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week, "% from 52 week low" : round(pct_from_52wklow,2)},index=[0])
            exportList = pd.concat([exportList,exportEntry], ignore_index=True)
            print (stock + " made the Minervini requirements")
    except Exception as e:
        print (e)
        print(f"Could not gather data on {stock}")

exportList = exportList.sort_values(by='RS_Rating', ascending=True)
print('\n', exportList)
writer = ExcelWriter(os.path.join(os.getcwd(),"output_screener_us_short_position.xlsx"))
exportList.to_excel(writer, "Sheet1",index=False)
writer.save()
# Out:
# RNG made the Minervini requirements
# UPST made the Minervini requirements
# NVAX made the Minervini requirements
# TREX made the Minervini requirements
# TWLO made the Minervini requirements
# TXG made the Minervini requirements
# FRPT made the Minervini requirements
# SWK made the Minervini requirements
# W made the Minervini requirements
# DOCU made the Minervini requirements
# TDOC made the Minervini requirements
# OKTA made the Minervini requirements
# SMG made the Minervini requirements
# SAM made the Minervini requirements
# GNRC made the Minervini requirements
# ROKU made the Minervini requirements
# DASH made the Minervini requirements
# ZM made the Minervini requirements
# DOCS made the Minervini requirements
# YETI made the Minervini requirements
# ALGN made the Minervini requirements
# BALL made the Minervini requirements
# SPB made the Minervini requirements
# MTCH made the Minervini requirements
# EXAS made the Minervini requirements
# PEGA made the Minervini requirements
# PACW made the Minervini requirements
# SITE made the Minervini requirements
# DEI made the Minervini requirements
# PENN made the Minervini requirements
# PNR made the Minervini requirements
# TRU made the Minervini requirements
# CG made the Minervini requirements
# EL made the Minervini requirements
# WBA made the Minervini requirements
# VNO made the Minervini requirements
# APP made the Minervini requirements
# XPO made the Minervini requirements
# COF made the Minervini requirements
# SBNY made the Minervini requirements
# MAN made the Minervini requirements
# JLL made the Minervini requirements
# IAA made the Minervini requirements
# BFAM made the Minervini requirements
# CERT made the Minervini requirements
# OMF made the Minervini requirements
# FBHS made the Minervini requirements
# MMM made the Minervini requirements
# RARE made the Minervini requirements
# MRVI made the Minervini requirements
# QRVO made the Minervini requirements
# CGNX made the Minervini requirements
# ALLE made the Minervini requirements
# CRL made the Minervini requirements
# HIW made the Minervini requirements
# BURL made the Minervini requirements
# EFX made the Minervini requirements
# GRMN made the Minervini requirements
# ZBRA made the Minervini requirements
# FIVN made the Minervini requirements
# HHC made the Minervini requirements
# IDXX made the Minervini requirements
# PVH made the Minervini requirements
# IPGP made the Minervini requirements
# ST made the Minervini requirements
# XRAY made the Minervini requirements
# OLED made the Minervini requirements
# MDB made the Minervini requirements
# QDEL made the Minervini requirements
# SHW made the Minervini requirements
# AZTA made the Minervini requirements
# TW made the Minervini requirements
# GWRE made the Minervini requirements
# OSK made the Minervini requirements
# CUZ made the Minervini requirements
# SPR made the Minervini requirements
# AVTR made the Minervini requirements
# SWKS made the Minervini requirements
# MHK made the Minervini requirements
# BIO made the Minervini requirements
# HZNP made the Minervini requirements
# LUV made the Minervini requirements
# FAF made the Minervini requirements
# SHC made the Minervini requirements
# ADBE made the Minervini requirements
# VNT made the Minervini requirements
# INTC made the Minervini requirements
# CHTR made the Minervini requirements
# ENOV made the Minervini requirements
# AOS made the Minervini requirements
# JAMF made the Minervini requirements
# VFC made the Minervini requirements
# EBAY made the Minervini requirements
# SPLK made the Minervini requirements
# TFX made the Minervini requirements
# BRKR made the Minervini requirements
# SYNH made the Minervini requirements
# IAC made the Minervini requirements
# APTV made the Minervini requirements
# TDC made the Minervini requirements
# CRM made the Minervini requirements
# DLR made the Minervini requirements
# BXP made the Minervini requirements
# KRC made the Minervini requirements
# TECH made the Minervini requirements
# NVDA made the Minervini requirements
# LBRDK made the Minervini requirements
# KMX made the Minervini requirements
# TRMB made the Minervini requirements
# WST made the Minervini requirements
# LBRDA made the Minervini requirements
# MKSI made the Minervini requirements
# ANSS made the Minervini requirements
# POOL made the Minervini requirements
# CABO made the Minervini requirements
# MDT made the Minervini requirements
# AMAT made the Minervini requirements
# CMCSA made the Minervini requirements
# IIVI made the Minervini requirements
# EEFT made the Minervini requirements
# IART made the Minervini requirements
# UHS made the Minervini requirements
# LPX made the Minervini requirements
# PARA made the Minervini requirements
# TOL made the Minervini requirements
# DDOG made the Minervini requirements
# TER made the Minervini requirements
#
#      Stock                  Sector RS_Rating  returns multiple  Last Price  \
# 0     RNG  Information Technology         1              0.23       45.62
# 1    UPST              Financials         1              0.11       27.53
# 2    NVAX             Health Care         1              0.15       31.72
# 3    TREX             Industrials         1              0.50       49.73
# 4    TWLO  Information Technology         2              0.24       72.19
# ..    ...                     ...       ...               ...         ...
# 120  IART             Health Care        38              0.79       49.59
# 121   UHS             Health Care        38              0.79      103.01
# 124   TOL  Consumer Discretionary        38              0.84       45.34
# 125  DDOG  Information Technology        39              0.82      100.54
# 126   TER  Information Technology        39              0.82       88.84
#
#      %change  50 Day MA  150 Day Ma  200 Day MA  52 Week Low  52 week High  \
# 0       4.42      49.63       81.95      107.95        40.59        315.00
# 1       2.88      28.11       64.55       83.71        22.42        401.49
# 2       4.76      48.90       58.23       79.82        28.25        260.69
# 3       3.11      55.75       63.90       78.05        44.49        140.98
# 4       3.99      82.17      115.96      147.44        64.29        373.00
# ..       ...        ...         ...         ...          ...           ...
# 120     2.35      53.18       59.24       60.93        46.46         74.98
# 121     1.75     105.60      123.09      124.31        94.70        158.28
# 124     2.53      47.36       48.19       52.55        40.20         75.61
# 125     2.71     103.14      118.19      128.27        81.12        199.68
# 126     3.13      94.21      103.83      115.63        80.41        168.91
#
#      % from 52 week low
# 0                 12.39
# 1                 22.79
# 2                 12.28
# 3                 11.78
# 4                 12.29
# ..                  ...
# 120                6.74
# 121                8.78
# 124               12.79
# 125               23.94
# 126               10.48
#
# [127 rows x 12 columns]

# %%
exportList
# Out:
#     Stock                  Sector RS_Rating  returns multiple  Last Price  \
# 0     RNG  Information Technology         1              0.23       45.62
# 1    UPST              Financials         1              0.11       27.53
# 2    NVAX             Health Care         1              0.15       31.72
# 3    TREX             Industrials         1              0.50       49.73
# 4    TWLO  Information Technology         2              0.24       72.19
# ..    ...                     ...       ...               ...         ...
# 120  IART             Health Care        38              0.79       49.59
# 121   UHS             Health Care        38              0.79      103.01
# 124   TOL  Consumer Discretionary        38              0.84       45.34
# 125  DDOG  Information Technology        39              0.82      100.54
# 126   TER  Information Technology        39              0.82       88.84
#
#      %change  50 Day MA  150 Day Ma  200 Day MA  52 Week Low  52 week High  \
# 0       4.42      49.63       81.95      107.95        40.59        315.00
# 1       2.88      28.11       64.55       83.71        22.42        401.49
# 2       4.76      48.90       58.23       79.82        28.25        260.69
# 3       3.11      55.75       63.90       78.05        44.49        140.98
# 4       3.99      82.17      115.96      147.44        64.29        373.00
# ..       ...        ...         ...         ...          ...           ...
# 120     2.35      53.18       59.24       60.93        46.46         74.98
# 121     1.75     105.60      123.09      124.31        94.70        158.28
# 124     2.53      47.36       48.19       52.55        40.20         75.61
# 125     2.71     103.14      118.19      128.27        81.12        199.68
# 126     3.13      94.21      103.83      115.63        80.41        168.91
#
#      % from 52 week low
# 0                 12.39
# 1                 22.79
# 2                 12.28
# 3                 11.78
# 4                 12.29
# ..                  ...
# 120                6.74
# 121                8.78
# 124               12.79
# 125               23.94
# 126               10.48
#
# [127 rows x 12 columns]

# %%
1+1
# Out:
# 2
