# %%
### Needed for google colab runtime
# import sys
# !{sys.executable} -m pip install yfinance yahoo_fin --upgrade --no-cache-dir

# from google.colab import drive
# drive.mount('/content/drive')

# %%
import os
from pandas_datareader import data as pdr
from yahoo_fin import stock_info as si
import asyncio
from pandas import ExcelWriter
import yfinance as yf
import pandas as pd
import numpy as np
import datetime
import time
yf.pdr_override()

# %%
### Variables
tickers = pd.DataFrame()
tickers = pd.read_excel("https://topforeignstocks.com/wp-content/uploads/2022/07/Complete-List-of-SP-500-Constituents-July-4-2022.xlsx",sheet_name=0,header=None,usecols = "C,D",skiprows = 1,names = ["ticker","sector"])
tickers["ticker"] = [item.replace(".", "-") for item in tickers["ticker"]] # Yahoo Finance uses dashes instead of dots
tickers = tickers.set_index("sector")

#combine into one string needed to download multiple files using yfinance module
tickers_string = ""
for i in tickers["ticker"]:
    tickers_string += i + " "

index_name = '^SPX' # SP 500
start_date = datetime.datetime.now() - datetime.timedelta(days=365)
end_date = datetime.date.today()

# %%
###  Download ticker data from yahoo finance simultaneously
results = yf.download(tickers = tickers_string,start = start_date, end = end_date, interval= '1d',threads = True,group_by="ticker")

### write to file
for ticker in tickers["ticker"]:
    df = results[ticker].reset_index()
    df.to_csv( os.path.join(os.getcwd(),'us_stocks',ticker+'.csv'), index = False, header=True )
# Out:
# [*********************100%***********************]  505 of 505 completed
#
# 1 Failed download:
# - CASH_USD: No data found, symbol may be delisted

# %%
# Index Returns
index_df = pdr.get_data_yahoo(index_name, start_date, end_date)
index_return = index_df['Adj Close'].iloc[-1] / index_df['Adj Close'].iloc[0]       # not efficient: (index_df['Percent Change'] + 1).cumprod()[-1]

# Import historical data as CSV for all stocks (makes the process faster)
df_list = pd.concat(( map(pd.read_csv, [os.path.join(os.getcwd(),'us_stocks',s+'.csv') for s in tickers["ticker"] ])), keys=tickers["ticker"] )

# Find top 30% performing stocks (relative to the index)
returns_multiples = []
for ticker in tickers["ticker"]:
    # Calculating returns relative to the market (returns multiple)
    df = df_list.loc[ticker].copy()
    stock_return = df['Adj Close'].iloc[-1] / df['Adj Close'].iloc[0]   # not efficient: ((df['Percent Change'] + 1).cumprod()).iloc[-1]
    
    returns_multiple = round((stock_return / index_return), 2)
    returns_multiples.extend([returns_multiple])
    
    print (f'Ticker: {ticker}; Returns Multiple against index: {returns_multiple}\n')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker: AAPL; Returns Multiple against index: 1.06
#
# Ticker: MSFT; Returns Multiple against index: 0.9
#
# Ticker: AMZN; Returns Multiple against index: 0.77
#
# Ticker: GOOGL; Returns Multiple against index: 0.79
#
# Ticker: GOOG; Returns Multiple against index: 0.79
#
# Ticker: TSLA; Returns Multiple against index: 1.22
#
# Ticker: BRK-B; Returns Multiple against index: 1.03
#
# Ticker: UNH; Returns Multiple against index: 1.32
#
# Ticker: JNJ; Returns Multiple against index: 1.02
#
# Ticker: XOM; Returns Multiple against index: 1.87
#
# Ticker: META; Returns Multiple against index: 0.45
#
# Ticker: NVDA; Returns Multiple against index: 0.64
#
# Ticker: PG; Returns Multiple against index: 0.99
#
# Ticker: JPM; Returns Multiple against index: 0.78
#
# Ticker: V; Returns Multiple against index: 0.92
#
# Ticker: PFE; Returns Multiple against index: 1.08
#
# Ticker: HD; Returns Multiple against index: 0.92
#
# Ticker: CVX; Returns Multiple against index: 1.73
#
# Ticker: MA; Returns Multiple against index: 0.97
#
# Ticker: ABBV; Returns Multiple against index: 1.38
#
# Ticker: LLY; Returns Multiple against index: 1.35
#
# Ticker: KO; Returns Multiple against index: 1.15
#
# Ticker: PEP; Returns Multiple against index: 1.14
#
# Ticker: MRK; Returns Multiple against index: 1.23
#
# Ticker: BAC; Returns Multiple against index: 0.89
#
# Ticker: VZ; Returns Multiple against index: 0.82
#
# Ticker: COST; Returns Multiple against index: 1.16
#
# Ticker: TMO; Returns Multiple against index: 1.0
#
# Ticker: AVGO; Returns Multiple against index: 1.08
#
# Ticker: ABT; Returns Multiple against index: 0.86
#
# Ticker: MCD; Returns Multiple against index: 1.11
#
# Ticker: CMCSA; Returns Multiple against index: 0.61
#
# Ticker: ACN; Returns Multiple against index: 0.86
#
# Ticker: CSCO; Returns Multiple against index: 0.81
#
# Ticker: DIS; Returns Multiple against index: 0.63
#
# Ticker: ADBE; Returns Multiple against index: 0.6
#
# Ticker: WMT; Returns Multiple against index: 0.95
#
# Ticker: CRM; Returns Multiple against index: 0.63
#
# Ticker: DHR; Returns Multiple against index: 0.88
#
# Ticker: BMY; Returns Multiple against index: 1.15
#
# Ticker: NEE; Returns Multiple against index: 1.08
#
# Ticker: PM; Returns Multiple against index: 0.99
#
# Ticker: T; Returns Multiple against index: 0.9
#
# Ticker: WFC; Returns Multiple against index: 1.04
#
# Ticker: INTC; Returns Multiple against index: 0.6
#
# Ticker: RTX; Returns Multiple against index: 1.09
#
# Ticker: LIN; Returns Multiple against index: 0.94
#
# Ticker: QCOM; Returns Multiple against index: 0.94
#
# Ticker: TXN; Returns Multiple against index: 0.92
#
# Ticker: UPS; Returns Multiple against index: 1.06
#
# Ticker: UNP; Returns Multiple against index: 1.14
#
# Ticker: AMGN; Returns Multiple against index: 1.2
#
# Ticker: NKE; Returns Multiple against index: 0.68
#
# Ticker: IBM; Returns Multiple against index: 1.04
#
# Ticker: CVS; Returns Multiple against index: 1.25
#
# Ticker: MDT; Returns Multiple against index: 0.7
#
# Ticker: AMT; Returns Multiple against index: 0.91
#
# Ticker: AMD; Returns Multiple against index: 0.81
#
# Ticker: HON; Returns Multiple against index: 0.88
#
# Ticker: SPGI; Returns Multiple against index: 0.83
#
# Ticker: COP; Returns Multiple against index: 2.08
#
# Ticker: ELV; Returns Multiple against index: 1.4
#
# Ticker: LOW; Returns Multiple against index: 1.02
#
# Ticker: ORCL; Returns Multiple against index: 0.86
#
# Ticker: INTU; Returns Multiple against index: 0.8
#
# Ticker: MS; Returns Multiple against index: 0.89
#
# Ticker: GS; Returns Multiple against index: 0.86
#
# Ticker: LMT; Returns Multiple against index: 1.25
#
# Ticker: NOW; Returns Multiple against index: 0.73
#
# Ticker: SCHW; Returns Multiple against index: 1.05
#
# Ticker: CAT; Returns Multiple against index: 0.94
#
# Ticker: C; Returns Multiple against index: 0.75
#
# Ticker: SBUX; Returns Multiple against index: 0.76
#
# Ticker: ADP; Returns Multiple against index: 1.24
#
# Ticker: PLD; Returns Multiple against index: 0.99
#
# Ticker: MDLZ; Returns Multiple against index: 1.04
#
# Ticker: BLK; Returns Multiple against index: 0.78
#
# Ticker: AXP; Returns Multiple against index: 1.01
#
# Ticker: CI; Returns Multiple against index: 1.46
#
# Ticker: DUK; Returns Multiple against index: 1.11
#
# Ticker: DE; Returns Multiple against index: 1.04
#
# Ticker: CB; Returns Multiple against index: 1.1
#
# Ticker: PYPL; Returns Multiple against index: 0.34
#
# Ticker: ZTS; Returns Multiple against index: 0.8
#
# Ticker: TMUS; Returns Multiple against index: 1.11
#
# Ticker: NFLX; Returns Multiple against index: 0.39
#
# Ticker: MMC; Returns Multiple against index: 1.05
#
# Ticker: GILD; Returns Multiple against index: 0.96
#
# Ticker: BA; Returns Multiple against index: 0.75
#
# Ticker: SO; Returns Multiple against index: 1.25
#
# Ticker: MO; Returns Multiple against index: 0.97
#
# Ticker: AMAT; Returns Multiple against index: 0.71
#
# Ticker: ADI; Returns Multiple against index: 0.92
#
# Ticker: CCI; Returns Multiple against index: 0.96
#
# Ticker: ISRG; Returns Multiple against index: 0.65
#
# Ticker: VRTX; Returns Multiple against index: 1.55
#
# Ticker: CME; Returns Multiple against index: 1.1
#
# Ticker: MMM; Returns Multiple against index: 0.69
#
# Ticker: BKNG; Returns Multiple against index: 0.86
#
# Ticker: BDX; Returns Multiple against index: 1.06
#
# Ticker: NOC; Returns Multiple against index: 1.41
#
# Ticker: GE; Returns Multiple against index: 0.73
#
# Ticker: PGR; Returns Multiple against index: 1.41
#
# Ticker: CL; Returns Multiple against index: 1.04
#
# Ticker: SYK; Returns Multiple against index: 0.85
#
# Ticker: PNC; Returns Multiple against index: 0.88
#
# Ticker: TGT; Returns Multiple against index: 0.72
#
# Ticker: TJX; Returns Multiple against index: 0.98
#
# Ticker: D; Returns Multiple against index: 1.11
#
# Ticker: EOG; Returns Multiple against index: 1.97
#
# Ticker: REGN; Returns Multiple against index: 1.11
#
# Ticker: TFC; Returns Multiple against index: 0.91
#
# Ticker: CSX; Returns Multiple against index: 1.07
#
# Ticker: USB; Returns Multiple against index: 0.89
#
# Ticker: EQIX; Returns Multiple against index: 0.79
#
# Ticker: ATVI; Returns Multiple against index: 0.99
#
# Ticker: EW; Returns Multiple against index: 0.8
#
# Ticker: HUM; Returns Multiple against index: 1.2
#
# Ticker: MU; Returns Multiple against index: 0.79
#
# Ticker: WM; Returns Multiple against index: 1.14
#
# Ticker: EL; Returns Multiple against index: 0.76
#
# Ticker: AON; Returns Multiple against index: 1.01
#
# Ticker: FIS; Returns Multiple against index: 0.75
#
# Ticker: SHW; Returns Multiple against index: 0.81
#
# Ticker: DG; Returns Multiple against index: 1.14
#
# Ticker: CHTR; Returns Multiple against index: 0.52
#
# Ticker: LRCX; Returns Multiple against index: 0.76
#
# Ticker: NSC; Returns Multiple against index: 1.03
#
# Ticker: BSX; Returns Multiple against index: 0.97
#
# Ticker: FISV; Returns Multiple against index: 0.96
#
# Ticker: APD; Returns Multiple against index: 0.98
#
# Ticker: OXY; Returns Multiple against index: 2.64
#
# Ticker: FDX; Returns Multiple against index: 0.83
#
# Ticker: ICE; Returns Multiple against index: 0.88
#
# Ticker: ITW; Returns Multiple against index: 0.97
#
# Ticker: MRNA; Returns Multiple against index: 0.32
#
# Ticker: GD; Returns Multiple against index: 1.18
#
# Ticker: PXD; Returns Multiple against index: 1.76
#
# Ticker: ETN; Returns Multiple against index: 0.93
#
# Ticker: CNC; Returns Multiple against index: 1.54
#
# Ticker: SLB; Returns Multiple against index: 1.5
#
# Ticker: AEP; Returns Multiple against index: 1.22
#
# Ticker: NEM; Returns Multiple against index: 0.79
#
# Ticker: PSA; Returns Multiple against index: 1.12
#
# Ticker: SRE; Returns Multiple against index: 1.35
#
# Ticker: MCK; Returns Multiple against index: 1.82
#
# Ticker: EMR; Returns Multiple against index: 0.87
#
# Ticker: GM; Returns Multiple against index: 0.84
#
# Ticker: LHX; Returns Multiple against index: 1.04
#
# Ticker: SNPS; Returns Multiple against index: 1.02
#
# Ticker: KMB; Returns Multiple against index: 0.96
#
# Ticker: MPC; Returns Multiple against index: 1.81
#
# Ticker: GIS; Returns Multiple against index: 1.34
#
# Ticker: EXC; Returns Multiple against index: 1.33
#
# Ticker: KLAC; Returns Multiple against index: 1.04
#
# Ticker: F; Returns Multiple against index: 1.25
#
# Ticker: MCO; Returns Multiple against index: 0.79
#
# Ticker: MET; Returns Multiple against index: 1.15
#
# Ticker: VLO; Returns Multiple against index: 1.86
#
# Ticker: SYY; Returns Multiple against index: 1.12
#
# Ticker: ADM; Returns Multiple against index: 1.56
#
# Ticker: AZO; Returns Multiple against index: 1.42
#
# Ticker: FCX; Returns Multiple against index: 0.92
#
# Ticker: ROP; Returns Multiple against index: 0.87
#
# Ticker: O; Returns Multiple against index: 1.06
#
# Ticker: COF; Returns Multiple against index: 0.71
#
# Ticker: ORLY; Returns Multiple against index: 1.22
#
# Ticker: AIG; Returns Multiple against index: 1.03
#
# Ticker: TRV; Returns Multiple against index: 1.07
#
# Ticker: CDNS; Returns Multiple against index: 1.05
#
# Ticker: IQV; Returns Multiple against index: 0.86
#
# Ticker: PSX; Returns Multiple against index: 1.39
#
# Ticker: HCA; Returns Multiple against index: 0.86
#
# Ticker: XEL; Returns Multiple against index: 1.17
#
# Ticker: CTVA; Returns Multiple against index: 1.46
#
# Ticker: ECL; Returns Multiple against index: 0.77
#
# Ticker: NXPI; Returns Multiple against index: 0.8
#
# Ticker: FTNT; Returns Multiple against index: 0.86
#
# Ticker: STZ; Returns Multiple against index: 1.17
#
# Ticker: MAR; Returns Multiple against index: 1.2
#
# Ticker: DOW; Returns Multiple against index: 0.88
#
# Ticker: ADSK; Returns Multiple against index: 0.74
#
# Ticker: APH; Returns Multiple against index: 1.02
#
# Ticker: WMB; Returns Multiple against index: 1.42
#
# Ticker: WELL; Returns Multiple against index: 0.92
#
# Ticker: DLR; Returns Multiple against index: 0.83
#
# Ticker: PAYX; Returns Multiple against index: 1.18
#
# Ticker: PRU; Returns Multiple against index: 0.99
#
# Ticker: CMG; Returns Multiple against index: 0.91
#
# Ticker: TEL; Returns Multiple against index: 0.9
#
# Ticker: SBAC; Returns Multiple against index: 0.95
#
# Ticker: ALL; Returns Multiple against index: 0.99
#
# Ticker: A; Returns Multiple against index: 0.78
#
# Ticker: CTSH; Returns Multiple against index: 0.87
#
# Ticker: MNST; Returns Multiple against index: 0.96
#
# Ticker: MSI; Returns Multiple against index: 1.05
#
# Ticker: DLTR; Returns Multiple against index: 1.6
#
# Ticker: EA; Returns Multiple against index: 0.89
#
# Ticker: ED; Returns Multiple against index: 1.4
#
# Ticker: AJG; Returns Multiple against index: 1.32
#
# Ticker: JCI; Returns Multiple against index: 0.79
#
# Ticker: MSCI; Returns Multiple against index: 0.76
#
# Ticker: DVN; Returns Multiple against index: 2.63
#
# Ticker: AFL; Returns Multiple against index: 1.16
#
# Ticker: YUM; Returns Multiple against index: 0.91
#
# Ticker: HPQ; Returns Multiple against index: 1.03
#
# Ticker: CTAS; Returns Multiple against index: 1.08
#
# Ticker: BAX; Returns Multiple against index: 0.75
#
# Ticker: KMI; Returns Multiple against index: 1.22
#
# Ticker: PEG; Returns Multiple against index: 1.13
#
# Ticker: WEC; Returns Multiple against index: 1.16
#
# Ticker: PH; Returns Multiple against index: 1.0
#
# Ticker: HSY; Returns Multiple against index: 1.32
#
# Ticker: KR; Returns Multiple against index: 1.24
#
# Ticker: GPN; Returns Multiple against index: 0.8
#
# Ticker: RMD; Returns Multiple against index: 0.8
#
# Ticker: WBD; Returns Multiple against index: 0.5
#
# Ticker: BK; Returns Multiple against index: 0.87
#
# Ticker: HLT; Returns Multiple against index: 1.07
#
# Ticker: SPG; Returns Multiple against index: 0.86
#
# Ticker: MCHP; Returns Multiple against index: 0.86
#
# Ticker: BIIB; Returns Multiple against index: 0.71
#
# Ticker: CARR; Returns Multiple against index: 0.76
#
# Ticker: TT; Returns Multiple against index: 0.88
#
# Ticker: OTIS; Returns Multiple against index: 0.82
#
# Ticker: DXCM; Returns Multiple against index: 0.68
#
# Ticker: IDXX; Returns Multiple against index: 0.55
#
# Ticker: IFF; Returns Multiple against index: 0.8
#
# Ticker: ES; Returns Multiple against index: 1.07
#
# Ticker: ILMN; Returns Multiple against index: 0.46
#
# Ticker: VICI; Returns Multiple against index: 1.19
#
# Ticker: HES; Returns Multiple against index: 1.83
#
# Ticker: TWTR; Returns Multiple against index: 0.69
#
# Ticker: PCAR; Returns Multiple against index: 1.09
#
# Ticker: TDG; Returns Multiple against index: 1.06
#
# Ticker: MTB; Returns Multiple against index: 1.42
#
# Ticker: FAST; Returns Multiple against index: 0.98
#
# Ticker: HAL; Returns Multiple against index: 1.54
#
# Ticker: DD; Returns Multiple against index: 0.84
#
# Ticker: NUE; Returns Multiple against index: 1.3
#
# Ticker: VRSK; Returns Multiple against index: 0.94
#
# Ticker: PPG; Returns Multiple against index: 0.85
#
# Ticker: RSG; Returns Multiple against index: 1.21
#
# Ticker: CMI; Returns Multiple against index: 0.96
#
# Ticker: AWK; Returns Multiple against index: 0.85
#
# Ticker: WBA; Returns Multiple against index: 0.77
#
# Ticker: DFS; Returns Multiple against index: 0.87
#
# Ticker: KHC; Returns Multiple against index: 1.05
#
# Ticker: AVB; Returns Multiple against index: 0.99
#
# Ticker: BKR; Returns Multiple against index: 1.09
#
# Ticker: MTD; Returns Multiple against index: 0.82
#
# Ticker: KDP; Returns Multiple against index: 1.13
#
# Ticker: AMP; Returns Multiple against index: 1.09
#
# Ticker: TROW; Returns Multiple against index: 0.59
#
# Ticker: FRC; Returns Multiple against index: 0.79
#
# Ticker: ENPH; Returns Multiple against index: 1.93
#
# Ticker: AME; Returns Multiple against index: 0.97
#
# Ticker: WY; Returns Multiple against index: 1.07
#
# Ticker: ROST; Returns Multiple against index: 0.84
#
# Ticker: OKE; Returns Multiple against index: 1.26
#
# Ticker: TSN; Returns Multiple against index: 1.03
#
# Ticker: KEYS; Returns Multiple against index: 0.96
#
# Ticker: DTE; Returns Multiple against index: 1.17
#
# Ticker: CBRE; Returns Multiple against index: 0.84
#
# Ticker: EQR; Returns Multiple against index: 0.98
#
# Ticker: APTV; Returns Multiple against index: 0.66
#
# Ticker: ODFL; Returns Multiple against index: 0.93
#
# Ticker: GLW; Returns Multiple against index: 0.89
#
# Ticker: EIX; Returns Multiple against index: 1.24
#
# Ticker: EBAY; Returns Multiple against index: 0.63
#
# Ticker: ALB; Returns Multiple against index: 1.25
#
# Ticker: AEE; Returns Multiple against index: 1.13
#
# Ticker: ETR; Returns Multiple against index: 1.11
#
# Ticker: CPRT; Returns Multiple against index: 0.81
#
# Ticker: SIVB; Returns Multiple against index: 0.71
#
# Ticker: EXR; Returns Multiple against index: 1.11
#
# Ticker: STT; Returns Multiple against index: 0.86
#
# Ticker: BALL; Returns Multiple against index: 0.63
#
# Ticker: FITB; Returns Multiple against index: 0.95
#
# Ticker: LYB; Returns Multiple against index: 1.0
#
# Ticker: ROK; Returns Multiple against index: 0.83
#
# Ticker: CHD; Returns Multiple against index: 1.0
#
# Ticker: DHI; Returns Multiple against index: 0.83
#
# Ticker: WST; Returns Multiple against index: 0.68
#
# Ticker: EFX; Returns Multiple against index: 0.73
#
# Ticker: LH; Returns Multiple against index: 0.8
#
# Ticker: FE; Returns Multiple against index: 1.14
#
# Ticker: TSCO; Returns Multiple against index: 1.0
#
# Ticker: ZBH; Returns Multiple against index: 0.85
#
# Ticker: WTW; Returns Multiple against index: 0.92
#
# Ticker: HIG; Returns Multiple against index: 0.99
#
# Ticker: ARE; Returns Multiple against index: 0.82
#
# Ticker: LUV; Returns Multiple against index: 0.8
#
# Ticker: ABC; Returns Multiple against index: 1.21
#
# Ticker: DRE; Returns Multiple against index: 1.23
#
# Ticker: CTRA; Returns Multiple against index: 1.8
#
# Ticker: CDW; Returns Multiple against index: 0.9
#
# Ticker: STE; Returns Multiple against index: 1.01
#
# Ticker: VTR; Returns Multiple against index: 0.91
#
# Ticker: ANET; Returns Multiple against index: 1.42
#
# Ticker: ANSS; Returns Multiple against index: 0.69
#
# Ticker: PPL; Returns Multiple against index: 1.05
#
# Ticker: WAT; Returns Multiple against index: 0.74
#
# Ticker: FANG; Returns Multiple against index: 1.9
#
# Ticker: MKC; Returns Multiple against index: 0.95
#
# Ticker: ON; Returns Multiple against index: 1.53
#
# Ticker: NTRS; Returns Multiple against index: 0.9
#
# Ticker: MTCH; Returns Multiple against index: 0.38
#
# Ticker: MAA; Returns Multiple against index: 0.93
#
# Ticker: GWW; Returns Multiple against index: 1.4
#
# Ticker: IT; Returns Multiple against index: 0.98
#
# Ticker: ULTA; Returns Multiple against index: 1.18
#
# Ticker: CMS; Returns Multiple against index: 1.13
#
# Ticker: TTWO; Returns Multiple against index: 0.83
#
# Ticker: FTV; Returns Multiple against index: 0.88
#
# Ticker: LEN; Returns Multiple against index: 0.81
#
# Ticker: CTLT; Returns Multiple against index: 0.7
#
# Ticker: CNP; Returns Multiple against index: 1.28
#
# Ticker: GPC; Returns Multiple against index: 1.41
#
# Ticker: AMCR; Returns Multiple against index: 1.04
#
# Ticker: VMC; Returns Multiple against index: 0.98
#
# Ticker: DAL; Returns Multiple against index: 0.83
#
# Ticker: CEG; Returns Multiple against index: nan
#
# Ticker: MLM; Returns Multiple against index: 0.97
#
# Ticker: K; Returns Multiple against index: 1.19
#
# Ticker: PKI; Returns Multiple against index: 0.76
#
# Ticker: ALGN; Returns Multiple against index: 0.37
#
# Ticker: RF; Returns Multiple against index: 1.18
#
# Ticker: NDAQ; Returns Multiple against index: 0.98
#
# Ticker: PWR; Returns Multiple against index: 1.27
#
# Ticker: CINF; Returns Multiple against index: 0.88
#
# Ticker: CFG; Returns Multiple against index: 0.93
#
# Ticker: CF; Returns Multiple against index: 2.31
#
# Ticker: HOLX; Returns Multiple against index: 0.86
#
# Ticker: TDY; Returns Multiple against index: 0.9
#
# Ticker: URI; Returns Multiple against index: 0.91
#
# Ticker: CLX; Returns Multiple against index: 0.9
#
# Ticker: DOV; Returns Multiple against index: 0.76
#
# Ticker: HBAN; Returns Multiple against index: 0.96
#
# Ticker: RJF; Returns Multiple against index: 1.21
#
# Ticker: MOS; Returns Multiple against index: 1.79
#
# Ticker: ESS; Returns Multiple against index: 0.89
#
# Ticker: EPAM; Returns Multiple against index: 0.69
#
# Ticker: IR; Returns Multiple against index: 0.92
#
# Ticker: BR; Returns Multiple against index: 1.03
#
# Ticker: HPE; Returns Multiple against index: 0.97
#
# Ticker: FLT; Returns Multiple against index: 0.85
#
# Ticker: MOH; Returns Multiple against index: 1.38
#
# Ticker: VRSN; Returns Multiple against index: 0.86
#
# Ticker: CAG; Returns Multiple against index: 1.08
#
# Ticker: EXPD; Returns Multiple against index: 0.83
#
# Ticker: J; Returns Multiple against index: 0.94
#
# Ticker: DGX; Returns Multiple against index: 0.85
#
# Ticker: KEY; Returns Multiple against index: 0.97
#
# Ticker: SWK; Returns Multiple against index: 0.49
#
# Ticker: ATO; Returns Multiple against index: 1.3
#
# Ticker: MRO; Returns Multiple against index: 2.37
#
# Ticker: PFG; Returns Multiple against index: 1.25
#
# Ticker: ZBRA; Returns Multiple against index: 0.53
#
# Ticker: MPWR; Returns Multiple against index: 0.91
#
# Ticker: WAB; Returns Multiple against index: 1.03
#
# Ticker: COO; Returns Multiple against index: 0.7
#
# Ticker: IP; Returns Multiple against index: 0.79
#
# Ticker: SEDG; Returns Multiple against index: 1.17
#
# Ticker: EVRG; Returns Multiple against index: 1.09
#
# Ticker: PARA; Returns Multiple against index: 0.62
#
# Ticker: KMX; Returns Multiple against index: 0.68
#
# Ticker: SWKS; Returns Multiple against index: 0.59
#
# Ticker: LNT; Returns Multiple against index: 1.09
#
# Ticker: AKAM; Returns Multiple against index: 0.82
#
# Ticker: FDS; Returns Multiple against index: 1.19
#
# Ticker: CAH; Returns Multiple against index: 1.37
#
# Ticker: DPZ; Returns Multiple against index: 0.73
#
# Ticker: GRMN; Returns Multiple against index: 0.54
#
# Ticker: DRI; Returns Multiple against index: 0.91
#
# Ticker: INCY; Returns Multiple against index: 1.02
#
# Ticker: TRMB; Returns Multiple against index: 0.67
#
# Ticker: WRB; Returns Multiple against index: 1.45
#
# Ticker: CPT; Returns Multiple against index: 0.92
#
# Ticker: EXPE; Returns Multiple against index: 0.75
#
# Ticker: SYF; Returns Multiple against index: 0.72
#
# Ticker: LDOS; Returns Multiple against index: 1.0
#
# Ticker: IRM; Returns Multiple against index: 1.24
#
# Ticker: PEAK; Returns Multiple against index: 0.8
#
# Ticker: AES; Returns Multiple against index: 1.19
#
# Ticker: VFC; Returns Multiple against index: 0.63
#
# Ticker: SJM; Returns Multiple against index: 1.19
#
# Ticker: XYL; Returns Multiple against index: 0.73
#
# Ticker: POOL; Returns Multiple against index: 0.73
#
# Ticker: NTAP; Returns Multiple against index: 0.8
#
# Ticker: TER; Returns Multiple against index: 0.74
#
# Ticker: PAYC; Returns Multiple against index: 0.78
#
# Ticker: IEX; Returns Multiple against index: 0.98
#
# Ticker: UDR; Returns Multiple against index: 0.94
#
# Ticker: STX; Returns Multiple against index: 0.85
#
# Ticker: BRO; Returns Multiple against index: 1.14
#
# Ticker: TECH; Returns Multiple against index: 0.67
#
# Ticker: GNRC; Returns Multiple against index: 0.53
#
# Ticker: FMC; Returns Multiple against index: 1.17
#
# Ticker: TYL; Returns Multiple against index: 0.82
#
# Ticker: WDC; Returns Multiple against index: 0.76
#
# Ticker: AVY; Returns Multiple against index: 0.86
#
# Ticker: BBY; Returns Multiple against index: 0.71
#
# Ticker: JKHY; Returns Multiple against index: 1.2
#
# Ticker: HRL; Returns Multiple against index: 1.13
#
# Ticker: OMC; Returns Multiple against index: 1.02
#
# Ticker: TXT; Returns Multiple against index: 0.94
#
# Ticker: CHRW; Returns Multiple against index: 1.33
#
# Ticker: JBHT; Returns Multiple against index: 1.01
#
# Ticker: LKQ; Returns Multiple against index: 1.08
#
# Ticker: PKG; Returns Multiple against index: 0.95
#
# Ticker: BF-B; Returns Multiple against index: 1.05
#
# Ticker: NVR; Returns Multiple against index: 0.83
#
# Ticker: NLOK; Returns Multiple against index: 0.85
#
# Ticker: VTRS; Returns Multiple against index: 0.74
#
# Ticker: BXP; Returns Multiple against index: 0.82
#
# Ticker: CE; Returns Multiple against index: 0.77
#
# Ticker: KIM; Returns Multiple against index: 1.08
#
# Ticker: MAS; Returns Multiple against index: 0.89
#
# Ticker: NI; Returns Multiple against index: 1.28
#
# Ticker: CBOE; Returns Multiple against index: 0.98
#
# Ticker: LVS; Returns Multiple against index: 0.91
#
# Ticker: CTXS; Returns Multiple against index: 0.97
#
# Ticker: HWM; Returns Multiple against index: 1.17
#
# Ticker: APA; Returns Multiple against index: 2.06
#
# Ticker: TFX; Returns Multiple against index: 0.65
#
# Ticker: L; Returns Multiple against index: 1.07
#
# Ticker: UAL; Returns Multiple against index: 0.89
#
# Ticker: SBNY; Returns Multiple against index: 0.71
#
# Ticker: ABMD; Returns Multiple against index: 0.78
#
# Ticker: EMN; Returns Multiple against index: 0.88
#
# Ticker: PTC; Returns Multiple against index: 0.96
#
# Ticker: RE; Returns Multiple against index: 1.13
#
# Ticker: LYV; Returns Multiple against index: 1.08
#
# Ticker: HST; Returns Multiple against index: 1.15
#
# Ticker: NDSN; Returns Multiple against index: 0.98
#
# Ticker: CRL; Returns Multiple against index: 0.49
#
# Ticker: IPG; Returns Multiple against index: 0.82
#
# Ticker: AAP; Returns Multiple against index: 0.93
#
# Ticker: BIO; Returns Multiple against index: 0.62
#
# Ticker: HSIC; Returns Multiple against index: 0.97
#
# Ticker: SNA; Returns Multiple against index: 1.05
#
# Ticker: MGM; Returns Multiple against index: 0.83
#
# Ticker: WRK; Returns Multiple against index: 0.8
#
# Ticker: FOXA; Returns Multiple against index: 0.97
#
# Ticker: TAP; Returns Multiple against index: 1.18
#
# Ticker: HAS; Returns Multiple against index: 0.86
#
# Ticker: LW; Returns Multiple against index: 1.33
#
# Ticker: LUMN; Returns Multiple against index: 0.91
#
# Ticker: ETSY; Returns Multiple against index: 0.51
#
# Ticker: PHM; Returns Multiple against index: 0.88
#
# Ticker: QRVO; Returns Multiple against index: 0.52
#
# Ticker: AIZ; Returns Multiple against index: 0.99
#
# Ticker: CPB; Returns Multiple against index: 1.15
#
# Ticker: CMA; Returns Multiple against index: 1.2
#
# Ticker: MKTX; Returns Multiple against index: 0.61
#
# Ticker: NRG; Returns Multiple against index: 1.03
#
# Ticker: GL; Returns Multiple against index: 1.13
#
# Ticker: REG; Returns Multiple against index: 0.98
#
# Ticker: FFIV; Returns Multiple against index: 0.79
#
# Ticker: JNPR; Returns Multiple against index: 1.07
#
# Ticker: ALLE; Returns Multiple against index: 0.7
#
# Ticker: WHR; Returns Multiple against index: 0.77
#
# Ticker: HII; Returns Multiple against index: 1.22
#
# Ticker: SEE; Returns Multiple against index: 0.97
#
# Ticker: OGN; Returns Multiple against index: 0.91
#
# Ticker: NLSN; Returns Multiple against index: 1.42
#
# Ticker: FBHS; Returns Multiple against index: 0.69
#
# Ticker: AAL; Returns Multiple against index: 0.75
#
# Ticker: PNW; Returns Multiple against index: 1.08
#
# Ticker: RHI; Returns Multiple against index: 0.8
#
# Ticker: CZR; Returns Multiple against index: 0.46
#
# Ticker: BWA; Returns Multiple against index: 0.91
#
# Ticker: TPR; Returns Multiple against index: 0.9
#
# Ticker: LNC; Returns Multiple against index: 0.8
#
# Ticker: RCL; Returns Multiple against index: 0.58
#
# Ticker: XRAY; Returns Multiple against index: 0.56
#
# Ticker: ZION; Returns Multiple against index: 1.05
#
# Ticker: ROL; Returns Multiple against index: 0.94
#
# Ticker: PNR; Returns Multiple against index: 0.62
#
# Ticker: AOS; Returns Multiple against index: 0.82
#
# Ticker: DXC; Returns Multiple against index: 0.78
#
# Ticker: NWL; Returns Multiple against index: 0.76
#
# Ticker: UHS; Returns Multiple against index: 0.7
#
# Ticker: CCL; Returns Multiple against index: 0.46
#
# Ticker: FRT; Returns Multiple against index: 0.92
#
# Ticker: BBWI; Returns Multiple against index: 0.63
#
# Ticker: MHK; Returns Multiple against index: 0.61
#
# Ticker: BEN; Returns Multiple against index: 0.88
#
# Ticker: CDAY; Returns Multiple against index: 0.58
#
# Ticker: NWSA; Returns Multiple against index: 0.81
#
# Ticker: WYNN; Returns Multiple against index: 0.62
#
# Ticker: IVZ; Returns Multiple against index: 0.74
#
# Ticker: PENN; Returns Multiple against index: 0.41
#
# Ticker: ALK; Returns Multiple against index: 0.83
#
# Ticker: DVA; Returns Multiple against index: nan
#
# Ticker: CASH_USD; Returns Multiple against index: nan
#
# Ticker: NCLH; Returns Multiple against index: 0.59
#
# Ticker: VNO; Returns Multiple against index: 0.73
#
# Ticker: DISH; Returns Multiple against index: 0.45
#
# Ticker: FOX; Returns Multiple against index: 0.97
#
# Ticker: RL; Returns Multiple against index: 0.88
#
# Ticker: PVH; Returns Multiple against index: 0.56
#
# Ticker: NWS; Returns Multiple against index: 0.83
#
# Ticker: EMBC; Returns Multiple against index: nan

# %%
# Creating dataframe of only top 40%
tickers["Returns_multiple"] =  returns_multiples
tickers["RS_Rating"] = tickers.groupby("sector").Returns_multiple.rank(pct=True) * 100
rs_df = tickers[tickers.RS_Rating >= tickers.RS_Rating.quantile(.60)].sort_values('RS_Rating',ascending=False)

# %%
# Checking Minervini conditions of top 40% of stocks in given list
exportList = pd.DataFrame(columns=['Stock', "Sector", "RS_Rating", "returns multiple", "Last Price","%change","50 Day MA", "150 Day Ma", "200 Day MA", "52 Week Low", "52 week High", "% from 52 week high"])

for i in range(len(rs_df)):
    stock = rs_df["ticker"].iloc[i]
    ret_mult = rs_df["Returns_multiple"].iloc[i]
    sector = rs_df.index[i]
    try:
        df = pd.read_csv(os.path.join(os.getcwd(),'us_stocks',f'{stock}.csv'), index_col=0) 
        sma = [50, 150, 200]
        for x in sma:
            df["SMA_"+str(x)] = round(df['Adj Close'].rolling(window=x).mean(), 2)
        
        # Storing required values 
        currentClose = df["Adj Close"][-1]
        prevClose =  df["Adj Close"][-2]
        pct_chg   = (currentClose - prevClose ) * 100/ prevClose
        moving_average_50 = df["SMA_50"][-1]
        moving_average_150 = df["SMA_150"][-1]
        moving_average_200 = df["SMA_200"][-1]
        low_of_52week = round(min(df["Low"]), 2)
        high_of_52week = round(max(df["High"]), 2)
        pct_from_52wkhigh = (high_of_52week - currentClose)/high_of_52week * 100
        RS_Rating = round(rs_df[rs_df['ticker']==stock].RS_Rating.tolist()[0])
        
        try:
            moving_average_200_20 = df["SMA_200"][-20]
        except Exception:
            moving_average_200_20 = 0

        # Condition 1: Current Price > 150 SMA and > 200 SMA
        condition_1 = currentClose > moving_average_150 > moving_average_200
        
        # Condition 2: 150 SMA and > 200 SMA
        condition_2 = moving_average_150 > moving_average_200

        # Condition 3: 200 SMA trending up for at least 1 month
        condition_3 = moving_average_200 > moving_average_200_20
        
        # Condition 4: 50 SMA> 150 SMA and 50 SMA> 200 SMA
        condition_4 = moving_average_50 > moving_average_150 > moving_average_200
           
        # Condition 5: Current Price > 50 SMA
        condition_5 = currentClose > moving_average_50
           
        # Condition 6: Current Price is at least 30% above 52 week low
        condition_6 = currentClose >= (1.3*low_of_52week)
           
        # Condition 7: Current Price is within 30% of 52 week high
        condition_7 = currentClose >= (.7*high_of_52week)

        # Condition 8: Daily change is positive 
        #
        
        # If all conditions above are true, add stock to exportList
        if(condition_1 and condition_2 and condition_3 and condition_4 and condition_5 and condition_6 and condition_7):
            exportEntry = pd.DataFrame({'Stock': stock, "Sector" : sector, "RS_Rating": RS_Rating , "returns multiple" : ret_mult, "Last Price" : round(currentClose,3), "%change" : round(pct_chg,2), "50 Day MA": moving_average_50, "150 Day Ma" : moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week, "% from 52 week high" : round(pct_from_52wkhigh,2)},index=[0])
            exportList = pd.concat([exportList,exportEntry], ignore_index=True)
            print (stock + " made the Minervini requirements")
    except Exception as e:
        print (e)
        print(f"Could not gather data on {stock}")

exportList = exportList.sort_values(by='RS_Rating', ascending=False)
print('\n', exportList)
writer = ExcelWriter(os.path.join(os.getcwd(),"output_screener_us_long_SP500.xlsx"))
exportList.to_excel(writer, "Sheet1",index=False)
writer.save()
# Out:
# ENPH made the Minervini requirements
# NLSN made the Minervini requirements
# OXY made the Minervini requirements
# TMUS made the Minervini requirements
# ED made the Minervini requirements
# IRM made the Minervini requirements
# MCK made the Minervini requirements
# CF made the Minervini requirements
# NOC made the Minervini requirements
# MTB made the Minervini requirements
# VRTX made the Minervini requirements
# AZO made the Minervini requirements
# GWW made the Minervini requirements
# PGR made the Minervini requirements
# CNC made the Minervini requirements
# GPC made the Minervini requirements
# SRE made the Minervini requirements
# CHRW made the Minervini requirements
# AJG made the Minervini requirements
# DVN made the Minervini requirements
# CI made the Minervini requirements
# JKHY made the Minervini requirements
# PWR made the Minervini requirements
# LW made the Minervini requirements
# ELV made the Minervini requirements
# CTVA made the Minervini requirements
# HII made the Minervini requirements
# MOH made the Minervini requirements
# HSY made the Minervini requirements
# ATO made the Minervini requirements
# CAH made the Minervini requirements
# ULTA made the Minervini requirements
# HWM made the Minervini requirements
# CNP made the Minervini requirements
# SO made the Minervini requirements
# CTXS made the Minervini requirements
# AEP made the Minervini requirements
# XOM made the Minervini requirements
# VLO made the Minervini requirements
#
#     Stock                  Sector RS_Rating  returns multiple  Last Price  \
# 0   ENPH  Information Technology       100              1.93      305.70
# 5    IRM             Real Estate       100              1.24       55.23
# 7     CF               Materials       100              2.31      103.68
# 6    MCK             Health Care       100              1.82      366.21
# 1   NLSN             Industrials       100              1.42       27.86
# 4     ED               Utilities       100              1.40      100.85
# 3   TMUS  Communication Services       100              1.11      145.70
# 2    OXY                  Energy       100              2.64       65.61
# 8    NOC             Industrials        99              1.41      491.41
# 9    MTB              Financials        98              1.42      187.61
# 11   AZO  Consumer Discretionary        98              1.42     2199.08
# 10  VRTX             Health Care        98              1.55      292.11
# 12   GWW             Industrials        97              1.40      572.74
# 13   PGR              Financials        97              1.41      128.68
# 14   CNC             Health Care        97              1.54       91.99
# 15   GPC  Consumer Discretionary        97              1.41      162.80
# 16   SRE               Utilities        96              1.35      173.76
# 17  CHRW             Industrials        96              1.33      114.29
# 20    CI             Health Care        95              1.46      292.84
# 21  JKHY  Information Technology        95              1.20      200.22
# 19   DVN                  Energy        95              2.63       68.51
# 18   AJG              Financials        95              1.32      188.42
# 22   PWR             Industrials        94              1.27      146.76
# 23    LW        Consumer Staples        94              1.33       79.50
# 24   ELV             Health Care        94              1.40      493.60
# 25  CTVA               Materials        93              1.46       62.52
# 26   HII             Industrials        92              1.22      235.30
# 27   MOH             Health Care        91              1.38      348.23
# 28   HSY        Consumer Staples        91              1.32      226.25
# 30   CAH             Health Care        89              1.37       69.89
# 29   ATO               Utilities        89              1.30      118.09
# 31  ULTA  Consumer Discretionary        88              1.18      442.90
# 32   HWM             Industrials        87              1.17       36.41
# 33   CNP               Utilities        84              1.28       32.85
# 34    SO               Utilities        79              1.25       79.52
# 35  CTXS  Information Technology        74              0.97      103.68
# 36   AEP               Utilities        71              1.22      104.71
# 37   XOM                  Energy        67              1.87       96.50
# 38   VLO                  Energy        62              1.86      113.32
#
#     %change  50 Day MA  150 Day Ma  200 Day MA  52 Week Low  52 week High  \
# 0     -3.69     259.93      203.33      197.34       113.40        324.84
# 5      4.60      50.67       50.50       49.45        41.67         58.61
# 7      1.19      96.67       94.15       87.11        44.83        119.60
# 6     -1.07     346.72      318.77      299.08       193.89        375.23
# 1     -0.04      25.46       24.03       23.01        16.02         27.92
# 4      0.19      96.35       92.79       89.83        71.52        101.57
# 3      0.23     141.25      132.59      127.66       101.51        148.04
# 2      1.75      64.13       59.08       52.31        24.94         77.13
# 8      0.34     473.51      452.93      433.71       344.89        497.20
# 9     -0.15     173.98      171.42      167.99       131.42        193.42
# 11     0.27    2191.92     2068.11     2045.93      1540.98       2362.24
# 10     1.08     288.02      267.48      255.27       176.36        305.95
# 12     0.34     526.67      498.22      497.77       391.16        588.62
# 13    -0.42     119.55      114.01      111.02        89.35        129.24
# 14     0.80      91.43       86.11       84.20        59.67         98.53
# 15     0.53     149.00      135.43      134.57       115.63        163.50
# 16     0.47     160.82      156.51      149.51       119.56        174.88
# 17     0.94     108.24      103.70      103.09        85.80        121.23
# 20     0.73     279.20      257.29      248.04       191.74        294.53
# 21     1.43     197.58      188.12      181.52       147.50        212.62
# 19     1.71      60.13       59.77       55.61        27.40         79.40
# 18     0.71     176.97      167.38      165.93       142.53        192.00
# 22     0.10     137.07      125.43      121.41        93.91        149.33
# 23     0.06      78.12       68.22       66.35        49.71         83.29
# 24     0.87     480.77      480.31      469.05       355.43        533.68
# 25     0.77      57.61       56.51       54.06        40.72         64.03
# 26     1.34     221.65      209.65      203.33       175.50        243.46
# 27    -1.47     317.13      311.80      307.95       249.57        361.25
# 28     0.34     223.58      215.78      208.86       167.80        234.56
# 30    -1.05      62.01       57.52       55.46        45.85         72.28
# 29     0.12     114.83      113.06      109.61        85.80        122.96
# 31    -0.55     399.55      392.85      391.05       330.80        448.29
# 32     1.56      35.58       34.84       33.98        27.41         38.99
# 33     0.46      31.02       30.04       29.27        24.33         33.00
# 34     0.14      75.41       71.80       70.03        60.99         80.57
# 35    -0.02     101.92      100.88       98.79        78.07        115.00
# 36     0.70      98.77       96.41       93.60        80.22        105.49
# 37     1.68      90.76       87.03       81.39        52.96        105.57
# 38     1.24     110.69      107.41       99.02        61.86        146.81
#
#     % from 52 week high
# 0                  5.89
# 5                  5.77
# 7                 13.31
# 6                  2.40
# 1                  0.21
# 4                  0.71
# 3                  1.58
# 2                 14.94
# 8                  1.16
# 9                  3.00
# 11                 6.91
# 10                 4.52
# 12                 2.70
# 13                 0.43
# 14                 6.64
# 15                 0.43
# 16                 0.64
# 17                 5.72
# 20                 0.57
# 21                 5.83
# 19                13.72
# 18                 1.86
# 22                 1.72
# 23                 4.55
# 24                 7.51
# 25                 2.36
# 26                 3.35
# 27                 3.60
# 28                 3.54
# 30                 3.31
# 29                 3.96
# 31                 1.20
# 32                 6.62
# 33                 0.45
# 34                 1.30
# 35                 9.84
# 36                 0.74
# 37                 8.59
# 38                22.81

# %%
exportList
# Out:
#    Stock                  Sector RS_Rating  returns multiple  Last Price  \
# 0   ENPH  Information Technology       100              1.93      305.70
# 5    IRM             Real Estate       100              1.24       55.23
# 7     CF               Materials       100              2.31      103.68
# 6    MCK             Health Care       100              1.82      366.21
# 1   NLSN             Industrials       100              1.42       27.86
# 4     ED               Utilities       100              1.40      100.85
# 3   TMUS  Communication Services       100              1.11      145.70
# 2    OXY                  Energy       100              2.64       65.61
# 8    NOC             Industrials        99              1.41      491.41
# 9    MTB              Financials        98              1.42      187.61
# 11   AZO  Consumer Discretionary        98              1.42     2199.08
# 10  VRTX             Health Care        98              1.55      292.11
# 12   GWW             Industrials        97              1.40      572.74
# 13   PGR              Financials        97              1.41      128.68
# 14   CNC             Health Care        97              1.54       91.99
# 15   GPC  Consumer Discretionary        97              1.41      162.80
# 16   SRE               Utilities        96              1.35      173.76
# 17  CHRW             Industrials        96              1.33      114.29
# 20    CI             Health Care        95              1.46      292.84
# 21  JKHY  Information Technology        95              1.20      200.22
# 19   DVN                  Energy        95              2.63       68.51
# 18   AJG              Financials        95              1.32      188.42
# 22   PWR             Industrials        94              1.27      146.76
# 23    LW        Consumer Staples        94              1.33       79.50
# 24   ELV             Health Care        94              1.40      493.60
# 25  CTVA               Materials        93              1.46       62.52
# 26   HII             Industrials        92              1.22      235.30
# 27   MOH             Health Care        91              1.38      348.23
# 28   HSY        Consumer Staples        91              1.32      226.25
# 30   CAH             Health Care        89              1.37       69.89
# 29   ATO               Utilities        89              1.30      118.09
# 31  ULTA  Consumer Discretionary        88              1.18      442.90
# 32   HWM             Industrials        87              1.17       36.41
# 33   CNP               Utilities        84              1.28       32.85
# 34    SO               Utilities        79              1.25       79.52
# 35  CTXS  Information Technology        74              0.97      103.68
# 36   AEP               Utilities        71              1.22      104.71
# 37   XOM                  Energy        67              1.87       96.50
# 38   VLO                  Energy        62              1.86      113.32
#
#     %change  50 Day MA  150 Day Ma  200 Day MA  52 Week Low  52 week High  \
# 0     -3.69     259.93      203.33      197.34       113.40        324.84
# 5      4.60      50.67       50.50       49.45        41.67         58.61
# 7      1.19      96.67       94.15       87.11        44.83        119.60
# 6     -1.07     346.72      318.77      299.08       193.89        375.23
# 1     -0.04      25.46       24.03       23.01        16.02         27.92
# 4      0.19      96.35       92.79       89.83        71.52        101.57
# 3      0.23     141.25      132.59      127.66       101.51        148.04
# 2      1.75      64.13       59.08       52.31        24.94         77.13
# 8      0.34     473.51      452.93      433.71       344.89        497.20
# 9     -0.15     173.98      171.42      167.99       131.42        193.42
# 11     0.27    2191.92     2068.11     2045.93      1540.98       2362.24
# 10     1.08     288.02      267.48      255.27       176.36        305.95
# 12     0.34     526.67      498.22      497.77       391.16        588.62
# 13    -0.42     119.55      114.01      111.02        89.35        129.24
# 14     0.80      91.43       86.11       84.20        59.67         98.53
# 15     0.53     149.00      135.43      134.57       115.63        163.50
# 16     0.47     160.82      156.51      149.51       119.56        174.88
# 17     0.94     108.24      103.70      103.09        85.80        121.23
# 20     0.73     279.20      257.29      248.04       191.74        294.53
# 21     1.43     197.58      188.12      181.52       147.50        212.62
# 19     1.71      60.13       59.77       55.61        27.40         79.40
# 18     0.71     176.97      167.38      165.93       142.53        192.00
# 22     0.10     137.07      125.43      121.41        93.91        149.33
# 23     0.06      78.12       68.22       66.35        49.71         83.29
# 24     0.87     480.77      480.31      469.05       355.43        533.68
# 25     0.77      57.61       56.51       54.06        40.72         64.03
# 26     1.34     221.65      209.65      203.33       175.50        243.46
# 27    -1.47     317.13      311.80      307.95       249.57        361.25
# 28     0.34     223.58      215.78      208.86       167.80        234.56
# 30    -1.05      62.01       57.52       55.46        45.85         72.28
# 29     0.12     114.83      113.06      109.61        85.80        122.96
# 31    -0.55     399.55      392.85      391.05       330.80        448.29
# 32     1.56      35.58       34.84       33.98        27.41         38.99
# 33     0.46      31.02       30.04       29.27        24.33         33.00
# 34     0.14      75.41       71.80       70.03        60.99         80.57
# 35    -0.02     101.92      100.88       98.79        78.07        115.00
# 36     0.70      98.77       96.41       93.60        80.22        105.49
# 37     1.68      90.76       87.03       81.39        52.96        105.57
# 38     1.24     110.69      107.41       99.02        61.86        146.81
#
#     % from 52 week high
# 0                  5.89
# 5                  5.77
# 7                 13.31
# 6                  2.40
# 1                  0.21
# 4                  0.71
# 3                  1.58
# 2                 14.94
# 8                  1.16
# 9                  3.00
# 11                 6.91
# 10                 4.52
# 12                 2.70
# 13                 0.43
# 14                 6.64
# 15                 0.43
# 16                 0.64
# 17                 5.72
# 20                 0.57
# 21                 5.83
# 19                13.72
# 18                 1.86
# 22                 1.72
# 23                 4.55
# 24                 7.51
# 25                 2.36
# 26                 3.35
# 27                 3.60
# 28                 3.54
# 30                 3.31
# 29                 3.96
# 31                 1.20
# 32                 6.62
# 33                 0.45
# 34                 1.30
# 35                 9.84
# 36                 0.74
# 37                 8.59
# 38                22.81
