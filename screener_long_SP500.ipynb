# %%
### Needed for google colab runtime
import sys
# !{sys.executable} -m pip install pandas_datareader yfinance yahoo_fin pandas numpy openpyxl --upgrade --no-cache-dir

# from google.colab import drive
# drive.mount('/content/drive')
###
# skip if running in mybinder
###
# Out:
# Requirement already satisfied: pandas_datareader in /home/loerl/anaconda3/lib/python3.9/site-packages (0.10.0)
# Requirement already satisfied: yfinance in /home/loerl/anaconda3/lib/python3.9/site-packages (0.1.74)
# Requirement already satisfied: yahoo_fin in /home/loerl/anaconda3/lib/python3.9/site-packages (0.8.9.1)
# Requirement already satisfied: pandas in /home/loerl/anaconda3/lib/python3.9/site-packages (1.4.4)
# Requirement already satisfied: numpy in /home/loerl/anaconda3/lib/python3.9/site-packages (1.23.3)
# Requirement already satisfied: openpyxl in /home/loerl/anaconda3/lib/python3.9/site-packages (3.0.10)
# Requirement already satisfied: lxml in /home/loerl/anaconda3/lib/python3.9/site-packages (from pandas_datareader) (4.6.3)
# Requirement already satisfied: requests>=2.19.0 in /home/loerl/anaconda3/lib/python3.9/site-packages (from pandas_datareader) (2.26.0)
# Requirement already satisfied: multitasking>=0.0.7 in /home/loerl/anaconda3/lib/python3.9/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: feedparser in /home/loerl/anaconda3/lib/python3.9/site-packages (from yahoo_fin) (6.0.10)
# Requirement already satisfied: requests-html in /home/loerl/anaconda3/lib/python3.9/site-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/loerl/anaconda3/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/loerl/anaconda3/lib/python3.9/site-packages (from pandas) (2021.3)
# Requirement already satisfied: et-xmlfile in /home/loerl/anaconda3/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: six>=1.5 in /home/loerl/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/loerl/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/loerl/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/loerl/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/loerl/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pandas_datareader) (3.2)
# Requirement already satisfied: sgmllib3k in /home/loerl/anaconda3/lib/python3.9/site-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: w3lib in /home/loerl/anaconda3/lib/python3.9/site-packages (from requests-html->yahoo_fin) (2.0.1)
# Requirement already satisfied: fake-useragent in /home/loerl/anaconda3/lib/python3.9/site-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: pyquery in /home/loerl/anaconda3/lib/python3.9/site-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: pyppeteer>=0.0.14 in /home/loerl/anaconda3/lib/python3.9/site-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: parse in /home/loerl/anaconda3/lib/python3.9/site-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: bs4 in /home/loerl/anaconda3/lib/python3.9/site-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /home/loerl/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /home/loerl/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /home/loerl/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.62.3)
# Requirement already satisfied: websockets<11.0,>=10.0 in /home/loerl/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.3)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/loerl/anaconda3/lib/python3.9/site-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.8.1)
# Requirement already satisfied: zipp>=0.5 in /home/loerl/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.6.0)
# Requirement already satisfied: beautifulsoup4 in /home/loerl/anaconda3/lib/python3.9/site-packages (from bs4->requests-html->yahoo_fin) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /home/loerl/anaconda3/lib/python3.9/site-packages (from beautifulsoup4->bs4->requests-html->yahoo_fin) (2.2.1)
# Requirement already satisfied: cssselect>0.7.9 in /home/loerl/anaconda3/lib/python3.9/site-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)

# %%
import os, os.path
import errno
from pandas_datareader import data as pdr
from yahoo_fin import stock_info as si
import asyncio
from pandas import ExcelWriter
import yfinance as yf
import pandas as pd
import numpy as np
import datetime
import time

yf.pdr_override()

# %%
#create directory if non-existent
def mkdir_p(path):
    try:
        os.makedirs(path)
    except OSError as exc: # Python >2.5
        if exc.errno == errno.EEXIST and os.path.isdir(path):
            pass
        else: raise
mkdir_p('us_stocks')

# %%
### Variables
tickers = pd.DataFrame()
tickers = pd.read_excel("https://topforeignstocks.com/wp-content/uploads/2022/07/Complete-List-of-SP-500-Constituents-July-4-2022.xlsx",sheet_name=0,header=None,usecols = "C,D",skiprows = 1,names = ["ticker","sector"])
tickers["ticker"] = [item.replace(".", "-") for item in tickers["ticker"]] # Yahoo Finance uses dashes instead of dots
tickers = tickers.set_index("sector")

#combine into one string needed to download multiple files using yfinance module
tickers_string = ""
for i in tickers["ticker"]:
    tickers_string += i + " "

index_name = '^SPX' # SP 500
start_date = datetime.datetime.now() - datetime.timedelta(days=365)
end_date = datetime.date.today()

# %%
###  Download ticker data from yahoo finance simultaneously
results = yf.download(tickers = tickers_string,start = start_date, end = end_date, interval= '1d',threads = True,group_by="ticker")

### write to file
for ticker in tickers["ticker"]:
    df = results[ticker].reset_index()
    df.to_csv( os.path.join(os.getcwd(),'us_stocks',ticker+'.csv'), index = False, header=True )
# Out:
# [*********************100%***********************]  505 of 505 completed
#
# 1 Failed download:
# - CASH_USD: No data found, symbol may be delisted

# %%
# Index Returns
index_df = pdr.get_data_yahoo(index_name, start_date, end_date)
index_return = index_df['Adj Close'].iloc[-1] / index_df['Adj Close'].iloc[0]       # not efficient: (index_df['Percent Change'] + 1).cumprod()[-1]

# Import historical data as CSV for all stocks (makes the process faster)
df_list = pd.concat(( map(pd.read_csv, [os.path.join(os.getcwd(),'us_stocks',s+'.csv') for s in tickers["ticker"] ])), keys=tickers["ticker"] )

# Find top 30% performing stocks (relative to the index)
returns_multiples = []
for ticker in tickers["ticker"]:
    # Calculating returns relative to the market (returns multiple)
    df = df_list.loc[ticker].copy()
    stock_return = df['Adj Close'].iloc[-1] / df['Adj Close'].iloc[0]   # not efficient: ((df['Percent Change'] + 1).cumprod()).iloc[-1]
    
    returns_multiple = round((stock_return / index_return), 2)
    returns_multiples.extend([returns_multiple])
    
    print (f'Ticker: {ticker}; Returns Multiple against index: {returns_multiple}\n')
# Out:
# [*********************100%***********************]  1 of 1 completed
# Ticker: AAPL; Returns Multiple against index: 1.1
#
# Ticker: MSFT; Returns Multiple against index: 0.91
#
# Ticker: AMZN; Returns Multiple against index: 0.79
#
# Ticker: GOOGL; Returns Multiple against index: 0.78
#
# Ticker: GOOG; Returns Multiple against index: 0.78
#
# Ticker: TSLA; Returns Multiple against index: 1.23
#
# Ticker: BRK-B; Returns Multiple against index: 1.03
#
# Ticker: UNH; Returns Multiple against index: 1.3
#
# Ticker: JNJ; Returns Multiple against index: 1.03
#
# Ticker: XOM; Returns Multiple against index: 1.84
#
# Ticker: META; Returns Multiple against index: 0.45
#
# Ticker: NVDA; Returns Multiple against index: 0.66
#
# Ticker: PG; Returns Multiple against index: 0.99
#
# Ticker: JPM; Returns Multiple against index: 0.78
#
# Ticker: V; Returns Multiple against index: 0.93
#
# Ticker: PFE; Returns Multiple against index: 1.11
#
# Ticker: HD; Returns Multiple against index: 0.91
#
# Ticker: CVX; Returns Multiple against index: 1.72
#
# Ticker: MA; Returns Multiple against index: 0.98
#
# Ticker: ABBV; Returns Multiple against index: 1.38
#
# Ticker: LLY; Returns Multiple against index: 1.34
#
# Ticker: KO; Returns Multiple against index: 1.15
#
# Ticker: PEP; Returns Multiple against index: 1.15
#
# Ticker: MRK; Returns Multiple against index: 1.25
#
# Ticker: BAC; Returns Multiple against index: 0.88
#
# Ticker: VZ; Returns Multiple against index: 0.82
#
# Ticker: COST; Returns Multiple against index: 1.18
#
# Ticker: TMO; Returns Multiple against index: 1.04
#
# Ticker: AVGO; Returns Multiple against index: 1.09
#
# Ticker: ABT; Returns Multiple against index: 0.88
#
# Ticker: MCD; Returns Multiple against index: 1.1
#
# Ticker: CMCSA; Returns Multiple against index: 0.61
#
# Ticker: ACN; Returns Multiple against index: 0.88
#
# Ticker: CSCO; Returns Multiple against index: 0.82
#
# Ticker: DIS; Returns Multiple against index: 0.63
#
# Ticker: ADBE; Returns Multiple against index: 0.61
#
# Ticker: WMT; Returns Multiple against index: 0.97
#
# Ticker: CRM; Returns Multiple against index: 0.65
#
# Ticker: DHR; Returns Multiple against index: 0.92
#
# Ticker: BMY; Returns Multiple against index: 1.19
#
# Ticker: NEE; Returns Multiple against index: 1.1
#
# Ticker: PM; Returns Multiple against index: 1.0
#
# Ticker: T; Returns Multiple against index: 0.91
#
# Ticker: WFC; Returns Multiple against index: 1.02
#
# Ticker: INTC; Returns Multiple against index: 0.59
#
# Ticker: RTX; Returns Multiple against index: 1.07
#
# Ticker: LIN; Returns Multiple against index: 0.95
#
# Ticker: QCOM; Returns Multiple against index: 0.94
#
# Ticker: TXN; Returns Multiple against index: 0.9
#
# Ticker: UPS; Returns Multiple against index: 1.06
#
# Ticker: UNP; Returns Multiple against index: 1.16
#
# Ticker: AMGN; Returns Multiple against index: 1.13
#
# Ticker: NKE; Returns Multiple against index: 0.71
#
# Ticker: IBM; Returns Multiple against index: 1.04
#
# Ticker: CVS; Returns Multiple against index: 1.25
#
# Ticker: MDT; Returns Multiple against index: 0.73
#
# Ticker: AMT; Returns Multiple against index: 0.92
#
# Ticker: AMD; Returns Multiple against index: 0.81
#
# Ticker: HON; Returns Multiple against index: 0.88
#
# Ticker: SPGI; Returns Multiple against index: 0.83
#
# Ticker: COP; Returns Multiple against index: 2.05
#
# Ticker: ELV; Returns Multiple against index: 1.35
#
# Ticker: LOW; Returns Multiple against index: 1.02
#
# Ticker: ORCL; Returns Multiple against index: 0.88
#
# Ticker: INTU; Returns Multiple against index: 0.82
#
# Ticker: MS; Returns Multiple against index: 0.89
#
# Ticker: GS; Returns Multiple against index: 0.86
#
# Ticker: LMT; Returns Multiple against index: 1.24
#
# Ticker: NOW; Returns Multiple against index: 0.75
#
# Ticker: SCHW; Returns Multiple against index: 1.05
#
# Ticker: CAT; Returns Multiple against index: 0.95
#
# Ticker: C; Returns Multiple against index: 0.75
#
# Ticker: SBUX; Returns Multiple against index: 0.76
#
# Ticker: ADP; Returns Multiple against index: 1.24
#
# Ticker: PLD; Returns Multiple against index: 1.0
#
# Ticker: MDLZ; Returns Multiple against index: 1.04
#
# Ticker: BLK; Returns Multiple against index: 0.78
#
# Ticker: AXP; Returns Multiple against index: 1.02
#
# Ticker: CI; Returns Multiple against index: 1.43
#
# Ticker: DUK; Returns Multiple against index: 1.12
#
# Ticker: DE; Returns Multiple against index: 1.05
#
# Ticker: CB; Returns Multiple against index: 1.09
#
# Ticker: PYPL; Returns Multiple against index: 0.35
#
# Ticker: ZTS; Returns Multiple against index: 0.82
#
# Ticker: TMUS; Returns Multiple against index: 1.12
#
# Ticker: NFLX; Returns Multiple against index: 0.4
#
# Ticker: MMC; Returns Multiple against index: 1.07
#
# Ticker: GILD; Returns Multiple against index: 1.0
#
# Ticker: BA; Returns Multiple against index: 0.74
#
# Ticker: SO; Returns Multiple against index: 1.26
#
# Ticker: MO; Returns Multiple against index: 0.97
#
# Ticker: AMAT; Returns Multiple against index: 0.7
#
# Ticker: ADI; Returns Multiple against index: 0.92
#
# Ticker: CCI; Returns Multiple against index: 0.96
#
# Ticker: ISRG; Returns Multiple against index: 0.65
#
# Ticker: VRTX; Returns Multiple against index: 1.54
#
# Ticker: CME; Returns Multiple against index: 1.09
#
# Ticker: MMM; Returns Multiple against index: 0.7
#
# Ticker: BKNG; Returns Multiple against index: 0.87
#
# Ticker: BDX; Returns Multiple against index: 1.06
#
# Ticker: NOC; Returns Multiple against index: 1.38
#
# Ticker: GE; Returns Multiple against index: 0.72
#
# Ticker: PGR; Returns Multiple against index: 1.4
#
# Ticker: CL; Returns Multiple against index: 1.03
#
# Ticker: SYK; Returns Multiple against index: 0.87
#
# Ticker: PNC; Returns Multiple against index: 0.88
#
# Ticker: TGT; Returns Multiple against index: 0.73
#
# Ticker: TJX; Returns Multiple against index: 0.99
#
# Ticker: D; Returns Multiple against index: 1.14
#
# Ticker: EOG; Returns Multiple against index: 1.94
#
# Ticker: REGN; Returns Multiple against index: 1.11
#
# Ticker: TFC; Returns Multiple against index: 0.91
#
# Ticker: CSX; Returns Multiple against index: 1.08
#
# Ticker: USB; Returns Multiple against index: 0.87
#
# Ticker: EQIX; Returns Multiple against index: 0.81
#
# Ticker: ATVI; Returns Multiple against index: 1.0
#
# Ticker: EW; Returns Multiple against index: 0.82
#
# Ticker: HUM; Returns Multiple against index: 1.2
#
# Ticker: MU; Returns Multiple against index: 0.78
#
# Ticker: WM; Returns Multiple against index: 1.14
#
# Ticker: EL; Returns Multiple against index: 0.77
#
# Ticker: AON; Returns Multiple against index: 1.01
#
# Ticker: FIS; Returns Multiple against index: 0.76
#
# Ticker: SHW; Returns Multiple against index: 0.81
#
# Ticker: DG; Returns Multiple against index: 1.15
#
# Ticker: CHTR; Returns Multiple against index: 0.51
#
# Ticker: LRCX; Returns Multiple against index: 0.74
#
# Ticker: NSC; Returns Multiple against index: 1.04
#
# Ticker: BSX; Returns Multiple against index: 0.98
#
# Ticker: FISV; Returns Multiple against index: 0.99
#
# Ticker: APD; Returns Multiple against index: 1.0
#
# Ticker: OXY; Returns Multiple against index: 2.52
#
# Ticker: FDX; Returns Multiple against index: 0.83
#
# Ticker: ICE; Returns Multiple against index: 0.89
#
# Ticker: ITW; Returns Multiple against index: 0.97
#
# Ticker: MRNA; Returns Multiple against index: 0.33
#
# Ticker: GD; Returns Multiple against index: 1.21
#
# Ticker: PXD; Returns Multiple against index: 1.78
#
# Ticker: ETN; Returns Multiple against index: 0.95
#
# Ticker: CNC; Returns Multiple against index: 1.48
#
# Ticker: SLB; Returns Multiple against index: 1.45
#
# Ticker: AEP; Returns Multiple against index: 1.23
#
# Ticker: NEM; Returns Multiple against index: 0.8
#
# Ticker: PSA; Returns Multiple against index: 1.13
#
# Ticker: SRE; Returns Multiple against index: 1.35
#
# Ticker: MCK; Returns Multiple against index: 1.78
#
# Ticker: EMR; Returns Multiple against index: 0.88
#
# Ticker: GM; Returns Multiple against index: 0.83
#
# Ticker: LHX; Returns Multiple against index: 1.05
#
# Ticker: SNPS; Returns Multiple against index: 1.02
#
# Ticker: KMB; Returns Multiple against index: 0.95
#
# Ticker: MPC; Returns Multiple against index: 1.75
#
# Ticker: GIS; Returns Multiple against index: 1.34
#
# Ticker: EXC; Returns Multiple against index: 1.32
#
# Ticker: KLAC; Returns Multiple against index: 1.02
#
# Ticker: F; Returns Multiple against index: 1.23
#
# Ticker: MCO; Returns Multiple against index: 0.81
#
# Ticker: MET; Returns Multiple against index: 1.14
#
# Ticker: VLO; Returns Multiple against index: 1.8
#
# Ticker: SYY; Returns Multiple against index: 1.12
#
# Ticker: ADM; Returns Multiple against index: 1.47
#
# Ticker: AZO; Returns Multiple against index: 1.43
#
# Ticker: FCX; Returns Multiple against index: 0.92
#
# Ticker: ROP; Returns Multiple against index: 0.87
#
# Ticker: O; Returns Multiple against index: 1.06
#
# Ticker: COF; Returns Multiple against index: 0.7
#
# Ticker: ORLY; Returns Multiple against index: 1.24
#
# Ticker: AIG; Returns Multiple against index: 1.05
#
# Ticker: TRV; Returns Multiple against index: 1.06
#
# Ticker: CDNS; Returns Multiple against index: 1.06
#
# Ticker: IQV; Returns Multiple against index: 0.89
#
# Ticker: PSX; Returns Multiple against index: 1.39
#
# Ticker: HCA; Returns Multiple against index: 0.87
#
# Ticker: XEL; Returns Multiple against index: 1.19
#
# Ticker: CTVA; Returns Multiple against index: 1.46
#
# Ticker: ECL; Returns Multiple against index: 0.79
#
# Ticker: NXPI; Returns Multiple against index: 0.8
#
# Ticker: FTNT; Returns Multiple against index: 0.94
#
# Ticker: STZ; Returns Multiple against index: 1.17
#
# Ticker: MAR; Returns Multiple against index: 1.17
#
# Ticker: DOW; Returns Multiple against index: 0.88
#
# Ticker: ADSK; Returns Multiple against index: 0.76
#
# Ticker: APH; Returns Multiple against index: 1.02
#
# Ticker: WMB; Returns Multiple against index: 1.44
#
# Ticker: WELL; Returns Multiple against index: 0.91
#
# Ticker: DLR; Returns Multiple against index: 0.85
#
# Ticker: PAYX; Returns Multiple against index: 1.19
#
# Ticker: PRU; Returns Multiple against index: 0.99
#
# Ticker: CMG; Returns Multiple against index: 0.94
#
# Ticker: TEL; Returns Multiple against index: 0.91
#
# Ticker: SBAC; Returns Multiple against index: 0.95
#
# Ticker: ALL; Returns Multiple against index: 0.98
#
# Ticker: A; Returns Multiple against index: 0.82
#
# Ticker: CTSH; Returns Multiple against index: 0.88
#
# Ticker: MNST; Returns Multiple against index: 0.98
#
# Ticker: MSI; Returns Multiple against index: 1.06
#
# Ticker: DLTR; Returns Multiple against index: 1.63
#
# Ticker: EA; Returns Multiple against index: 0.91
#
# Ticker: ED; Returns Multiple against index: 1.42
#
# Ticker: AJG; Returns Multiple against index: 1.32
#
# Ticker: JCI; Returns Multiple against index: 0.8
#
# Ticker: MSCI; Returns Multiple against index: 0.78
#
# Ticker: DVN; Returns Multiple against index: 2.65
#
# Ticker: AFL; Returns Multiple against index: 1.16
#
# Ticker: YUM; Returns Multiple against index: 0.93
#
# Ticker: HPQ; Returns Multiple against index: 1.03
#
# Ticker: CTAS; Returns Multiple against index: 1.07
#
# Ticker: BAX; Returns Multiple against index: 0.75
#
# Ticker: KMI; Returns Multiple against index: 1.23
#
# Ticker: PEG; Returns Multiple against index: 1.15
#
# Ticker: WEC; Returns Multiple against index: 1.18
#
# Ticker: PH; Returns Multiple against index: 0.99
#
# Ticker: HSY; Returns Multiple against index: 1.32
#
# Ticker: KR; Returns Multiple against index: 1.2
#
# Ticker: GPN; Returns Multiple against index: 0.83
#
# Ticker: RMD; Returns Multiple against index: 0.83
#
# Ticker: WBD; Returns Multiple against index: 0.49
#
# Ticker: BK; Returns Multiple against index: 0.87
#
# Ticker: HLT; Returns Multiple against index: 1.05
#
# Ticker: SPG; Returns Multiple against index: 0.85
#
# Ticker: MCHP; Returns Multiple against index: 0.85
#
# Ticker: BIIB; Returns Multiple against index: 0.71
#
# Ticker: CARR; Returns Multiple against index: 0.77
#
# Ticker: TT; Returns Multiple against index: 0.89
#
# Ticker: OTIS; Returns Multiple against index: 0.83
#
# Ticker: DXCM; Returns Multiple against index: 0.7
#
# Ticker: IDXX; Returns Multiple against index: 0.57
#
# Ticker: IFF; Returns Multiple against index: 0.81
#
# Ticker: ES; Returns Multiple against index: 1.08
#
# Ticker: ILMN; Returns Multiple against index: 0.47
#
# Ticker: VICI; Returns Multiple against index: 1.19
#
# Ticker: HES; Returns Multiple against index: 1.8
#
# Ticker: TWTR; Returns Multiple against index: 0.69
#
# Ticker: PCAR; Returns Multiple against index: 1.09
#
# Ticker: TDG; Returns Multiple against index: 1.06
#
# Ticker: MTB; Returns Multiple against index: 1.43
#
# Ticker: FAST; Returns Multiple against index: 0.97
#
# Ticker: HAL; Returns Multiple against index: 1.5
#
# Ticker: DD; Returns Multiple against index: 0.86
#
# Ticker: NUE; Returns Multiple against index: 1.32
#
# Ticker: VRSK; Returns Multiple against index: 0.95
#
# Ticker: PPG; Returns Multiple against index: 0.88
#
# Ticker: RSG; Returns Multiple against index: 1.2
#
# Ticker: CMI; Returns Multiple against index: 0.96
#
# Ticker: AWK; Returns Multiple against index: 0.87
#
# Ticker: WBA; Returns Multiple against index: 0.78
#
# Ticker: DFS; Returns Multiple against index: 0.86
#
# Ticker: KHC; Returns Multiple against index: 1.05
#
# Ticker: AVB; Returns Multiple against index: 0.98
#
# Ticker: BKR; Returns Multiple against index: 1.07
#
# Ticker: MTD; Returns Multiple against index: 0.85
#
# Ticker: KDP; Returns Multiple against index: 1.13
#
# Ticker: AMP; Returns Multiple against index: 1.09
#
# Ticker: TROW; Returns Multiple against index: 0.59
#
# Ticker: FRC; Returns Multiple against index: 0.79
#
# Ticker: ENPH; Returns Multiple against index: 1.93
#
# Ticker: AME; Returns Multiple against index: 0.98
#
# Ticker: WY; Returns Multiple against index: 1.07
#
# Ticker: ROST; Returns Multiple against index: 0.85
#
# Ticker: OKE; Returns Multiple against index: 1.27
#
# Ticker: TSN; Returns Multiple against index: 1.01
#
# Ticker: KEYS; Returns Multiple against index: 0.97
#
# Ticker: DTE; Returns Multiple against index: 1.19
#
# Ticker: CBRE; Returns Multiple against index: 0.83
#
# Ticker: EQR; Returns Multiple against index: 0.98
#
# Ticker: APTV; Returns Multiple against index: 0.67
#
# Ticker: ODFL; Returns Multiple against index: 0.96
#
# Ticker: GLW; Returns Multiple against index: 0.91
#
# Ticker: EIX; Returns Multiple against index: 1.26
#
# Ticker: EBAY; Returns Multiple against index: 0.64
#
# Ticker: ALB; Returns Multiple against index: 1.31
#
# Ticker: AEE; Returns Multiple against index: 1.14
#
# Ticker: ETR; Returns Multiple against index: 1.12
#
# Ticker: CPRT; Returns Multiple against index: 0.82
#
# Ticker: SIVB; Returns Multiple against index: 0.67
#
# Ticker: EXR; Returns Multiple against index: 1.11
#
# Ticker: STT; Returns Multiple against index: 0.86
#
# Ticker: BALL; Returns Multiple against index: 0.65
#
# Ticker: FITB; Returns Multiple against index: 0.95
#
# Ticker: LYB; Returns Multiple against index: 0.99
#
# Ticker: ROK; Returns Multiple against index: 0.83
#
# Ticker: CHD; Returns Multiple against index: 1.0
#
# Ticker: DHI; Returns Multiple against index: 0.84
#
# Ticker: WST; Returns Multiple against index: 0.71
#
# Ticker: EFX; Returns Multiple against index: 0.73
#
# Ticker: LH; Returns Multiple against index: 0.82
#
# Ticker: FE; Returns Multiple against index: 1.16
#
# Ticker: TSCO; Returns Multiple against index: 1.02
#
# Ticker: ZBH; Returns Multiple against index: 0.88
#
# Ticker: WTW; Returns Multiple against index: 0.92
#
# Ticker: HIG; Returns Multiple against index: 0.99
#
# Ticker: ARE; Returns Multiple against index: 0.82
#
# Ticker: LUV; Returns Multiple against index: 0.8
#
# Ticker: ABC; Returns Multiple against index: 1.21
#
# Ticker: DRE; Returns Multiple against index: 1.23
#
# Ticker: CTRA; Returns Multiple against index: 1.79
#
# Ticker: CDW; Returns Multiple against index: 0.91
#
# Ticker: STE; Returns Multiple against index: 1.02
#
# Ticker: VTR; Returns Multiple against index: 0.9
#
# Ticker: ANET; Returns Multiple against index: 1.39
#
# Ticker: ANSS; Returns Multiple against index: 0.71
#
# Ticker: PPL; Returns Multiple against index: 1.06
#
# Ticker: WAT; Returns Multiple against index: 0.78
#
# Ticker: FANG; Returns Multiple against index: 1.87
#
# Ticker: MKC; Returns Multiple against index: 0.97
#
# Ticker: ON; Returns Multiple against index: 1.51
#
# Ticker: NTRS; Returns Multiple against index: 0.89
#
# Ticker: MTCH; Returns Multiple against index: 0.39
#
# Ticker: MAA; Returns Multiple against index: 0.94
#
# Ticker: GWW; Returns Multiple against index: 1.39
#
# Ticker: IT; Returns Multiple against index: 1.01
#
# Ticker: ULTA; Returns Multiple against index: 1.2
#
# Ticker: CMS; Returns Multiple against index: 1.15
#
# Ticker: TTWO; Returns Multiple against index: 0.85
#
# Ticker: FTV; Returns Multiple against index: 0.9
#
# Ticker: LEN; Returns Multiple against index: 0.82
#
# Ticker: CTLT; Returns Multiple against index: 0.7
#
# Ticker: CNP; Returns Multiple against index: 1.3
#
# Ticker: GPC; Returns Multiple against index: 1.4
#
# Ticker: AMCR; Returns Multiple against index: 1.05
#
# Ticker: VMC; Returns Multiple against index: 0.97
#
# Ticker: DAL; Returns Multiple against index: 0.83
#
# Ticker: CEG; Returns Multiple against index: nan
#
# Ticker: MLM; Returns Multiple against index: 0.97
#
# Ticker: K; Returns Multiple against index: 1.19
#
# Ticker: PKI; Returns Multiple against index: 0.78
#
# Ticker: ALGN; Returns Multiple against index: 0.38
#
# Ticker: RF; Returns Multiple against index: 1.17
#
# Ticker: NDAQ; Returns Multiple against index: 1.0
#
# Ticker: PWR; Returns Multiple against index: 1.27
#
# Ticker: CINF; Returns Multiple against index: 0.89
#
# Ticker: CFG; Returns Multiple against index: 0.92
#
# Ticker: CF; Returns Multiple against index: 2.18
#
# Ticker: HOLX; Returns Multiple against index: 0.89
#
# Ticker: TDY; Returns Multiple against index: 0.91
#
# Ticker: URI; Returns Multiple against index: 0.91
#
# Ticker: CLX; Returns Multiple against index: 0.89
#
# Ticker: DOV; Returns Multiple against index: 0.78
#
# Ticker: HBAN; Returns Multiple against index: 0.98
#
# Ticker: RJF; Returns Multiple against index: 1.22
#
# Ticker: MOS; Returns Multiple against index: 1.65
#
# Ticker: ESS; Returns Multiple against index: 0.88
#
# Ticker: EPAM; Returns Multiple against index: 0.71
#
# Ticker: IR; Returns Multiple against index: 0.96
#
# Ticker: BR; Returns Multiple against index: 1.03
#
# Ticker: HPE; Returns Multiple against index: 0.99
#
# Ticker: FLT; Returns Multiple against index: 0.86
#
# Ticker: MOH; Returns Multiple against index: 1.33
#
# Ticker: VRSN; Returns Multiple against index: 0.86
#
# Ticker: CAG; Returns Multiple against index: 1.08
#
# Ticker: EXPD; Returns Multiple against index: 0.83
#
# Ticker: J; Returns Multiple against index: 0.93
#
# Ticker: DGX; Returns Multiple against index: 0.87
#
# Ticker: KEY; Returns Multiple against index: 0.95
#
# Ticker: SWK; Returns Multiple against index: 0.5
#
# Ticker: ATO; Returns Multiple against index: 1.33
#
# Ticker: MRO; Returns Multiple against index: 2.28
#
# Ticker: PFG; Returns Multiple against index: 1.25
#
# Ticker: ZBRA; Returns Multiple against index: 0.54
#
# Ticker: MPWR; Returns Multiple against index: 0.92
#
# Ticker: WAB; Returns Multiple against index: 1.04
#
# Ticker: COO; Returns Multiple against index: 0.72
#
# Ticker: IP; Returns Multiple against index: 0.79
#
# Ticker: SEDG; Returns Multiple against index: 1.15
#
# Ticker: EVRG; Returns Multiple against index: 1.1
#
# Ticker: PARA; Returns Multiple against index: 0.62
#
# Ticker: KMX; Returns Multiple against index: 0.68
#
# Ticker: SWKS; Returns Multiple against index: 0.58
#
# Ticker: LNT; Returns Multiple against index: 1.1
#
# Ticker: AKAM; Returns Multiple against index: 0.83
#
# Ticker: FDS; Returns Multiple against index: 1.2
#
# Ticker: CAH; Returns Multiple against index: 1.35
#
# Ticker: DPZ; Returns Multiple against index: 0.72
#
# Ticker: GRMN; Returns Multiple against index: 0.56
#
# Ticker: DRI; Returns Multiple against index: 0.92
#
# Ticker: INCY; Returns Multiple against index: 0.97
#
# Ticker: TRMB; Returns Multiple against index: 0.7
#
# Ticker: WRB; Returns Multiple against index: 1.45
#
# Ticker: CPT; Returns Multiple against index: 0.92
#
# Ticker: EXPE; Returns Multiple against index: 0.75
#
# Ticker: SYF; Returns Multiple against index: 0.72
#
# Ticker: LDOS; Returns Multiple against index: 0.99
#
# Ticker: IRM; Returns Multiple against index: 1.26
#
# Ticker: PEAK; Returns Multiple against index: 0.81
#
# Ticker: AES; Returns Multiple against index: 1.19
#
# Ticker: VFC; Returns Multiple against index: 0.64
#
# Ticker: SJM; Returns Multiple against index: 1.19
#
# Ticker: XYL; Returns Multiple against index: 0.74
#
# Ticker: POOL; Returns Multiple against index: 0.75
#
# Ticker: NTAP; Returns Multiple against index: 0.82
#
# Ticker: TER; Returns Multiple against index: 0.72
#
# Ticker: PAYC; Returns Multiple against index: 0.81
#
# Ticker: IEX; Returns Multiple against index: 1.0
#
# Ticker: UDR; Returns Multiple against index: 0.92
#
# Ticker: STX; Returns Multiple against index: 0.85
#
# Ticker: BRO; Returns Multiple against index: 1.14
#
# Ticker: TECH; Returns Multiple against index: 0.69
#
# Ticker: GNRC; Returns Multiple against index: 0.53
#
# Ticker: FMC; Returns Multiple against index: 1.17
#
# Ticker: TYL; Returns Multiple against index: 0.83
#
# Ticker: WDC; Returns Multiple against index: 0.74
#
# Ticker: AVY; Returns Multiple against index: 0.87
#
# Ticker: BBY; Returns Multiple against index: 0.71
#
# Ticker: JKHY; Returns Multiple against index: 1.2
#
# Ticker: HRL; Returns Multiple against index: 1.13
#
# Ticker: OMC; Returns Multiple against index: 1.03
#
# Ticker: TXT; Returns Multiple against index: 0.95
#
# Ticker: CHRW; Returns Multiple against index: 1.31
#
# Ticker: JBHT; Returns Multiple against index: 1.03
#
# Ticker: LKQ; Returns Multiple against index: 1.07
#
# Ticker: PKG; Returns Multiple against index: 0.96
#
# Ticker: BF-B; Returns Multiple against index: 1.06
#
# Ticker: NVR; Returns Multiple against index: 0.85
#
# Ticker: NLOK; Returns Multiple against index: 0.87
#
# Ticker: VTRS; Returns Multiple against index: 0.75
#
# Ticker: BXP; Returns Multiple against index: 0.82
#
# Ticker: CE; Returns Multiple against index: 0.78
#
# Ticker: KIM; Returns Multiple against index: 1.05
#
# Ticker: MAS; Returns Multiple against index: 0.9
#
# Ticker: NI; Returns Multiple against index: 1.28
#
# Ticker: CBOE; Returns Multiple against index: 0.99
#
# Ticker: LVS; Returns Multiple against index: 0.9
#
# Ticker: CTXS; Returns Multiple against index: 0.96
#
# Ticker: HWM; Returns Multiple against index: 1.15
#
# Ticker: APA; Returns Multiple against index: 2.01
#
# Ticker: TFX; Returns Multiple against index: 0.65
#
# Ticker: L; Returns Multiple against index: 1.07
#
# Ticker: UAL; Returns Multiple against index: 0.87
#
# Ticker: SBNY; Returns Multiple against index: 0.71
#
# Ticker: ABMD; Returns Multiple against index: 0.79
#
# Ticker: EMN; Returns Multiple against index: 0.89
#
# Ticker: PTC; Returns Multiple against index: 0.98
#
# Ticker: RE; Returns Multiple against index: 1.13
#
# Ticker: LYV; Returns Multiple against index: 1.07
#
# Ticker: HST; Returns Multiple against index: 1.11
#
# Ticker: NDSN; Returns Multiple against index: 0.99
#
# Ticker: CRL; Returns Multiple against index: 0.52
#
# Ticker: IPG; Returns Multiple against index: 0.82
#
# Ticker: AAP; Returns Multiple against index: 0.93
#
# Ticker: BIO; Returns Multiple against index: 0.65
#
# Ticker: HSIC; Returns Multiple against index: 0.96
#
# Ticker: SNA; Returns Multiple against index: 1.05
#
# Ticker: MGM; Returns Multiple against index: 0.84
#
# Ticker: WRK; Returns Multiple against index: 0.82
#
# Ticker: FOXA; Returns Multiple against index: 0.97
#
# Ticker: TAP; Returns Multiple against index: 1.17
#
# Ticker: HAS; Returns Multiple against index: 0.87
#
# Ticker: LW; Returns Multiple against index: 1.32
#
# Ticker: LUMN; Returns Multiple against index: 0.87
#
# Ticker: ETSY; Returns Multiple against index: 0.54
#
# Ticker: PHM; Returns Multiple against index: 0.88
#
# Ticker: QRVO; Returns Multiple against index: 0.51
#
# Ticker: AIZ; Returns Multiple against index: 0.99
#
# Ticker: CPB; Returns Multiple against index: 1.14
#
# Ticker: CMA; Returns Multiple against index: 1.19
#
# Ticker: MKTX; Returns Multiple against index: 0.62
#
# Ticker: NRG; Returns Multiple against index: 1.04
#
# Ticker: GL; Returns Multiple against index: 1.12
#
# Ticker: REG; Returns Multiple against index: 0.96
#
# Ticker: FFIV; Returns Multiple against index: 0.81
#
# Ticker: JNPR; Returns Multiple against index: 1.07
#
# Ticker: ALLE; Returns Multiple against index: 0.72
#
# Ticker: WHR; Returns Multiple against index: 0.76
#
# Ticker: HII; Returns Multiple against index: 1.2
#
# Ticker: SEE; Returns Multiple against index: 0.97
#
# Ticker: OGN; Returns Multiple against index: 0.91
#
# Ticker: NLSN; Returns Multiple against index: 1.39
#
# Ticker: FBHS; Returns Multiple against index: 0.68
#
# Ticker: AAL; Returns Multiple against index: 0.75
#
# Ticker: PNW; Returns Multiple against index: 1.09
#
# Ticker: RHI; Returns Multiple against index: 0.8
#
# Ticker: CZR; Returns Multiple against index: 0.48
#
# Ticker: BWA; Returns Multiple against index: 0.92
#
# Ticker: TPR; Returns Multiple against index: 0.93
#
# Ticker: LNC; Returns Multiple against index: 0.8
#
# Ticker: RCL; Returns Multiple against index: 0.57
#
# Ticker: XRAY; Returns Multiple against index: 0.56
#
# Ticker: ZION; Returns Multiple against index: 1.03
#
# Ticker: ROL; Returns Multiple against index: 0.97
#
# Ticker: PNR; Returns Multiple against index: 0.64
#
# Ticker: AOS; Returns Multiple against index: 0.82
#
# Ticker: DXC; Returns Multiple against index: 0.79
#
# Ticker: NWL; Returns Multiple against index: 0.76
#
# Ticker: UHS; Returns Multiple against index: 0.71
#
# Ticker: CCL; Returns Multiple against index: 0.45
#
# Ticker: FRT; Returns Multiple against index: 0.9
#
# Ticker: BBWI; Returns Multiple against index: 0.64
#
# Ticker: MHK; Returns Multiple against index: 0.59
#
# Ticker: BEN; Returns Multiple against index: 0.88
#
# Ticker: CDAY; Returns Multiple against index: 0.58
#
# Ticker: NWSA; Returns Multiple against index: 0.81
#
# Ticker: WYNN; Returns Multiple against index: 0.62
#
# Ticker: IVZ; Returns Multiple against index: 0.74
#
# Ticker: PENN; Returns Multiple against index: 0.42
#
# Ticker: ALK; Returns Multiple against index: 0.82
#
# Ticker: DVA; Returns Multiple against index: 0.76
#
# Ticker: CASH_USD; Returns Multiple against index: nan
#
# Ticker: NCLH; Returns Multiple against index: 0.58
#
# Ticker: VNO; Returns Multiple against index: 0.73
#
# Ticker: DISH; Returns Multiple against index: 0.44
#
# Ticker: FOX; Returns Multiple against index: 0.97
#
# Ticker: RL; Returns Multiple against index: 0.9
#
# Ticker: PVH; Returns Multiple against index: 0.55
#
# Ticker: NWS; Returns Multiple against index: 0.85
#
# Ticker: EMBC; Returns Multiple against index: nan

# %%
# Creating dataframe of only top 40%
tickers["Returns_multiple"] =  returns_multiples
tickers["RS_Rating"] = tickers.groupby("sector").Returns_multiple.rank(pct=True) * 100
rs_df = tickers[tickers.RS_Rating >= tickers.RS_Rating.quantile(.60)].sort_values('RS_Rating',ascending=False)

# %%
# Checking Minervini conditions of top 40% of stocks in given list
exportList = pd.DataFrame(columns=['Stock', "Sector", "RS_Rating", "returns multiple", "Last Price","%change","50 Day MA", "150 Day Ma", "200 Day MA", "52 Week Low", "52 week High", "% from 52 week high"])

for i in range(len(rs_df)):
    stock = rs_df["ticker"].iloc[i]
    ret_mult = rs_df["Returns_multiple"].iloc[i]
    sector = rs_df.index[i]
    try:
        df = pd.read_csv(os.path.join(os.getcwd(),'us_stocks',f'{stock}.csv'), index_col=0) 
        sma = [50, 150, 200]
        for x in sma:
            df["SMA_"+str(x)] = round(df['Adj Close'].rolling(window=x).mean(), 2)
        
        # Storing required values 
        currentClose = df["Adj Close"][-1]
        prevClose =  df["Adj Close"][-2]
        pct_chg   = (currentClose - prevClose ) * 100/ prevClose
        moving_average_50 = df["SMA_50"][-1]
        moving_average_150 = df["SMA_150"][-1]
        moving_average_200 = df["SMA_200"][-1]
        low_of_52week = round(min(df["Low"]), 2)
        high_of_52week = round(max(df["High"]), 2)
        pct_from_52wkhigh = (high_of_52week - currentClose)/high_of_52week * 100
        RS_Rating = round(rs_df[rs_df['ticker']==stock].RS_Rating.tolist()[0])
        
        try:
            moving_average_200_20 = df["SMA_200"][-20]
        except Exception:
            moving_average_200_20 = 0

        # Condition 1: Current Price > 150 SMA and > 200 SMA
        condition_1 = currentClose > moving_average_150 > moving_average_200
        
        # Condition 2: 150 SMA and > 200 SMA
        condition_2 = moving_average_150 > moving_average_200

        # Condition 3: 200 SMA trending up for at least 1 month
        condition_3 = moving_average_200 > moving_average_200_20
        
        # Condition 4: 50 SMA> 150 SMA and 50 SMA> 200 SMA
        condition_4 = moving_average_50 > moving_average_150 > moving_average_200
           
        # Condition 5: Current Price > 50 SMA
        condition_5 = currentClose > moving_average_50
           
        # Condition 6: Current Price is at least 30% above 52 week low
        condition_6 = currentClose >= (1.3*low_of_52week)
           
        # Condition 7: Current Price is within 30% of 52 week high
        condition_7 = currentClose >= (.7*high_of_52week)

        # Condition 8: Daily change is positive 
        #
        
        # If all conditions above are true, add stock to exportList
        if(condition_1 and condition_2 and condition_3 and condition_4 and condition_5 and condition_6 and condition_7):
            exportEntry = pd.DataFrame({'Stock': stock, "Sector" : sector, "RS_Rating": RS_Rating , "returns multiple" : ret_mult, "Last Price" : round(currentClose,3), "%change" : round(pct_chg,2), "50 Day MA": moving_average_50, "150 Day Ma" : moving_average_150, "200 Day MA": moving_average_200, "52 Week Low": low_of_52week, "52 week High": high_of_52week, "% from 52 week high" : round(pct_from_52wkhigh,2)},index=[0])
            exportList = pd.concat([exportList,exportEntry], ignore_index=True)
            print (stock + " made the Minervini requirements")
    except Exception as e:
        print (e)
        print(f"Could not gather data on {stock}")

exportList = exportList.sort_values(by='RS_Rating', ascending=False)
# print('\n', exportList)
writer = ExcelWriter(os.path.join(os.getcwd(),"output_screener_us_long_SP500.xlsx"))
exportList.to_excel(writer, "Sheet1",index=False)
writer.save()
# Out:
# MCK made the Minervini requirements
# IRM made the Minervini requirements
# TMUS made the Minervini requirements
# ENPH made the Minervini requirements
# ED made the Minervini requirements
# DVN made the Minervini requirements
# CF made the Minervini requirements
# NLSN made the Minervini requirements
# GWW made the Minervini requirements
# MTB made the Minervini requirements
# VRTX made the Minervini requirements
# AZO made the Minervini requirements
# NOC made the Minervini requirements
# PGR made the Minervini requirements
# GIS made the Minervini requirements
# CNC made the Minervini requirements
# GPC made the Minervini requirements
# SRE made the Minervini requirements
# CHRW made the Minervini requirements
# AJG made the Minervini requirements
# CI made the Minervini requirements
# OXY made the Minervini requirements
# JKHY made the Minervini requirements
# PWR made the Minervini requirements
# CTVA made the Minervini requirements
# ATO made the Minervini requirements
# LW made the Minervini requirements
# HSY made the Minervini requirements
# CAH made the Minervini requirements
# ELV made the Minervini requirements
# ULTA made the Minervini requirements
# RSG made the Minervini requirements
# HII made the Minervini requirements
# MOH made the Minervini requirements
# UNH made the Minervini requirements
# HWM made the Minervini requirements
# CNP made the Minervini requirements
# HUM made the Minervini requirements
# SO made the Minervini requirements
# AEP made the Minervini requirements
# CTXS made the Minervini requirements
# XOM made the Minervini requirements

# %%
exportList
# Out:
#    Stock                  Sector RS_Rating  returns multiple  Last Price  \
# 0    MCK             Health Care       100              1.78      363.73
# 1    IRM             Real Estate       100              1.26       56.54
# 2   TMUS  Communication Services       100              1.12      145.15
# 3   ENPH  Information Technology       100              1.93      308.93
# 4     ED               Utilities       100              1.42      101.92
# 5    DVN                  Energy       100              2.65       71.19
# 6     CF               Materials       100              2.18       99.48
# 7   NLSN             Industrials        99              1.39       27.86
# 8    GWW             Industrials        99              1.39      568.10
# 11   AZO  Consumer Discretionary        98              1.43     2220.38
# 10  VRTX             Health Care        98              1.54      293.48
# 9    MTB              Financials        98              1.43      190.55
# 12   NOC             Industrials        97              1.38      482.30
# 13   PGR              Financials        97              1.40      129.10
# 14   GIS        Consumer Staples        97              1.34       76.15
# 15   CNC             Health Care        97              1.48       92.90
# 16   GPC  Consumer Discretionary        97              1.40      163.15
# 17   SRE               Utilities        96              1.35      175.65
# 18  CHRW             Industrials        96              1.31      113.55
# 22  JKHY  Information Technology        95              1.20      200.17
# 21   OXY                  Energy        95              2.52       66.80
# 20    CI             Health Care        95              1.43      294.15
# 19   AJG              Financials        95              1.32      187.63
# 23   PWR             Industrials        94              1.27      145.66
# 24  CTVA               Materials        93              1.46       62.11
# 25   ATO               Utilities        93              1.33      119.44
# 26    LW        Consumer Staples        92              1.32       80.06
# 27   HSY        Consumer Staples        92              1.32      227.18
# 28   CAH             Health Care        91              1.35       69.03
# 29   ELV             Health Care        91              1.35      493.66
# 30  ULTA  Consumer Discretionary        90              1.20      446.14
# 32   HII             Industrials        89              1.20      235.00
# 31   RSG             Industrials        89              1.20      148.10
# 33   MOH             Health Care        88              1.33      349.36
# 34   UNH             Health Care        86              1.30      531.25
# 35   HWM             Industrials        86              1.15       37.02
# 36   CNP               Utilities        86              1.30       33.10
# 37   HUM             Health Care        80              1.20      486.14
# 38    SO               Utilities        77              1.26       80.15
# 39   AEP               Utilities        71              1.23      105.18
# 40  CTXS  Information Technology        68              0.96      103.67
# 41   XOM                  Energy        67              1.84       97.61
#
#     %change  50 Day MA  150 Day Ma  200 Day MA  52 Week Low  52 week High  \
# 0     -0.68     347.48      319.44      299.77       193.89        375.23
# 1      2.37      50.83       50.58       49.51        41.67         58.61
# 2     -0.38     141.46      132.76      127.81       101.51        148.04
# 3      1.06     262.20      204.45      197.63       113.40        324.84
# 4      1.06      96.51       92.91       89.95        71.52        102.21
# 5      3.91      60.47       59.92       55.77        27.40         79.40
# 6     -4.05      96.95       94.32       87.28        45.52        119.60
# 7      0.00      25.55       24.10       23.04        16.02         27.92
# 8     -0.81     528.97      498.79      498.14       391.16        588.62
# 11     0.97    2193.34     2069.45     2047.64      1540.98       2362.24
# 10     0.47     288.25      267.83      255.80       176.36        305.95
# 9      1.57     174.63      171.52      168.15       131.42        193.42
# 12    -1.85     473.62      453.71      434.33       344.89        497.20
# 13     0.33     119.80      114.15      111.20        89.35        129.76
# 14     0.32      75.94       70.56       69.32        57.47         78.54
# 15     0.99      91.60       86.19       84.29        59.84         98.53
# 16     0.21     149.62      135.67      134.72       115.63        164.99
# 17     1.09     161.35      156.79      149.78       119.56        176.47
# 18    -0.65     108.50      103.87      103.18        85.80        121.23
# 22    -0.02     197.99      188.34      181.76       147.50        212.62
# 21     1.81      64.29       59.25       52.48        24.96         77.13
# 20     0.45     279.84      257.79      248.47       191.74        296.29
# 19    -0.42     177.47      167.60      166.06       142.53        192.00
# 23    -0.75     137.48      125.74      121.54        93.91        149.33
# 24    -0.66      57.78       56.59       54.13        40.72         64.03
# 25     1.14     114.99      113.17      109.74        85.80        122.96
# 26     0.70      78.30       68.34       66.46        49.71         83.29
# 27     0.41     223.84      215.96      209.10       167.80        234.56
# 28    -1.23      62.35       57.64       55.56        45.85         72.28
# 29     0.01     481.02      480.65      469.42       358.39        533.68
# 30     0.73     400.77      393.38      391.23       330.80        451.30
# 32    -0.13     222.01      210.02      203.58       175.50        243.46
# 31     0.26     139.04      132.05      131.97       113.57        149.17
# 33     0.32     318.53      312.14      308.16       249.78        361.25
# 34     1.32     527.44      505.09      496.03       383.12        553.29
# 35     1.68      35.69       34.87       34.01        27.41         38.99
# 36     0.76      31.09       30.08       29.31        24.33         33.23
# 37     1.60     485.84      454.53      446.31       351.20        504.99
# 38     0.79      75.60       71.88       70.13        60.99         80.57
# 39     0.45      98.97       96.53       93.71        80.22        105.60
# 40    -0.01     102.05      100.89       98.89        78.07        115.00
# 41     1.15      91.01       87.15       81.57        52.96        105.57
#
#     % from 52 week high
# 0                  3.06
# 1                  3.53
# 2                  1.95
# 3                  4.90
# 4                  0.28
# 5                 10.34
# 6                 16.82
# 7                  0.21
# 8                  3.49
# 11                 6.01
# 10                 4.08
# 9                  1.48
# 12                 3.00
# 13                 0.51
# 14                 3.04
# 15                 5.71
# 16                 1.12
# 17                 0.46
# 18                 6.34
# 22                 5.86
# 21                13.39
# 20                 0.72
# 19                 2.28
# 23                 2.46
# 24                 3.00
# 25                 2.86
# 26                 3.88
# 27                 3.15
# 28                 4.50
# 29                 7.50
# 30                 1.14
# 32                 3.47
# 31                 0.72
# 33                 3.29
# 34                 3.98
# 35                 5.05
# 36                 0.39
# 37                 3.73
# 38                 0.52
# 39                 0.40
# 40                 9.85
# 41                 7.54
